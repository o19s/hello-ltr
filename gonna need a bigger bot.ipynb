# %% [markdown]
# # We're Gonna Need a Bigger Bot
#
# Let's map all the bits and pieces to a meatier example, to see how hello-ltr's abstractions make it easier to play with LTR via ipynbs
#
# Genome-tags is a crowdsourced movie tagging resource project. Each movie is assigned from 0-1 how close a movie matches a tag. Luckily the tags look remarkably like search queries (ie `star trek` or `berlin`). We derrived judgments from the genome-tags data, and use them to experiment with search.
#
# BUT
#
# While some tags are straight forward (`Star Trek`) others are much tougher (`boxing` or `french art movie`) where its unlikely any text has a match.
#
# We're not going to solve those problems here, but we give this to you as a sandbox to apply your skills after the class to see how close you can get to approximating the genome tags data

# %% [markdown]
# ### Clients
#
# While syntaxes differ, the LTR process is nearly identical between Solr and Elastic. So you can repeat a lot of the labs with Solr (some have been already translated)
#
# But we'll stick with Elastic

# %%
from ltr.client.elastic_client import ElasticClient
client = ElasticClient()

# %% [markdown]
# ### Reindex if you need to

# %%
from ltr.index import rebuild_tmdb
rebuild_tmdb(client)
# Out:
# Deleted index tmdb [Status: 200]
# Created index tmdb [Status: 200]
# Reindexing...
# Indexed 0 movies (last Black Mirror: White Christmas)
# Indexed 100 movies (last Apocalypse Now)
# Indexed 200 movies (last Crooks in Clover)
# Indexed 300 movies (last For a Few Dollars More)
# Indexed 400 movies (last Downfall)
# Indexed 500 movies (last Finding Nemo)
# Indexed 600 movies (last Platoon)
# Indexed 700 movies (last Night of the Living Dead)
# Indexed 800 movies (last Evangelion: 1.0: You Are (Not) Alone)
# Indexed 900 movies (last Batman: Assault on Arkham)
# Indexed 1000 movies (last Riley's First Date?)
# Indexed 1100 movies (last The Raid)
# Indexed 1200 movies (last Falling Down)
# Indexed 1300 movies (last Kal Ho Naa Ho)
# Indexed 1400 movies (last Elizabeth)
# Indexed 1500 movies (last Irreversible)
# Indexed 1600 movies (last Friday Night Lights)
# Indexed 1700 movies (last Ben X)
# Indexed 1800 movies (last Pump up the Volume)
# Indexed 1900 movies (last Armour of God)
# Indexed 2000 movies (last Swingers)
# Indexed 2100 movies (last The Guard)
# Indexed 2200 movies (last Win Win)
# Indexed 2300 movies (last Where the Heart Is)
# Indexed 2400 movies (last UHF)
# Indexed 2500 movies (last Jerry Maguire)
# Indexed 2600 movies (last Cloud Atlas)
# Indexed 2700 movies (last Rango)
# Indexed 2800 movies (last Rosewater)
# Indexed 2900 movies (last Kalifornia)
# Indexed 3000 movies (last Bad Santa)
# Indexed 3100 movies (last Defendor)
# Indexed 3200 movies (last The Pirates! Band of Misfits)
# Indexed 3300 movies (last Sister Act)
# Indexed 3400 movies (last Live and Let Die)
# Indexed 3500 movies (last Hours)
# Indexed 3600 movies (last Monsters)
# Indexed 3700 movies (last MouseHunt)
# Indexed 3800 movies (last Olympus Has Fallen)
# Indexed 3900 movies (last Godzilla)
# Indexed 4000 movies (last Arbitrage)
# Indexed 4100 movies (last Under Siege)
# Indexed 4200 movies (last Underdogs)
# Indexed 4300 movies (last The Duke of Burgundy)
# Indexed 4400 movies (last Bambi II)
# Indexed 4500 movies (last Solaris)
# Indexed 4600 movies (last The Stuff)
# Indexed 4700 movies (last Tales from the Darkside: The Movie)
# Indexed 4800 movies (last Final Fantasy: The Spirits Within)
# Indexed 4900 movies (last The Back-Up Plan)
# Indexed 5000 movies (last Absolutely Anything)
# Indexed 5100 movies (last Funny People)
# Indexed 5200 movies (last Tad, the Lost Explorer)
# Indexed 5300 movies (last Fiston)
# Indexed 5400 movies (last The Reaping)
# Indexed 5500 movies (last American Pie Presents: Beta House)
# Indexed 5600 movies (last Casino Royale)
# Indexed 5700 movies (last Jennifer's Body)
# Indexed 5800 movies (last Caligula)
# Indexed 5900 movies (last Alex Cross)
# Indexed 6000 movies (last Rapture Palooza)
# Indexed 6100 movies (last The Seeker: The Dark Is Rising)
# Indexed 6200 movies (last Boogeyman)
# Indexed 6300 movies (last Fifty Shades of Black)
# Indexed 6400 movies (last Wilbur Wants to Kill Himself)
# Indexed 6500 movies (last A Cruel Romance)
# Indexed 6600 movies (last La discrète)
# Indexed 6700 movies (last The Rapture)
# Indexed 6800 movies (last Ricky Gervais Live 3: Fame)
# Indexed 6900 movies (last Bunny Lake Is Missing)
# Indexed 7000 movies (last Alice in the Cities)
# Indexed 7100 movies (last Le pélican)
# Indexed 7200 movies (last 20,000 Leagues Under the Sea)
# Indexed 7300 movies (last Deuces Wild)
# Indexed 7400 movies (last Lost Horizon)
# Indexed 7500 movies (last The Detective 2)
# Indexed 7600 movies (last Absolute Aggression)
# Indexed 7700 movies (last A Fairly Odd Movie: Grow Up, Timmy Turner!)
# Indexed 7800 movies (last How Much Do You Love Me?)
# Indexed 7900 movies (last The Snows of Kilimanjaro)
# Indexed 8000 movies (last The Wrong Guys)
# Indexed 8100 movies (last BFFs)
# Indexed 8200 movies (last Foreverland)
# Indexed 8300 movies (last Rebellion)
# Indexed 8400 movies (last Air Crew)
# Indexed 8500 movies (last Down in the Valley)
# Indexed 8600 movies (last Female Agents)
# Indexed 8700 movies (last Come Dance with Me!)
# Indexed 8800 movies (last Versailles)
# Indexed 8900 movies (last Girls on Top)
# Indexed 9000 movies (last Voll Normaaal)
# Indexed 9100 movies (last Unrated II: Scary as Hell)
# Indexed 9200 movies (last The Flight of the Phoenix)
# Indexed 9300 movies (last DragonHeart: A New Beginning)
# Indexed 9400 movies (last Empire of the Wolves)
# Indexed 9500 movies (last Searching for Debra Winger)
# Indexed 9600 movies (last Swimming Pool)
# Indexed 9700 movies (last Bomber)
# Indexed 9800 movies (last Bullet in the Head)
# Indexed 9900 movies (last Club Fed)
# Indexed 10000 movies (last Titus)
# Indexed 10100 movies (last Revolution)
# Indexed 10200 movies (last The Last Dispatch)
# Indexed 10300 movies (last Wings of Courage)
# Indexed 10400 movies (last Gaslight)
# Indexed 10500 movies (last Frenchmen 2)
# Indexed 10600 movies (last Closing the Ring)
# Indexed 10700 movies (last 3:10 to Yuma)
# Indexed 10800 movies (last Harvest)
# Indexed 10900 movies (last Song of the Thin Man)
# Indexed 11000 movies (last Nobody Knows Anything!)
# Indexed 11100 movies (last Dirty Deeds)
# Indexed 11200 movies (last The Adventure of Faustus Bidgood)
# Indexed 11300 movies (last Running Time)
# Indexed 11400 movies (last While She Was Out)
# Indexed 11500 movies (last What?)
# Indexed 11600 movies (last The Legend of Hell House)
# Indexed 11700 movies (last When Worlds Collide)
# Indexed 11800 movies (last The Girl in the Red Velvet Swing)
# Indexed 11900 movies (last 9 Souls)
# Indexed 12000 movies (last Paradise Lost 2: Revelations)
# Indexed 12100 movies (last Riki-Oh: The Story of Ricky)
# Indexed 12200 movies (last In Vogue: The Editor’s Eye)
# Indexed 12300 movies (last Smart Money)
# Indexed 12400 movies (last Manda Bala (Send a Bullet))
# Indexed 12500 movies (last Something to Talk About)
# Indexed 12600 movies (last Donald Glover: Weirdo)
# Indexed 12700 movies (last Demon Seed)
# Indexed 12800 movies (last Zig Zag)
# Indexed 12900 movies (last Going Overboard)
# Indexed 13000 movies (last Mahler)
# Indexed 13100 movies (last Carriage to Vienna)
# Indexed 13200 movies (last The Big Clock)
# Indexed 13300 movies (last Arsenal)
# Indexed 13400 movies (last First Descent)
# Indexed 13500 movies (last Deep Cover)
# Indexed 13600 movies (last Mixed Blood)
# Indexed 13700 movies (last Red Psalm)
# Indexed 13800 movies (last Bad Biology)
# Indexed 13900 movies (last Shirin)
# Indexed 14000 movies (last Rhyme & Reason)
# Indexed 14100 movies (last Tuareg: Desert Warrior)
# Indexed 14200 movies (last Havoc)
# Indexed 14300 movies (last Fire Over England)
# Indexed 14400 movies (last Impulse)
# Indexed 14500 movies (last Cheers For Miss Bishop)
# Indexed 14600 movies (last Don't Bother to Knock)
# Indexed 14700 movies (last Brides)
# Indexed 14800 movies (last The Land Before Time XI: Invasion of the Tinysauruses)
# Indexed 14900 movies (last The Gnome-Mobile)
# Indexed 15000 movies (last Miracles: Mr. Canton and Lady Rose)
# Indexed 15100 movies (last An Occurrence at Owl Creek Bridge)
# Indexed 15200 movies (last 16 to Life)
# Indexed 15300 movies (last Week-End at the Waldorf)
# Indexed 15400 movies (last Made in Hong Kong)
# Indexed 15500 movies (last Viva Cuba)
# Indexed 15600 movies (last Big Pun: The Legacy)
# Indexed 15700 movies (last Hurt)
# Indexed 15800 movies (last The Mudge Boy)
# Indexed 15900 movies (last The Hollywood Complex)
# Indexed 16000 movies (last The Great Northfield Minnesota Raid)
# Indexed 16100 movies (last Lotta Leaves Home)
# Indexed 16200 movies (last Just One of the Girls)
# Indexed 16300 movies (last Which Way Is The Front Line From Here? The Life and Time of Tim Hetherington)
# Indexed 16400 movies (last The Ladies Man)
# Indexed 16500 movies (last Assassin of the Tsar)
# Indexed 16600 movies (last The Adventures of Tarzan)
# Indexed 16700 movies (last Vendetta)
# Indexed 16800 movies (last Trucker)
# Indexed 16900 movies (last Branded)
# Indexed 17000 movies (last Mariage à Mendoza)
# Indexed 17100 movies (last Love Bites)
# Indexed 17200 movies (last The Ballad of Ramblin' Jack)
# Indexed 17300 movies (last Blade of the Ripper)
# Indexed 17400 movies (last Kiler)
# Indexed 17500 movies (last Kaïrat)
# Indexed 17600 movies (last Body Bags)
# Indexed 17700 movies (last Dave Attell: Captain Miserable)
# Indexed 17800 movies (last Wodehouse In Exile)
# Indexed 17900 movies (last Duel in the Sun)
# Indexed 18000 movies (last The Message)
# Indexed 18100 movies (last Shock)
# Indexed 18200 movies (last Harvey)
# Indexed 18300 movies (last The Worthless)
# Indexed 18400 movies (last Queen of the Mountains)
# Indexed 18500 movies (last Urgh! A Music War)
# Indexed 18600 movies (last Wuthering Heights)
# Indexed 18700 movies (last Gabriel Over the White House)
# Indexed 18800 movies (last Friendship!)
# Indexed 18900 movies (last Mía)
# Indexed 19000 movies (last Danger! 50,000 Zombies)
# Indexed 19100 movies (last Top Dog)
# Indexed 19200 movies (last Reaching for the Moon)
# Indexed 19300 movies (last A Child's Christmas in Wales)
# Indexed 19400 movies (last The Dog Who Stopped the War)
# Indexed 19500 movies (last Police Python 357)
# Indexed 19600 movies (last Accidents Happen)
# Indexed 19700 movies (last Changing Times)
# Indexed 19800 movies (last The Ape)
# Indexed 19900 movies (last Heartbreak Hotel)
# Indexed 20000 movies (last Left Behind III: World at War)
# Indexed 20100 movies (last Dragon Ball Z: Lord Slug)
# Indexed 20200 movies (last The Adventures of Sherlock Holmes)
# Indexed 20300 movies (last Billy's Hollywood Screen Kiss)
# Indexed 20400 movies (last Short Night of Glass Dolls)
# Indexed 20500 movies (last Kawa)
# Indexed 20600 movies (last Bears)
# Indexed 20700 movies (last Pyrates)
# Indexed 20800 movies (last Bastard Out of Carolina)
# Indexed 20900 movies (last The Mole People)
# Indexed 21000 movies (last Till Human Voices Wake Us)
# Indexed 21100 movies (last It's a Wonderful Afterlife)
# Indexed 21200 movies (last The Bingo Long Traveling All-Stars & Motor Kings)
# Indexed 21300 movies (last Ciao! Manhattan)
# Indexed 21400 movies (last The Night They Raided Minsky's)
# Indexed 21500 movies (last The Girl Can't Help It)
# Indexed 21600 movies (last Sam Peckinpah's West: Legacy of a Hollywood Renegade)
# Indexed 21700 movies (last A Guy Named Joe)
# Indexed 21800 movies (last Odd Man Out)
# Indexed 21900 movies (last The Rise of Catherine the Great)
# Indexed 22000 movies (last The Girl of the Golden West)
# Indexed 22100 movies (last The Killing of John Lennon)
# Indexed 22200 movies (last Twist)
# Indexed 22300 movies (last After Life)
# Indexed 22400 movies (last The Great Ecstasy of Robert Carmichael)
# Indexed 22500 movies (last Do Not Disturb)
# Indexed 22600 movies (last Something Real and Good)
# Indexed 22700 movies (last CBGB)
# Indexed 22800 movies (last California Solo)
# Indexed 22900 movies (last Richard III)
# Indexed 23000 movies (last She's Out of Control)
# Indexed 23100 movies (last Dead End Drive-In)
# Indexed 23200 movies (last Venus Boyz)
# Indexed 23300 movies (last My Giant)
# Indexed 23400 movies (last The Beekeeper)
# Indexed 23500 movies (last The Bobo)
# Indexed 23600 movies (last Amen)
# Indexed 23700 movies (last Favela Rising)
# Indexed 23800 movies (last The 4th Floor)
# Indexed 23900 movies (last Chisum)
# Indexed 24000 movies (last Boulevard)
# Indexed 24100 movies (last Ingmar Bergman Makes a Movie)
# Indexed 24200 movies (last The Play House)
# Indexed 24300 movies (last Of Mice and Men)
# Indexed 24400 movies (last Dr. Gillespie's New Assistant)
# Indexed 24500 movies (last Rat)
# Indexed 24600 movies (last Unstrung Heroes)
# Indexed 24700 movies (last Crazy Sexy Cancer)
# Indexed 24800 movies (last High and Dizzy)
# Indexed 24900 movies (last The Murder of Fred Hampton)
# Indexed 25000 movies (last Holiday for Drumsticks)
# Indexed 25100 movies (last China Blue)
# Indexed 25200 movies (last Pancho, el perro millonario)
# Indexed 25300 movies (last The Diary of Anne Frank)
# Indexed 25400 movies (last To Be Twenty)
# Indexed 25500 movies (last Empire of Silver)
# Indexed 25600 movies (last Knockout)
# Indexed 25700 movies (last Speed & Angels)
# Indexed 25800 movies (last Meek's Cutoff)
# Indexed 25900 movies (last Sharpe's Sword)
# Indexed 26000 movies (last May 18)
# Indexed 26100 movies (last Dealer)
# Indexed 26200 movies (last Carmen Miranda: Bananas Is My Business)
# Indexed 26300 movies (last Il figlio dello sceicco)
# Indexed 26400 movies (last Muddy River)
# Indexed 26500 movies (last Judy Moody and the Not Bummer Summer)
# Indexed 26600 movies (last The Naughty Room)
# Indexed 26700 movies (last Time Without Pity)
# Indexed 26800 movies (last L'outremangeur)
# Indexed 26900 movies (last Buddha Collapsed Out of Shame)
# Indexed 27000 movies (last Uno contro l'altro praticamente amici)
# Indexed 27100 movies (last The Talent Given Us)
# Indexed 27200 movies (last Paris Trout)
# Indexed 27300 movies (last The Crystal Ball)
# Indexed 27400 movies (last West Is West)
# Indexed 27500 movies (last Breaktime)
# Indexed 27600 movies (last Two for the Seesaw)
# Indexed 27700 movies (last Fingers at the Window)
# Streaming Bulk index DONE tmdb [Status: 201]
# Done

# %% [markdown]
# ###  Feature Sets in ipynb
#
# You played with creating a feature set in the last lab, see the same process repeated here.
#
# Learning to rank requires creating feature set. Each feature has a name like `title_bm25` and as part of a list an ordinal `title_bm25` is the 0th item. Confusingly, Ranklib uses 1-based feature numbering, so feature 0 in this list corresponds to feature 1 in Ranklib training file, that we'll see soon.
#
# Notice also:
#
# - Each feature is a templated query with `{{keywords}}` parameter, that is passed at query time
# - We've added a `validation` block, which will run these queries with the specified parameters and index and return any query errors

# %%
config = {
    "featureset": {
        "features": [
            {
                "name": "title_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {
                        "title": "{{keywords}}"
                    } 
                }
            },
            {
                "name": "text_all_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {
                        "text_all": "{{keywords}}"
                    } 
                }
            },
            {
                "name": "text_std_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {
                        "text_std": "{{keywords}}"
                    } 
                }
            },
            {
                "name": "release_year",
                "params": [],
                "template": {
                    "function_score": {
                        "field_value_factor": {
                            "field": "release_year",
                            "missing": 2000
                        },
                        "query": { "match_all": {} }
                    }
                }
            }
        ]
    },
    "validation": {
              "index": "tmdb",
              "params": {
                  "keywords": "rambo"
              }
    
           }
}


from ltr import setup
setup(client, config=config, featureset='genome')
# Out:
# Removed Default LTR feature store [Status: 200]
# Initialize Default LTR feature store [Status: 200]
# Create genome feature set [Status: 201]

# %% [markdown]
# ### Logging Queries
#
# Logging is one of the more complex operations from an engineering perspective.
#
# The same query you ran manually when reviewing the slides is rerun here for every query in the source judgment list `judgmentInFile` with some batching when needed.

# %%
from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client,
                                        judgmentInFile='data/genome_judgments.txt', 
                                        trainingOutFile='data/genome_judgments_train.txt', 
                                        featureSet='genome')
# Out:
# Recognizing 1128 queries...
# Parsing QID 100
# Parsing QID 200
# Parsing QID 300
# Parsing QID 400
# Parsing QID 500
# Parsing QID 600
# Parsing QID 700
# Parsing QID 800
# Parsing QID 900
# Parsing QID 1000
# Parsing QID 1100
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 007 (0/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 007 (series) (1/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 18th century (2/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1920s (3/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1930s (4/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1950s (5/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1960s (6/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1970s (7/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 1980s (8/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 19th century (9/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 3d (10/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 70mm (11/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 80s (12/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for 9/11 (13/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aardman (14/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aardman studios (15/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for abortion (16/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for absurd (17/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for action (18/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for action packed (19/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adaptation (20/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adapted from:book (21/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adapted from:comic (22/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adapted from:game (23/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for addiction (24/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adolescence (25/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adoption (26/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adultery (27/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for adventure (28/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for affectionate (29/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for afi 100 (30/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for afi 100 (laughs) (31/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for afi 100 (movie quotes) (32/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for africa (33/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for afterlife (34/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aging (35/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aids (36/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for airplane (37/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for airport (38/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alaska (39/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alcatraz (40/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alcoholism (41/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alien (42/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alien invasion (43/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aliens (44/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for allegory (45/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for almodovar (46/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alone in the world (47/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alter ego (48/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alternate endings (49/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alternate history (50/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alternate reality (51/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for alternate universe (52/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for amazing cinematography (53/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for amazing photography (54/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for american civil war (55/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for amnesia (56/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for amy smart (57/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for android(s)/cyborg(s) (58/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for androids (59/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for animal movie (60/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for animals (61/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for animated (62/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for animation (63/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for anime (64/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for antarctica (65/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for anti-hero (66/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for anti-semitism (67/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for anti-war (68/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for apocalypse (69/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for archaeology (70/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for argentina (71/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for arms dealer (72/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for arnold (73/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for art (74/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for art house (75/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for artificial intelligence (76/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for artist (77/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for artistic (78/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for artsy (79/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for assassin (80/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for assassination (81/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for assassins (82/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for astronauts (83/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for atheism (84/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for atmospheric (85/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for australia (86/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for australian (87/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for author:alan moore (88/1128)
# Duplicate Doc in qid:90 105045
# Duplicate Doc in qid:90 105045
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for author:neil gaiman (89/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for autism (90/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for aviation (91/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for awesome (92/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for awesome soundtrack (93/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for awful (94/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad (95/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad acting (96/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad cgi (97/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad ending (98/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad plot (99/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad science (100/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad script (101/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bad sequel (102/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for ballet (103/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bank robbery (104/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for baseball (105/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a book (106/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a comic (107/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a play (108/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a true story (109/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a tv show (110/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on a video game (111/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on book (112/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on comic (113/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for based on true story (114/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for basketball (115/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for batman (116/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bdsm (117/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beatles (118/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beautiful (119/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beautiful scenery (120/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beautifully filmed (121/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beauty pageant (122/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for beer (123/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for berlin (124/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for best of 2005 (125/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for best war films (126/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for betrayal (127/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for better than expected (128/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for better than the american version (129/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for biblical (130/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for big budget (131/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for biographical (132/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for biography (133/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for biopic (134/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for birds (135/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for biting (136/1128)
# Duplicate Doc in qid:138 105045
# Duplicate Doc in qid:138 105045
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bittersweet (137/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bizarre (138/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for black and white (139/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for black comedy (140/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for blaxploitation (141/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bleak (142/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for blindness (143/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for blood (144/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bloody (145/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boarding school (146/1128)
# Duplicate Doc in qid:148 105045
# Duplicate Doc in qid:148 105045
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boat (147/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bollywood (148/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bombs (149/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bond (150/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for book (151/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for book was better (152/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for books (153/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boring (154/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boring! (155/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boston (156/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bowling (157/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for boxing (158/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brainwashing (159/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brazil (160/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for breathtaking (161/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brilliant (162/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for british (163/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for british comedy (164/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for broadway (165/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brothers (166/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brutal (167/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for brutality (168/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for buddy movie (169/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bullshit history (170/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for bullying (171/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for business (172/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for c.s. lewis (173/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for california (174/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for camp (175/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for campy (176/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for canada (177/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cancer (178/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cannibalism (179/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for caper (180/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for capitalism (181/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for car chase (182/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for carrie-anne moss (183/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cars (184/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cartoon (185/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for casino (186/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for catastrophe (187/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cathartic (188/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for catholicism (189/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for censorship (190/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cerebral (191/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cgi (192/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for character study (193/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chase (194/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cheating (195/1128)
# Duplicate Doc in qid:197 105045
# Duplicate Doc in qid:197 105045
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cheerleading (196/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cheesy (197/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chess (198/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chicago (199/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chick flick (200/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for child abuse (201/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for childhood (202/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for children (203/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for china (204/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chocolate (205/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for chris tucker (206/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for christian (207/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for christianity (208/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for christmas (209/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cia (210/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cinematography (211/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for circus (212/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for civil war (213/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for classic (214/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for classic car (215/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for classical music (216/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for claustrophobic (217/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for claymation (218/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for clever (219/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for clones (220/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cloning (221/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for clowns (222/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for coen bros (223/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for coen brothers (224/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for cold war (225/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for college (226/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for colonialism (227/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for colourful (228/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for comedy (229/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for comic (230/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for comic book (231/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for comic book adaption (232/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for comics (233/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# ...
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for twist ending (1049/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for twists & turns (1050/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for undercover cop (1051/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for underdog (1052/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for underrated (1053/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for understated (1054/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for underwater (1055/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unfunny (1056/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unintentionally funny (1057/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unique (1058/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for united nations (1059/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unlikeable characters (1060/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unlikely friendships (1061/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unrealistic (1062/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for unusual plot structure (1063/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for us history (1064/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for utopia (1065/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vampire (1066/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vampire human love (1067/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vampires (1068/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vengeance (1069/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for very funny (1070/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for very good (1071/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for very interesting (1072/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for video game (1073/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for video game adaptation (1074/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for video games (1075/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for videogame (1076/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vienna (1077/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vietnam (1078/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vietnam war (1079/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for view askew (1080/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vigilante (1081/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for vigilantism (1082/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for violence (1083/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for violent (1084/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for virginity (1085/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for virtual reality (1086/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for virus (1087/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for visceral (1088/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for visual (1089/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for visually appealing (1090/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for visually stunning (1091/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for visuals (1092/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for voodoo (1093/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for voyeurism (1094/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for war (1095/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for war movie (1096/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wartime (1097/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for waste of time (1098/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for watch the credits (1099/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for weapons (1100/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wedding (1101/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for weed (1102/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for weird (1103/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for werewolf (1104/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for werewolves (1105/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for western (1106/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for whimsical (1107/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wilderness (1108/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wine (1109/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wistful (1110/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for witch (1111/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for witches (1112/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for witty (1113/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wizards (1114/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for women (1115/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for working class (1116/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for workplace (1117/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for world politics (1118/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for world war i (1119/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for world war ii (1120/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for writer's life (1121/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for writers (1122/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for writing (1123/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wuxia (1124/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for wwii (1125/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for zombie (1126/1128)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for zombies (1127/1128)
# Discarded 3070 Keep 1198092

# %% [markdown]
# ### Training
#
# Here's where we train the model, under the hood this executes Ranklib just as you ran during the training exercises.
#
# Notice here we're optimizing for NDCG@10

# %%
from ltr.train import train
trainLog = train(client,
                 trainingInFile='data/genome_judgments_train.txt',
                 metric2t='NDCG@10',
                 featureSet='genome',
                 modelName='genome')
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 10 -leaf 10 -train data/genome_judgments_train.txt -save data/genome_model.txt
# DONE
# Delete model genome: 404
# Created Model genome [Status: 201]

# %% [markdown]
# Now that training is done, we can output some statistics about the model, including the training metrics. In future units we'll get more into what this looks like.
#
# Notice the training NDCG isn't that great. When originally run, it was only 0.5885. So pretty far off of the genome data. One challenge of Learning to Rank (and Relevance in general) is trying to figure out the features that can close the gap.

# %%
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
print("trainLog Metric %s" % trainLog.metric())
# Out:
# Impact of each feature on the model
# 2 - 4152515.485482863
# 1 - 854906.8367087343
# 4 - 1.7066532720419414
# 3 - 1.1561805533583989
# trainLog Metric 0.5885

# %% [markdown]
# ### Search with our model
#
# Here we're going to search using the `genome` model. You can see the LTR query being output (sent to Elasticsearch). You're encouraged to run that directly against Elasticsearch if you like.
#
# Please note, this isn't rescoring. And that's fine for our purposes of directly evaluating the model, in real life you really should run a rescore query.

# %%
from ltr import search
search(client, "world war", modelName='genome')
# Out:
# {"size": 5, "query": {"sltr": {"params": {"keywords": "world war"}, "model": "genome"}}}
# Searching tmdb - {'size': 5, 'query': [Status: 200]
# World War Three
# 1.3450011
# 1998
# ['War', 'Documentary', 'History', 'Drama', 'TV Movie']
# This mock documentary uses archival footage, interviews and reports taken out of context and staged interviews to highlight a possible escalation into a nuclear war. In this feature, tension in East Germany, and an uprising triggered by a visit by Gorbachev sees a successful military coup taking place in the USSR. Western actions against brutal crack-downs on civilians involved increases tension between the sides, finally resulting in nuclear war.
# ---------------------------------------
# The Fourth World War
# 1.3450011
# 2003
# ['Documentary']
# From the front-lines of conflicts in Mexico, Argentina, South Africa, Palestine, Korea, 'the North' from Seattle to Genova, and the 'War on Terror' in New York, Afghanistan, and Iraq. It is the story of men and women around the world who resist being annihilated in this war. While our airwaves are crowded with talk of a new world war, narrated by generals and filmed from the noses of bombs, the human story of this global conflict remains untold. "The Fourth World War" brings together the images and voices of the war on the ground. It is a story of a war without end and of those who resist. The product of over two years of filming on the inside of movements on five continents, "The Fourth World War" is a film that would have been unimaginable at any other moment in history. Directed by the makers of "This Is What Democracy Looks Like" and "Zapatista", produced through a global network of independent media and activist groups, it is a truly global film from our global movement.
# ---------------------------------------
# The Counterfeiters
# 1.3421056
# 2007
# ['Drama', 'War']
# The story Jewish counterfeiter, Salomon Sorowitsch, coerced into assisting the Nazi operation of the Sachsenhausen concentration camp during World War II.
# ---------------------------------------
# The Notebook
# 1.3421056
# 2013
# ['Drama', 'War']
# In a village on the Hungarian border, two young brothers grow up during war time with their cruel grandmother and must learn every trick of evil to survive in the absurd world of adults.
# ---------------------------------------
# Blue Gold: World Water Wars
# 1.3421056
# 2008
# ['Documentary']
# Wars of the future will be fought over water as they are over oil today, as the source of human survival enters the global marketplace and political arena. Corporate giants, private investors, and corrupt governments vie for control of our dwindling supply, prompting protests, lawsuits, and revolutions from citizens fighting for the right to survive.
# ---------------------------------------
