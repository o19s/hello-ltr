# %% [markdown]
# # Elastic Client

# %%
from ltr.client import ElasticClient
client = ElasticClient()

# %% [markdown]
# # Download & Build Index (run once)
#
# If you don't already have the downloaded dependencies; if you don't have TheMovieDB data indexed run this

# %%
from ltr import download
download();

from ltr.index import rebuild_tmdb
rebuild_tmdb(client)

# %% [markdown]
# ## Features for movie titles
#
# We'll be searching movie titles (think searching for a specific movie on Netflix). And we have a set of judgments around the appropriatte movie to return. IE search for "Star Wars" return good star wars matches, in quality order...
#
# These cover various aspects of the problem (searching title by phrase, title bm25 score, release date, etc). We'll use this to explore and analyze a simple model

# %%
config = {"validation": {
              "index": "tmdb",
              "params": {
                  "keywords": "rambo"
              }
    
           },
           "featureset": {
            "features": [
            { #1
                "name": "title_has_phrase",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match_phrase": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
            { #2
                "name": "title_has_terms",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
            { #3
                "name": "title_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"title": "{{keywords}}"}
                }
            },
            { #4
                "name": "overview_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"overview": "{{keywords}}"}
                }
            },
            { #5
                "name": "overview_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {"overview": "{{keywords}}"}
                }
            },
            { #6
                "name": "title_fuzzy",
                "params": ["keywords"],
                "template": {
                    "match": {"title": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            },
             { #7
                "name": "release_year",
                "params": [],
                "template": {
                    "function_score": {
                        "field_value_factor": {
                            "field": "release_year",
                            "missing": 2000
                        },
                        "query": { "match_all": {} }
                    }
                }
            }
            
            
            ]
    }}




from ltr import setup
setup(client, config=config, index='tmdb', featureset='title')
# Out:
# Removed Default LTR feature store [Status: 200]
# Initialize Default LTR feature store [Status: 200]
# Create title feature set [Status: 201]

# %% [markdown]
# ## Training Set Generation
#
# Log out features for each of the above queries out to a training set file

# %%
from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title_judgments_train.txt', 
                                        featureSet='title')
# Out:
# Recognizing 40 queries...
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for rambo (0/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for rocky (1/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for war games (2/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for crocodile dundee (3/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for matrix (4/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for contact (5/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for space jam (6/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for battlestar galactica (7/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for her (8/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for jobs (9/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for social network (10/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for rocky horror (11/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for shawshank redemption (12/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for french connection (13/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for star wars new hope (14/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for lego batman (15/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for crouching tiger hidden dragon (16/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for fight club (17/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for die hard (18/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for last temptation of christ (19/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for tree of life (20/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for murray saves christmas (21/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for black swan (22/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for emma (23/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for mad max fury road (24/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for kung fury (25/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for mr smith goes to washington (26/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for kill bill (27/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for the godfather (28/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for pulp fiction (29/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for christmas vacation (30/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for psycho (31/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for life is beautiful (32/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for dark knight (33/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for the green mile (34/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for forrest gump (35/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for top gun (36/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for how to train your dragon (37/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for how to train your dragon 2 (38/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for star wars (39/40)
# Discarded 0 Keep 1390

# %% [markdown]
# ## Feature Search: which features work best?
#
# What combination of these features work best? Train a model with every combination, and use k-fold cross valudation (see `kcv=15` below). The combination with the best NDCG is output

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               features=[1,2,3,4,5,6,7],
                                               featureSet='title')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1] TEST NDCG@10=0.9071
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2] TEST NDCG@10=0.9067
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3] TEST NDCG@10=0.8754
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4] TEST NDCG@10=0.5022
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5] TEST NDCG@10=0.7247
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6] TEST NDCG@10=0.8084
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [7] TEST NDCG@10=0.2794
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2] TEST NDCG@10=0.9067
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3] TEST NDCG@10=0.8737
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4] TEST NDCG@10=0.8057
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5] TEST NDCG@10=0.8597
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 6] TEST NDCG@10=0.8654
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 7] TEST NDCG@10=0.7869
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3] TEST NDCG@10=0.8754
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4] TEST NDCG@10=0.5979
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5] TEST NDCG@10=0.8498
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 6] TEST NDCG@10=0.8061
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 7] TEST NDCG@10=0.5268
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4] TEST NDCG@10=0.8693
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 6] TEST NDCG@10=0.8959
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 7] TEST NDCG@10=0.8778
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5] TEST NDCG@10=0.4874
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 6] TEST NDCG@10=0.8286
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 7] TEST NDCG@10=0.4166
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 6] TEST NDCG@10=0.7694
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 7] TEST NDCG@10=0.3976
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6, 7] TEST NDCG@10=0.7877
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3] TEST NDCG@10=0.8737
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4] TEST NDCG@10=0.7967
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5] TEST NDCG@10=0.863
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 6] TEST NDCG@10=0.8779
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 7] TEST NDCG@10=0.7955
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4] TEST NDCG@10=0.9011
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 6] TEST NDCG@10=0.879
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 7] TEST NDCG@10=0.8756
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5] TEST NDCG@10=0.8321
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 6] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 7] TEST NDCG@10=0.8098
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5, 6] TEST NDCG@10=0.8777
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5, 7] TEST NDCG@10=0.7773
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 6, 7] TEST NDCG@10=0.8282
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4] TEST NDCG@10=0.8693
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 5] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 6] TEST NDCG@10=0.8959
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 7] TEST NDCG@10=0.8778
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 5] TEST NDCG@10=0.6083
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 6] TEST NDCG@10=0.8016
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 7] TEST NDCG@10=0.5786
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5, 6] TEST NDCG@10=0.8065
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5, 7] TEST NDCG@10=0.5996
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 6, 7] TEST NDCG@10=0.8102
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 5] TEST NDCG@10=0.854
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 6] TEST NDCG@10=0.889
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 7] TEST NDCG@10=0.8815
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5, 6] TEST NDCG@10=0.8813
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5, 7] TEST NDCG@10=0.8657
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 6, 7] TEST NDCG@10=0.8753
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5, 6] TEST NDCG@10=0.8144
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5, 7] TEST NDCG@10=0.3601
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 6, 7] TEST NDCG@10=0.8208
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 6, 7] TEST NDCG@10=0.798
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4] TEST NDCG@10=0.9011
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 5] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 6] TEST NDCG@10=0.879
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 7] TEST NDCG@10=0.8756
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 5] TEST NDCG@10=0.8296
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 6] TEST NDCG@10=0.8822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 7] TEST NDCG@10=0.8054
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5, 6] TEST NDCG@10=0.8838
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5, 7] TEST NDCG@10=0.7935
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 6, 7] TEST NDCG@10=0.8447
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5] TEST NDCG@10=0.907
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 6] TEST NDCG@10=0.9022
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 7] TEST NDCG@10=0.9119
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5, 6] TEST NDCG@10=0.8876
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5, 7] TEST NDCG@10=0.8644
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 6, 7] TEST NDCG@10=0.8747
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5, 6] TEST NDCG@10=0.8826
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5, 7] TEST NDCG@10=0.8222
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 6, 7] TEST NDCG@10=0.8953
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5, 6, 7] TEST NDCG@10=0.8504
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5] TEST NDCG@10=0.854
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 6] TEST NDCG@10=0.889
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 7] TEST NDCG@10=0.8815
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 5, 6] TEST NDCG@10=0.8813
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 5, 7] TEST NDCG@10=0.8657
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 6, 7] TEST NDCG@10=0.8753
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 5, 6] TEST NDCG@10=0.7876
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 5, 7] TEST NDCG@10=0.6095
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 6, 7] TEST NDCG@10=0.8212
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5, 6, 7] TEST NDCG@10=0.8167
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 5, 6] TEST NDCG@10=0.8849
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 5, 7] TEST NDCG@10=0.8877
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 6, 7] TEST NDCG@10=0.8605
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5, 6, 7] TEST NDCG@10=0.8503
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5, 6, 7] TEST NDCG@10=0.7956
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5] TEST NDCG@10=0.907
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 6] TEST NDCG@10=0.9022
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 7] TEST NDCG@10=0.9119
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 5, 6] TEST NDCG@10=0.8876
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 5, 7] TEST NDCG@10=0.8644
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 6, 7] TEST NDCG@10=0.8747
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 5, 6] TEST NDCG@10=0.8828
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 5, 7] TEST NDCG@10=0.815
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 6, 7] TEST NDCG@10=0.8953
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5, 6, 7] TEST NDCG@10=0.8493
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5, 6] TEST NDCG@10=0.8978
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5, 7] TEST NDCG@10=0.906
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 6, 7] TEST NDCG@10=0.8951
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5, 6, 7] TEST NDCG@10=0.8709
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5, 6, 7] TEST NDCG@10=0.8837
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 6] TEST NDCG@10=0.8849
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 7] TEST NDCG@10=0.8877
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 6, 7] TEST NDCG@10=0.8605
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 5, 6, 7] TEST NDCG@10=0.8503
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 5, 6, 7] TEST NDCG@10=0.8083
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 5, 6, 7] TEST NDCG@10=0.8659
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 6] TEST NDCG@10=0.8978
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 7] TEST NDCG@10=0.906
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 6, 7] TEST NDCG@10=0.8951
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 5, 6, 7] TEST NDCG@10=0.8709
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 5, 6, 7] TEST NDCG@10=0.8837
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5, 6, 7] TEST NDCG@10=0.9004
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 6, 7] TEST NDCG@10=0.8659
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 6, 7] TEST NDCG@10=0.9004
#
# Impact of each feature on the model
# 3 - 17728.651362443747
# 4 - 10986.88505569509
# 7 - 7504.573843344015
# 1 - 1580.321225819952
# 0.9088
# 0.9187
# 0.9198
# 0.9198
# 0.9198
# 0.9198
# 0.9204
# 0.9204
# 0.9204
# 0.9286
# 0.9294
# 0.9291
# 0.9293
# 0.9337
# 0.9317
# 0.9317
# 0.9317
# 0.934
# 0.9331
# 0.9333
# Avg NDCG@10 when feature included:
# 1 => 0.8692281249999998
# 2 => 0.8369812499999998
# 3 => 0.882071875
# 4 => 0.8229937499999999
# 5 => 0.8249453125
# 6 => 0.8604359374999998
# 7 => 0.8076609374999998
# Avg K-Fold NDCG@10 0.9119

# %% [markdown]
# ## Compare to model w/ all features
#
# Compare the features output above (something like...)
#
# ```
# Impact of each feature on the model
# 3 - 17728.651362443747
# 4 - 10986.88505569509
# 7 - 7504.573843344015
# 1 - 1580.321225819952
# ```
#
# to one trained with the full model. Notice how features have different impacts. This is due to feature dependency

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=20,
                  trees=20,
                  features=[1,2,3,4,5,6,7],
                  index='tmdb',
                  featureSet='title',
                  modelName='title')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 20 -bag 1 -leaf 20 -train data/title_judgments_train.txt -save data/title_model.txt  -feature features.txt
# DONE
# Delete model title: 404
# Created Model title [Status: 201]
#
# Impact of each feature on the model
# 6 - 18766.11246284367
# 3 - 14740.291519685004
# 4 - 10002.493638661677
# 7 - 6315.7831389888
# 5 - 2898.441699180107
# 1 - 2059.7002349446443
# 2 - 0.009750295980646107
# 0.9129
# 0.9159
# 0.917
# 0.9198
# 0.9198
# 0.9227
# 0.926
# 0.926
# 0.926
# 0.9259
# 0.9316
# 0.9348
# 0.934
# 0.9338
# 0.9349
# 0.9349
# 0.9346
# 0.9392
# 0.9392
# 0.9394
# Train NDCG@10 0.9394

# %% [markdown]
# ## Bias towards fewer features
#
# By adding a 'cost', to feature search, we add a multiplier that punishes models with more features slightly. This results in a tiny bias towards simpler models all things being equal. As we'd prefer one that doesn't need to execute more features

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               featureCost=0.02,# 1.0-cost ^ num_features
                                               features=[1,2,3,4,5,6,7],
                                               featureSet='title')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)

# %% [markdown]
# # Evaluating the Model
#
# It's interesting to see what features our model makes use of, but we need guidance on adding additional features to the model. We know our model is an ensemble of decision trees. Wouldn't it be cool if we could trace where documents end up on that decision tree?
#
# Specifically, we care about problems. Or what we will call affectionately *whoopsies*.
#
# As a 'whoopsie' example, consider the query "Rambo". if a '0' document like 'First Daughter' ranked the same or higher than a '4' document ("Rambo")., that's a problem. It's also an opportunity for improvement. We'd want to isolate that, see if it's indicative of a broader trend, and thus worth adding a feature for.
#
# Let's see a concrete example

# %%
from ltr.client import ElasticClient
from ltr.MART_model import eval_model
from ltr.judgments import judgments_from_file, judgments_by_qid

features, _ = client.feature_set(index='tmdb', name='title')

judgmentDict = judgments_by_qid(judgments_from_file(filename='data/title_judgments_train.txt'))


rambo=judgmentDict[1]
model = eval_model(modelName='title',
                       features=features,
                       judgments=rambo)

print()
print("## Evaluating graded docs for search keywords '%s'" % rambo[0].keywords)
print()
print(model)
# Out:
# Fetched FeatureSet title [Status: 200]
# Recognizing 40 queries...
# Whoopsies on LAMBDAMart
# Header At 6
#
# ## Evaluating graded docs for search keywords 'rambo'
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if overview_phrase_bm25 > 8.602512:
#       if release_year > 2014.0:
#         <= 0.2000(0/0/)
#       else:
#         if overview_phrase_bm25 > 12.821155:
#           <= 0.1887(0/0/)
#         else:
#           <= 0.2000(1/0/)
#     else:
#       if overview_bm25 > 0.0:
#         if title_fuzzy > 11.085816:
#           if title_bm25 > 11.56597:
#             if title_bm25 > 17.490662:
#               <= 0.2000(0/0/)
#             else:
#               if overview_bm25 > 8.614496:
#                 <= 0.1995(0/0/)
#               else:
#                 <= 0.2000(0/0/)
#           else:
#             <= -0.2000(0/0/)
#         else:
#           <= 0.2000(0/0/)
#       else:
#         if title_bm25 > 13.815164:
#           if title_fuzzy > 13.919787:
#             <= 0.1989(0/0/)
#           else:
#             <= 0.2000(0/0/)
#         else:
#           if title_bm25 > 10.667803:
#             <= 0.1917(0/0/)
#           else:
#             <= 0.2000(0/0/)
#   else:
#     <= 0.1373(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 9.502127:
#       if title_fuzzy > 9.835535:
#         <= 0.1952(0/0/)
#       else:
#         <= 0.2000(0/0/)
#     else:
#       if title_fuzzy > 7.0849166:
#         if title_fuzzy > 8.251845:
#           <= 0.1568(1/0/)
#         else:
#           if title_fuzzy > 8.085141:
#             <= 0.2000(0/0/)
#           else:
#             <= 0.1907(0/0/)
#       else:
#         <= 0.0236(1/0/)
#   else:
#     <= -0.1831(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 13.815164:
#       if title_fuzzy > 14.336548:
#         if title_bm25 > 17.879606:
#           if overview_bm25 > 5.8678446:
#             <= 0.1688(0/0/)
#           else:
#             <= 0.1688(0/0/)
#         else:
#           <= 0.1649(0/0/)
#       else:
#         <= 0.1682(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if title_fuzzy > 9.668831:
#           if release_year > 1996.0:
#             if release_year > 1997.0:
#               if title_fuzzy > 10.919112:
#                 if overview_phrase_bm25 > 13.891626:
#                   <= 0.1258(0/0/)
#                 else:
#                   <= 0.1683(1/0/)
#               else:
#                 <= 0.1564(0/0/)
#             else:
#               <= 0.1685(0/0/)
#           else:
#             <= 0.1637(0/0/)
#         else:
#           <= 0.1683(0/0/)
#       else:
#         <= 0.1703(0/0/)
#   else:
#     <= 0.1313(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 9.502127:
#       if title_fuzzy > 9.835535:
#         <= 0.1632(0/0/)
#       else:
#         <= 0.1682(0/0/)
#     else:
#       if title_fuzzy > 7.0015645:
#         if title_fuzzy > 8.251845:
#           if overview_bm25 > 2.1224115:
#             <= 0.1520(1/0/)
#           else:
#             <= 0.0700(0/0/)
#         else:
#           if title_fuzzy > 8.085141:
#             <= 0.1766(0/0/)
#           else:
#             <= 0.1574(0/0/)
#       else:
#         <= -0.0031(1/0/)
#   else:
#     <= -0.1557(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1503(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1495(0/0/)
#         else:
#           if title_fuzzy > 8.668606:
#             <= 0.1463(1/0/)
#           else:
#             <= 0.1501(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1501(0/0/)
#           else:
#             <= -0.2182(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1430(0/0/)
#             else:
#               <= 0.1493(0/0/)
#           else:
#             if title_bm25 > 10.667803:
#               <= 0.1429(0/0/)
#             else:
#               <= 0.1519(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1552(0/0/)
#     else:
#       <= 0.1022(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 9.502127:
#       if title_fuzzy > 9.835535:
#         <= 0.1450(0/0/)
#       else:
#         <= 0.1493(0/0/)
#     else:
#       if title_bm25 > 8.093332:
#         if release_year > 1976.0:
#           if release_year > 2012.0:
#             if title_bm25 > 8.217656:
#               <= 0.1392(0/0/)
#             else:
#               <= 0.1607(0/0/)
#           else:
#             <= 0.1157(1/0/)
#         else:
#           <= 0.1535(0/0/)
#       else:
#         <= -0.0151(1/0/)
#   else:
#     <= -0.1375(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1383(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1373(0/0/)
#         else:
#           if title_fuzzy > 8.668606:
#             <= 0.1339(1/0/)
#           else:
#             <= 0.1381(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1380(0/0/)
#           else:
#             <= -0.2064(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1305(0/0/)
#             else:
#               <= 0.1370(0/0/)
#           else:
#             if title_bm25 > 10.667803:
#               <= 0.1305(0/0/)
#             else:
#               <= 0.1399(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1411(0/0/)
#     else:
#       <= 0.0836(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1321(1/0/)
#         else:
#           <= 0.1396(0/0/)
#       else:
#         <= 0.1046(0/0/)
#     else:
#       <= -0.0569(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if release_year > 2012.0:
#         if title_fuzzy > 8.085141:
#           <= 0.1484(0/0/)
#         else:
#           <= 0.1142(0/0/)
#       else:
#         <= 0.0162(1/0/)
#     else:
#       <= -0.1258(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1300(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1288(0/0/)
#         else:
#           if title_fuzzy > 8.668606:
#             <= 0.1250(1/0/)
#           else:
#             <= 0.1299(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1296(0/0/)
#           else:
#             <= -0.1979(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1216(0/0/)
#             else:
#               <= 0.1285(0/0/)
#           else:
#             <= 0.1244(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1317(0/0/)
#     else:
#       <= 0.0731(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1221(1/0/)
#         else:
#           <= 0.1308(0/0/)
#       else:
#         <= 0.0934(0/0/)
#     else:
#       <= -0.0030(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if release_year > 2012.0:
#         if title_fuzzy > 8.085141:
#           if release_year > 2013.0:
#             <= 0.1279(0/0/)
#           else:
#             <= 0.1420(0/0/)
#         else:
#           <= 0.1060(0/0/)
#       else:
#         <= 0.0123(1/0/)
#     else:
#       <= -0.1170(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1242(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1226(0/0/)
#         else:
#           <= 0.1194(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1236(0/0/)
#           else:
#             <= -0.1905(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1148(0/0/)
#             else:
#               <= 0.1223(0/0/)
#           else:
#             <= 0.1177(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1249(0/0/)
#     else:
#       <= 0.0641(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1147(1/0/)
#         else:
#           <= 0.1248(0/0/)
#       else:
#         <= 0.0844(0/0/)
#     else:
#       <= -0.0010(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if release_year > 2012.0:
#         if title_fuzzy > 8.085141:
#           if title_fuzzy > 8.251845:
#             <= 0.1209(0/0/)
#           else:
#             <= 0.1363(0/0/)
#         else:
#           <= 0.0964(0/0/)
#       else:
#         <= 0.0099(1/0/)
#     else:
#       if overview_bm25 > 10.612055:
#         <= 0.0492(1/0/)
#       else:
#         <= -0.1155(37/1/qid:1:0(319074)-2(13258))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1199(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1180(0/0/)
#         else:
#           <= 0.1144(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1190(0/0/)
#           else:
#             <= -0.1269(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1093(0/0/)
#             else:
#               <= 0.1176(0/0/)
#           else:
#             <= 0.1125(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1199(0/0/)
#     else:
#       <= 0.0564(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1088(1/0/)
#         else:
#           <= 0.1204(0/0/)
#       else:
#         <= 0.0763(0/0/)
#     else:
#       <= 0.0005(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if release_year > 2012.0:
#         if title_fuzzy > 8.085141:
#           if title_bm25 > 8.217656:
#             <= 0.1153(0/0/)
#           else:
#             <= 0.1319(0/0/)
#         else:
#           <= 0.0883(0/0/)
#       else:
#         <= 0.0078(1/0/)
#     else:
#       if overview_bm25 > 11.111444:
#         <= 0.0794(1/0/)
#       else:
#         <= -0.1101(37/1/qid:1:0(319074)-2(13258))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1167(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1145(0/0/)
#         else:
#           <= 0.1103(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1156(0/0/)
#           else:
#             <= -0.1235(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1047(0/0/)
#             else:
#               <= 0.1141(0/0/)
#           else:
#             <= 0.1093(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1161(0/0/)
#     else:
#       <= 0.0493(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1072(1/0/)
#         else:
#           <= 0.1172(0/0/)
#       else:
#         <= 0.0690(0/0/)
#     else:
#       <= 0.0015(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if title_bm25 > 8.093332:
#         if release_year > 2010.0:
#           if title_bm25 > 8.217656:
#             <= 0.0812(0/0/)
#           else:
#             <= 0.1282(0/0/)
#         else:
#           <= 0.0754(0/0/)
#       else:
#         <= -0.0393(1/0/)
#     else:
#       if overview_bm25 > 11.111444:
#         <= 0.0678(1/0/)
#       else:
#         <= -0.1053(37/1/qid:1:0(319074)-2(13258))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1144(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         if release_year > 2014.0:
#           <= 0.1119(0/0/)
#         else:
#           <= 0.1070(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           if release_year > 1965.0:
#             <= 0.1131(0/0/)
#           else:
#             <= -0.1193(0/0/)
#         else:
#           if title_bm25 > 13.815164:
#             if title_fuzzy > 13.919787:
#               <= 0.1006(0/0/)
#             else:
#               <= 0.1113(0/0/)
#           else:
#             <= 0.1056(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1133(0/0/)
#     else:
#       <= 0.0430(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.1029(1/0/)
#         else:
#           <= 0.1145(0/0/)
#       else:
#         <= 0.0620(0/0/)
#     else:
#       <= -0.0126(0/0/)
#   else:
#     if title_has_phrase > 0.0:
#       if release_year > 2012.0:
#         if title_fuzzy > 8.085141:
#           if title_fuzzy > 8.251845:
#             <= 0.0620(0/0/)
#           else:
#             <= 0.1240(0/0/)
#         else:
#           <= 0.0738(0/0/)
#       else:
#         <= 0.0031(1/0/)
#     else:
#       if overview_bm25 > 11.111444:
#         <= 0.0626(1/0/)
#       else:
#         <= -0.1008(37/1/qid:1:0(319074)-2(13258))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1127(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if release_year > 1999.0:
#           if title_fuzzy > 13.753083:
#             <= 0.0766(0/0/)
#           else:
#             <= 0.1035(1/0/)
#         else:
#           if release_year > 1996.0:
#             <= 0.1103(0/0/)
#           else:
#             if title_bm25 > 11.171097:
#               if release_year > 1965.0:
#                 <= 0.1110(0/0/)
#               else:
#                 <= 0.0952(0/0/)
#             else:
#               <= 0.0991(0/0/)
#       else:
#         <= 0.1150(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1111(0/0/)
#     else:
#       <= 0.0374(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if overview_bm25 > 4.494518:
#         if overview_phrase_bm25 > 4.581127:
#           <= 0.0989(1/0/)
#         else:
#           <= 0.1127(0/0/)
#       else:
#         <= 0.0557(0/0/)
#     else:
#       <= -0.0098(0/0/)
#   else:
#     if title_bm25 > 8.086992:
#       if title_has_phrase > 0.0:
#         if release_year > 2010.0:
#           if title_bm25 > 8.217656:
#             <= 0.0693(0/0/)
#           else:
#             <= 0.1215(0/0/)
#         else:
#           <= 0.0646(0/0/)
#       else:
#         <= -0.0553(0/0/)
#     else:
#       if overview_bm25 > 10.612055:
#         <= 0.0470(2/1/qid:1:3(1369)-4(1368))
#       else:
#         <= -0.0947(37/1/qid:1:0(319074)-2(13258))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1114(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if release_year > 1999.0:
#           if title_bm25 > 15.244253:
#             <= 0.0715(0/0/)
#           else:
#             if title_fuzzy > 10.919112:
#               <= 0.1060(1/0/)
#             else:
#               <= 0.0697(0/0/)
#         else:
#           if release_year > 1996.0:
#             <= 0.1089(0/0/)
#           else:
#             if title_bm25 > 13.815164:
#               <= 0.1093(0/0/)
#             else:
#               if title_fuzzy > 9.668831:
#                 <= 0.0975(0/0/)
#               else:
#                 <= 0.1076(0/0/)
#       else:
#         <= 0.1134(0/0/)
#   else:
#     if release_year > 2010.0:
#       <= 0.1094(0/0/)
#     else:
#       <= 0.0330(0/0/)
# else:
#   if title_bm25 > 8.086992:
#     if title_has_phrase > 0.0:
#       if title_fuzzy > 9.502127:
#         <= 0.1038(0/0/)
#       else:
#         if release_year > 1976.0:
#           if release_year > 2012.0:
#             if title_bm25 > 8.217656:
#               <= 0.0768(0/0/)
#             else:
#               <= 0.1174(0/0/)
#           else:
#             <= 0.0609(1/0/)
#         else:
#           <= 0.1151(0/0/)
#     else:
#       <= -0.0029(0/0/)
#   else:
#     if overview_bm25 > 11.111444:
#       <= 0.0453(2/1/qid:1:3(1369)-4(1368))
#     else:
#       if overview_bm25 > 3.6205833:
#         <= -0.0681(3/1/qid:1:1(31362)-2(13258))
#       else:
#         <= -0.1017(34/1/qid:1:0(319074)-1(208982))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1105(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if release_year > 1999.0:
#           <= 0.0931(1/0/)
#         else:
#           if release_year > 1996.0:
#             <= 0.1077(0/0/)
#           else:
#             if title_bm25 > 11.171097:
#               <= 0.1051(0/0/)
#             else:
#               <= 0.0928(0/0/)
#       else:
#         <= 0.1122(0/0/)
#   else:
#     <= 0.0469(0/0/)
# else:
#   if title_bm25 > 9.000727:
#     if title_has_phrase > 0.0:
#       if release_year > 2003.0:
#         <= 0.0624(0/0/)
#       else:
#         <= 0.1047(1/0/)
#     else:
#       <= -0.0053(0/0/)
#   else:
#     if title_bm25 > 8.086992:
#       if title_bm25 > 8.395502:
#         <= -0.0321(0/0/)
#       else:
#         if overview_bm25 > 4.119974:
#           <= 0.0620(0/0/)
#         else:
#           <= 0.1064(0/0/)
#     else:
#       if overview_bm25 > 5.243605:
#         if release_year > 1988.0:
#           <= -0.0554(1/0/)
#         else:
#           if release_year > 1981.0:
#             if title_has_terms > 0.0:
#               <= -0.0030(1/0/)
#             else:
#               if overview_bm25 > 6.1175404:
#                 <= 0.0872(2/1/qid:1:1(31362)-4(1368))
#               else:
#                 if overview_bm25 > 5.9926925:
#                   <= 0.2139(0/0/)
#                 else:
#                   <= 0.0184(0/0/)
#           else:
#             <= -0.0663(0/0/)
#       else:
#         <= -0.0993(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.664251:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1098(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if title_fuzzy > 9.668831:
#           if title_fuzzy > 11.002464:
#             if title_fuzzy > 11.085816:
#               if title_fuzzy > 13.919787:
#                 <= 0.0919(0/0/)
#               else:
#                 <= 0.1030(1/0/)
#             else:
#               <= 0.1075(0/0/)
#           else:
#             <= 0.0865(0/0/)
#         else:
#           <= 0.1077(0/0/)
#       else:
#         <= 0.1107(0/0/)
#   else:
#     <= 0.0421(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 7.069654:
#       if title_fuzzy > 9.502127:
#         <= 0.0987(0/0/)
#       else:
#         if title_bm25 > 9.639984:
#           <= 0.1111(0/0/)
#         else:
#           if release_year > 2010.0:
#             <= 0.0910(0/0/)
#           else:
#             <= 0.0494(1/0/)
#     else:
#       <= -0.0729(1/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if overview_bm25 > 13.608393:
#         <= 0.0827(0/0/)
#       else:
#         if release_year > 1988.0:
#           <= -0.0491(1/0/)
#         else:
#           if release_year > 1981.0:
#             if overview_bm25 > 6.1175404:
#               <= 0.0642(2/1/qid:1:1(31362)-4(1368))
#             else:
#               if overview_bm25 > 5.9926925:
#                 <= 0.1794(0/0/)
#               else:
#                 <= 0.0359(0/0/)
#           else:
#             <= -0.0878(0/0/)
#     else:
#       <= -0.1012(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1094(0/0/)
#     else:
#       if release_year > 1999.0:
#         <= 0.0868(1/0/)
#       else:
#         if release_year > 1996.0:
#           <= 0.1078(0/0/)
#         else:
#           if overview_phrase_bm25 > 0.0:
#             <= 0.0813(0/0/)
#           else:
#             <= 0.1047(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1072(0/0/)
#     else:
#       <= 0.0238(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 7.069654:
#       if title_bm25 > 9.639984:
#         <= 0.0941(0/0/)
#       else:
#         if title_fuzzy > 9.502127:
#           <= 0.0970(0/0/)
#         else:
#           if release_year > 2010.0:
#             if overview_phrase_bm25 > 4.4724007:
#               <= 0.1150(0/0/)
#             else:
#               if title_bm25 > 8.217656:
#                 <= -0.0323(0/0/)
#               else:
#                 <= 0.1008(0/0/)
#           else:
#             <= 0.0441(1/0/)
#     else:
#       <= -0.0743(1/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0352(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.1175404:
#             <= 0.0585(2/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1626(0/0/)
#             else:
#               <= 0.0310(0/0/)
#         else:
#           <= -0.0832(0/0/)
#     else:
#       <= -0.0984(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1090(0/0/)
#     else:
#       if release_year > 1999.0:
#         <= 0.0835(1/0/)
#       else:
#         if release_year > 1996.0:
#           <= 0.1073(0/0/)
#         else:
#           if overview_phrase_bm25 > 0.0:
#             <= 0.0775(0/0/)
#           else:
#             if title_fuzzy > 9.668831:
#               <= 0.1037(0/0/)
#             else:
#               <= 0.1040(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1065(0/0/)
#     else:
#       if release_year > 1988.0:
#         <= -0.0489(0/0/)
#       else:
#         <= 0.0534(0/0/)
# else:
#   if title_bm25 > 8.086992:
#     if title_has_phrase > 0.0:
#       if title_bm25 > 9.639984:
#         <= 0.0916(0/0/)
#       else:
#         if title_bm25 > 8.395502:
#           <= 0.0387(1/0/)
#         else:
#           <= 0.0854(0/0/)
#     else:
#       <= -0.0036(0/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0435(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.2423882:
#             <= 0.0665(3/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1510(0/0/)
#             else:
#               <= 0.0411(0/0/)
#         else:
#           <= -0.0775(0/0/)
#     else:
#       if title_bm25 > 6.958411:
#         <= -0.0347(0/0/)
#       else:
#         <= -0.0990(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1087(0/0/)
#     else:
#       if release_year > 1999.0:
#         <= 0.0789(1/0/)
#       else:
#         if release_year > 1996.0:
#           <= 0.1069(0/0/)
#         else:
#           if overview_phrase_bm25 > 0.0:
#             <= 0.0754(0/0/)
#           else:
#             <= 0.1029(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1061(0/0/)
#     else:
#       if release_year > 1988.0:
#         <= -0.0651(0/0/)
#       else:
#         <= 0.0535(0/0/)
# else:
#   if title_bm25 > 8.086992:
#     if title_has_phrase > 0.0:
#       if title_bm25 > 9.639984:
#         <= 0.0886(0/0/)
#       else:
#         if title_bm25 > 8.395502:
#           if overview_bm25 > 4.494518:
#             <= 0.0729(1/0/)
#           else:
#             <= -0.0287(0/0/)
#         else:
#           <= 0.0823(0/0/)
#     else:
#       <= -0.0028(0/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0398(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.1175404:
#             <= 0.0603(3/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1378(0/0/)
#             else:
#               <= 0.0346(0/0/)
#         else:
#           <= -0.0723(0/0/)
#     else:
#       if title_bm25 > 6.958411:
#         <= -0.0298(0/0/)
#       else:
#         <= -0.0973(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 17.879606:
#       <= 0.1084(0/0/)
#     else:
#       if release_year > 1999.0:
#         <= 0.0754(1/0/)
#       else:
#         if release_year > 1996.0:
#           <= 0.1063(0/0/)
#         else:
#           if overview_phrase_bm25 > 0.0:
#             <= 0.0719(0/0/)
#           else:
#             <= 0.1020(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1058(0/0/)
#     else:
#       if release_year > 1988.0:
#         <= -0.0596(0/0/)
#       else:
#         <= 0.0494(0/0/)
# else:
#   if title_bm25 > 8.086992:
#     if title_has_phrase > 0.0:
#       if release_year > 1976.0:
#         if title_fuzzy > 9.585479:
#           <= 0.0801(0/0/)
#         else:
#           if title_bm25 > 8.395502:
#             <= 0.0103(1/0/)
#           else:
#             <= 0.0775(0/0/)
#       else:
#         <= 0.1123(0/0/)
#     else:
#       <= -0.0022(0/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0362(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.1175404:
#             <= 0.0539(3/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1319(0/0/)
#             else:
#               <= 0.0251(0/0/)
#         else:
#           <= -0.0662(0/0/)
#     else:
#       if title_bm25 > 6.958411:
#         <= -0.0269(0/0/)
#       else:
#         <= -0.0942(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 20.159218:
#       <= 0.1123(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         <= 0.0930(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1024(0/0/)
#         else:
#           if release_year > 2008.0:
#             <= -0.0612(0/0/)
#           else:
#             <= 0.1026(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1056(0/0/)
#     else:
#       <= 0.0128(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 7.069654:
#       if title_bm25 > 9.639984:
#         <= 0.0833(0/0/)
#       else:
#         if title_bm25 > 7.2790813:
#           if title_fuzzy > 9.502127:
#             <= 0.0897(0/0/)
#           else:
#             if release_year > 2010.0:
#               <= 0.0638(0/0/)
#             else:
#               <= 0.0138(1/0/)
#         else:
#           <= 0.1179(0/0/)
#     else:
#       <= -0.0659(1/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if overview_phrase_bm25 > 12.782484:
#         <= -0.2468(0/0/)
#       else:
#         if overview_bm25 > 11.111444:
#           <= 0.0586(1/0/)
#         else:
#           if overview_bm25 > 6.1175404:
#             <= -0.0383(2/1/qid:1:1(31362)-2(13258))
#           else:
#             if overview_bm25 > 5.9926925:
#               if release_year > 1983.0:
#                 <= -0.0930(0/0/)
#               else:
#                 <= 0.1276(0/0/)
#             else:
#               <= -0.0304(0/0/)
#     else:
#       <= -0.0871(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 20.159218:
#       <= 0.1116(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         <= 0.0893(1/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1016(0/0/)
#         else:
#           <= 0.0960(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1053(0/0/)
#     else:
#       if release_year > 1988.0:
#         <= -0.0586(0/0/)
#       else:
#         <= 0.0447(0/0/)
# else:
#   if title_bm25 > 8.093332:
#     if title_has_phrase > 0.0:
#       if release_year > 1978.0:
#         if overview_phrase_bm25 > 5.5572166:
#           <= 0.0028(1/0/)
#         else:
#           if overview_bm25 > 4.494518:
#             <= 0.1008(0/0/)
#           else:
#             <= 0.0290(0/0/)
#       else:
#         <= 0.1123(0/0/)
#     else:
#       <= 0.0020(0/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0320(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.1175404:
#             <= 0.0472(3/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1245(0/0/)
#             else:
#               <= 0.0211(0/0/)
#         else:
#           <= -0.0593(0/0/)
#     else:
#       if overview_phrase_bm25 > 3.7614212:
#         <= 0.0075(1/0/)
#       else:
#         if overview_phrase_bm25 > 1.3098165:
#           <= -0.1341(0/0/)
#         else:
#           <= -0.0817(34/1/qid:1:0(319074)-1(208982))
#
#
# if title_bm25 > 10.230932:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 20.159218:
#       <= 0.1111(0/0/)
#     else:
#       if overview_bm25 > 8.614496:
#         <= 0.0872(1/0/)
#       else:
#         if release_year > 1965.0:
#           if overview_bm25 > 0.0:
#             <= 0.1058(0/0/)
#           else:
#             <= 0.0934(0/0/)
#         else:
#           <= 0.0583(0/0/)
#   else:
#     if release_year > 2014.0:
#       <= 0.1051(0/0/)
#     else:
#       <= 0.0099(0/0/)
# else:
#   if title_bm25 > 8.093332:
#     if title_has_phrase > 0.0:
#       if release_year > 1978.0:
#         if overview_phrase_bm25 > 5.5572166:
#           <= -0.0059(1/0/)
#         else:
#           if overview_bm25 > 4.494518:
#             <= 0.1004(0/0/)
#           else:
#             <= 0.0247(0/0/)
#       else:
#         <= 0.1117(0/0/)
#     else:
#       <= 0.0016(0/0/)
#   else:
#     if overview_bm25 > 5.243605:
#       if release_year > 1988.0:
#         <= -0.0289(1/0/)
#       else:
#         if release_year > 1981.0:
#           if overview_bm25 > 6.1175404:
#             <= 0.0424(3/1/qid:1:1(31362)-4(1368))
#           else:
#             if overview_bm25 > 5.9926925:
#               <= 0.1224(0/0/)
#             else:
#               <= 0.0170(0/0/)
#         else:
#           <= -0.0547(0/0/)
#     else:
#       if title_bm25 > 6.930693:
#         <= -0.0257(0/0/)
#       else:
#         if title_fuzzy > 5.417875:
#           <= -0.1123(4/0/)
#         else:
#           <= -0.0768(31/1/qid:1:0(319074)-1(61410))

# %% [markdown]
# ## Examining our evaluation for whoopsies
#
# Let's looks at one tree in our ensemble, te see how it was evaluated.
#
# ```
# if title_bm25 > 10.664251:
#   if title_phrase > 0.0:
#     if title_bm25 > 13.815164:
#       if release_year > 2000.0:
#         <= 0.1215(0/0/)
#       else:
#         <= 0.1240(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if overview_bm25 > 0.0:
#           <= 0.1194(0/0/)
#         else:
#           <= 0.1161(1/0/)
#       else:
#         <= 0.1264(0/0/)
#   else:
#     <= 0.0800(0/0/)
# else:
#   if title_phrase > 0.0:
#     if title_bm25 > 8.115499:
#       if title_bm25 > 8.217656:
#         <= 0.1097(2/1/qid:40:2(12180)-3(140607))
#       else:
#         <= 0.1559(0/0/)
#     else:
#       <= -0.0021(2/1/qid:40:2(1895)-3(330459))
#   else:
#     <= -0.1093(25/1/qid:40:0(85783)-3(1892))
# ```
#
# You'll notice here this tree is represented by a series of if statements, where the feature's name is used. This is handy as it lets us take apart the structure of the tree.
#
# You'll also notice the leaf nodes starting with
#
# ```
# <=
# ```
#
# These leaf nodes have a floating point value, corresponding to the relevance score that documents ending up here will have. Each leaf also has three items in paranthesis, such as `(2/1/qid:40:2(1895)-3(330459))`. This is a report summarizing the result of evaluating the tree on the provided judgment list. Indicating:
#
#
# ```
#
#
#
#    +--- 2 Documents evaluated to this leaf node                   +-- max grade doc eval'd to this leaf
#    |                                                              |
#    | +----- 1 'whoopsie' occured                                  |  +-- corresp. doc id of max doc
#    | |                                                            |  |
#    | |   +--- details on each whoopsie ----------- qid:40:2(1985)-3(330459)
#    | |   |                                              | |  |
#   (2/1/qid:40:2(1895)-3(330459))                        | |  |
#                                                         | |  + doc id of min graded doc
#                                                         | |
#                                                         | + min grade of docs eval'd to this leaf
#                                                         |
#                                                         + query id of whoopsie from judgments
# ```
#
#
# Looking at Star Wars, our biggest issues in this tree are with the bottom-most leaf. Here
#
# ```
# if title_bm25 > 10.664251:
#   ...
# else:
#   if title_phrase > 0.0:
#     ...
#   else:
#     <= -0.1093(25/1/qid:40:0(85783)-3(1892))
# ```
#
#
# Document 85783 (a '0') and doc 1892 are given the same grade.

# %% [markdown]
# ### Whoopsie, from the query perspective
#
# Whoopsies can also be examined at the "query" level to see for a query id, how many whoopsies existed, and what was the evaluation for that query at each tree. This can help see if an error was fixed later in the ensemble of trees.

# %%
whoopsies = model.whoopsies()
for qid, whoopsie in whoopsies.items():
    print("== QID %s ==" % qid)
    print("%s - %s" % (whoopsie.count, whoopsie.totalMagnitude))
    print(whoopsie.perTreeReport())

# %%
### Doc in index... (notice nothing mentions 'star wars')

client.get_doc(index='tmdb', doc_id=1368)

# %% [markdown]
# ## Add a feature: collection name
#
# We have an intuition about our data, there is a field for the movies "collection name". See it here below:

# %%
from ltr.helpers.movies import get_movie
get_movie(1368)

# %% [markdown]
# We'll add collection name, and reindex.

# %%
def add_collection_name(src_movie, base_doc):
    if 'belongs_to_collection' in src_movie and src_movie['belongs_to_collection'] is not None:
        if 'name' in src_movie['belongs_to_collection']:
            base_doc['collection_name'] = src_movie['belongs_to_collection']['name']
    return base_doc

from ltr.index import rebuild_tmdb
rebuild_tmdb(client, enrich=add_collection_name)

# %% [markdown]
# Confirm it's in our doc now...

# %%
client.get_doc(index='tmdb', doc_id=1892)

# %% [markdown]
# Add it to the features, and retrain....

# %%
config = {"validation": {
              "index": "tmdb",
              "params": {
                  "keywords": "rambo"
              }
    
           },
           "featureset": {
            "features": [
            {
                "name": "title_phrase",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match_phrase": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
            {
                "name": "title",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
            {
                "name": "title_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"title": "{{keywords}}"}
                }
            },
            {
                "name": "overview_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"overview": "{{keywords}}"}
                }
            },
            {
                "name": "overview_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {"overview": "{{keywords}}"}
                }
            },
            {
                "name": "title_fuzzy",
                "params": ["keywords"],
                "template": {
                    "match": {"title": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            },
             {
                "name": "release_year",
                "params": [],
                "template": {
                    "function_score": {
                        "field_value_factor": {
                            "field": "release_year",
                            "missing": 2000
                        },
                        "query": { "match_all": {} }
                    }
                }
            },
            {
                "name": "coll_name_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"collection_name": 
                                {"query": "{{keywords}}"}}
                }
            },
             {
                "name": "coll_name_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {"collection_name": 
                                {"query": "{{keywords}}"}}
                }
            }
            
            
            ]
    }}




from ltr import setup
setup(client, config=config, index='tmdb', featureset='title2')

from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title2_judgments_train.txt', 
                                        featureSet='title2')

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title2_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               features=[1,2,3,4,5,6,7,8,9],
                                               featureSet='title2')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title2_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=20,
                  trees=20,
                  index='tmdb',
                  features=[1,4,6,7,8],
                  featureSet='title2',
                  modelName='title2')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])

# %%
from ltr import search
search(client, "cartoon with basketball aliens", modelName='title2')

# %%
config = {"validation": {
              "index": "tmdb",
              "params": {
                  "keywords": "rambo"
              }
    
           },
           "featureset": {
            "features": [
            {
                "name": "title_phrase",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match_phrase": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
 
            {
                "name": "overview_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"overview": "{{keywords}}"}
                }
            },
   
            {
                "name": "title_fuzzy",
                "params": ["keywords"],
                "template": {
                    "match": {"title": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            },
             {
                "name": "release_year",
                "params": [],
                "template": {
                    "function_score": {
                        "field_value_factor": {
                            "field": "release_year",
                            "missing": 2000
                        },
                        "query": { "match_all": {} }
                    }
                }
            },
            {
                "name": "coll_name_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"collection_name": 
                                {"query": "{{keywords}}"}}
                }
            },
            {
                "name": "title_fuzzy_2",
                "params": ["keywords"],
                "template": {
                       "match": {"title.as_str": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            }
            ]
    }}




from ltr import setup
setup(client, config=config, index='tmdb', featureset='title2')

from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title2_judgments_train.txt', 
                                        featureSet='title2')

# %%
client.get_doc(doc_id=1892)

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title2_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               features=[1,2,3,4,5],
                                               featureSet='title2')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title2_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=20,
                  trees=20,
                  index='tmdb',
                  featureSet='title2',
                  modelName='title2')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])

# %%
from ltr.client import ElasticClient
from ltr.MART_model import eval_model
from ltr.judgments import judgments_from_file, judgments_by_qid

features, _ = client.feature_set(index='tmdb', name='title2')

judgmentDict = judgments_by_qid(judgments_from_file(filename='data/title_judgments_train.txt'))

for qid, judgments in judgmentDict.items():

    model = eval_model(modelName='title2',
                           features=features,
                           judgments=judgments)

    print()
    print("## Evaluating graded docs for search keywords '%s'" % judgments[0].keywords)
    print()
    print(model)

# %%
client.get_doc(doc_id=860)
