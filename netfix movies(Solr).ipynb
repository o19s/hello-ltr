# %% [markdown]
# # Solr Client

# %%
from ltr.client import SolrClient
client = SolrClient()

# %% [markdown]
# # Download & Build Index (run once)
#
# If you don't already have the downloaded dependencies; if you don't have TheMovieDB data indexed run this

# %%
from ltr import download
download();

from ltr.index import rebuild_tmdb
rebuild_tmdb(client)
# Out:
# GET http://es-learn-to-rank.labs.o19s.com/tmdb.json
# GET http://es-learn-to-rank.labs.o19s.com/RankyMcRankFace.jar
# GET http://es-learn-to-rank.labs.o19s.com/title_judgments.txt
# GET http://es-learn-to-rank.labs.o19s.com/genome_judgments.txt
# GET http://es-learn-to-rank.labs.o19s.com/sample_judgments_train.txt
# Done.
# Deleted index tmdb [Status: 200]
# Created index tmdb [Status: 200]
# Reindexing...
# Indexed 0 movies (last Black Mirror: White Christmas)
# Indexed 100 movies (last Apocalypse Now)
# Indexed 200 movies (last Crooks in Clover)
# Indexed 300 movies (last For a Few Dollars More)
# Indexed 400 movies (last Downfall)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 500 movies (last Finding Nemo)
# Indexed 600 movies (last Platoon)
# Indexed 700 movies (last Night of the Living Dead)
# Indexed 800 movies (last Evangelion: 1.0: You Are (Not) Alone)
# Indexed 900 movies (last Batman: Assault on Arkham)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 1000 movies (last Riley's First Date?)
# Indexed 1100 movies (last The Raid)
# Indexed 1200 movies (last Falling Down)
# Indexed 1300 movies (last Kal Ho Naa Ho)
# Indexed 1400 movies (last Elizabeth)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 1500 movies (last Irreversible)
# Indexed 1600 movies (last Friday Night Lights)
# Indexed 1700 movies (last Ben X)
# Indexed 1800 movies (last Pump up the Volume)
# Indexed 1900 movies (last Armour of God)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 2000 movies (last Swingers)
# Indexed 2100 movies (last The Guard)
# Indexed 2200 movies (last Win Win)
# Indexed 2300 movies (last Where the Heart Is)
# Indexed 2400 movies (last UHF)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 2500 movies (last Jerry Maguire)
# Indexed 2600 movies (last Cloud Atlas)
# Indexed 2700 movies (last Rango)
# Indexed 2800 movies (last Rosewater)
# Indexed 2900 movies (last Kalifornia)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 3000 movies (last Bad Santa)
# Indexed 3100 movies (last Defendor)
# Indexed 3200 movies (last The Pirates! Band of Misfits)
# Indexed 3300 movies (last Sister Act)
# Indexed 3400 movies (last Live and Let Die)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 3500 movies (last Hours)
# Indexed 3600 movies (last Monsters)
# Indexed 3700 movies (last MouseHunt)
# Indexed 3800 movies (last Olympus Has Fallen)
# Indexed 3900 movies (last Godzilla)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 4000 movies (last Arbitrage)
# Indexed 4100 movies (last Under Siege)
# Indexed 4200 movies (last Underdogs)
# Indexed 4300 movies (last The Duke of Burgundy)
# Indexed 4400 movies (last Bambi II)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 4500 movies (last Solaris)
# Indexed 4600 movies (last The Stuff)
# Indexed 4700 movies (last Tales from the Darkside: The Movie)
# Indexed 4800 movies (last Final Fantasy: The Spirits Within)
# Indexed 4900 movies (last The Back-Up Plan)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 5000 movies (last Absolutely Anything)
# Indexed 5100 movies (last Funny People)
# Indexed 5200 movies (last Tad, the Lost Explorer)
# Indexed 5300 movies (last Fiston)
# Indexed 5400 movies (last The Reaping)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 5500 movies (last American Pie Presents: Beta House)
# Indexed 5600 movies (last Casino Royale)
# Indexed 5700 movies (last Jennifer's Body)
# Indexed 5800 movies (last Caligula)
# Indexed 5900 movies (last Alex Cross)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 6000 movies (last Rapture Palooza)
# Indexed 6100 movies (last The Seeker: The Dark Is Rising)
# Indexed 6200 movies (last Boogeyman)
# Indexed 6300 movies (last Fifty Shades of Black)
# Indexed 6400 movies (last Wilbur Wants to Kill Himself)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 6500 movies (last A Cruel Romance)
# Indexed 6600 movies (last La discrète)
# Indexed 6700 movies (last The Rapture)
# Indexed 6800 movies (last Ricky Gervais Live 3: Fame)
# Indexed 6900 movies (last Bunny Lake Is Missing)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 7000 movies (last Alice in the Cities)
# Indexed 7100 movies (last Le pélican)
# Indexed 7200 movies (last 20,000 Leagues Under the Sea)
# Indexed 7300 movies (last Deuces Wild)
# Indexed 7400 movies (last Lost Horizon)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 7500 movies (last The Detective 2)
# Indexed 7600 movies (last Absolute Aggression)
# Indexed 7700 movies (last A Fairly Odd Movie: Grow Up, Timmy Turner!)
# Indexed 7800 movies (last How Much Do You Love Me?)
# Indexed 7900 movies (last The Snows of Kilimanjaro)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 8000 movies (last The Wrong Guys)
# Indexed 8100 movies (last BFFs)
# Indexed 8200 movies (last Foreverland)
# Indexed 8300 movies (last Rebellion)
# Indexed 8400 movies (last Air Crew)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 8500 movies (last Down in the Valley)
# Indexed 8600 movies (last Female Agents)
# Indexed 8700 movies (last Come Dance with Me!)
# Indexed 8800 movies (last Versailles)
# Indexed 8900 movies (last Girls on Top)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 9000 movies (last Voll Normaaal)
# Indexed 9100 movies (last Unrated II: Scary as Hell)
# Indexed 9200 movies (last The Flight of the Phoenix)
# Indexed 9300 movies (last DragonHeart: A New Beginning)
# Indexed 9400 movies (last Empire of the Wolves)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 9500 movies (last Searching for Debra Winger)
# Indexed 9600 movies (last Swimming Pool)
# Indexed 9700 movies (last Bomber)
# Indexed 9800 movies (last Bullet in the Head)
# Indexed 9900 movies (last Club Fed)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 10000 movies (last Titus)
# Indexed 10100 movies (last Revolution)
# Indexed 10200 movies (last The Last Dispatch)
# Indexed 10300 movies (last Wings of Courage)
# Indexed 10400 movies (last Gaslight)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 10500 movies (last Frenchmen 2)
# Indexed 10600 movies (last Closing the Ring)
# Indexed 10700 movies (last 3:10 to Yuma)
# Indexed 10800 movies (last Harvest)
# Indexed 10900 movies (last Song of the Thin Man)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 11000 movies (last Nobody Knows Anything!)
# Indexed 11100 movies (last Dirty Deeds)
# Indexed 11200 movies (last The Adventure of Faustus Bidgood)
# Indexed 11300 movies (last Running Time)
# Indexed 11400 movies (last While She Was Out)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 11500 movies (last What?)
# Indexed 11600 movies (last The Legend of Hell House)
# Indexed 11700 movies (last When Worlds Collide)
# Indexed 11800 movies (last The Girl in the Red Velvet Swing)
# Indexed 11900 movies (last 9 Souls)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 12000 movies (last Paradise Lost 2: Revelations)
# Indexed 12100 movies (last Riki-Oh: The Story of Ricky)
# Indexed 12200 movies (last In Vogue: The Editor’s Eye)
# Indexed 12300 movies (last Smart Money)
# Indexed 12400 movies (last Manda Bala (Send a Bullet))
# Flushing 500 movies
# Done [Status: 200]
# Indexed 12500 movies (last Something to Talk About)
# Indexed 12600 movies (last Donald Glover: Weirdo)
# Indexed 12700 movies (last Demon Seed)
# Indexed 12800 movies (last Zig Zag)
# Indexed 12900 movies (last Going Overboard)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 13000 movies (last Mahler)
# Indexed 13100 movies (last Carriage to Vienna)
# Indexed 13200 movies (last The Big Clock)
# Indexed 13300 movies (last Arsenal)
# Indexed 13400 movies (last First Descent)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 13500 movies (last Deep Cover)
# Indexed 13600 movies (last Mixed Blood)
# Indexed 13700 movies (last Red Psalm)
# Indexed 13800 movies (last Bad Biology)
# Indexed 13900 movies (last Shirin)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 14000 movies (last Rhyme & Reason)
# Indexed 14100 movies (last Tuareg: Desert Warrior)
# Indexed 14200 movies (last Havoc)
# Indexed 14300 movies (last Fire Over England)
# Indexed 14400 movies (last Impulse)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 14500 movies (last Cheers For Miss Bishop)
# Indexed 14600 movies (last Don't Bother to Knock)
# Indexed 14700 movies (last Brides)
# Indexed 14800 movies (last The Land Before Time XI: Invasion of the Tinysauruses)
# Indexed 14900 movies (last The Gnome-Mobile)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 15000 movies (last Miracles: Mr. Canton and Lady Rose)
# Indexed 15100 movies (last An Occurrence at Owl Creek Bridge)
# Indexed 15200 movies (last 16 to Life)
# Indexed 15300 movies (last Week-End at the Waldorf)
# Indexed 15400 movies (last Made in Hong Kong)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 15500 movies (last Viva Cuba)
# Indexed 15600 movies (last Big Pun: The Legacy)
# Indexed 15700 movies (last Hurt)
# Indexed 15800 movies (last The Mudge Boy)
# Indexed 15900 movies (last The Hollywood Complex)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 16000 movies (last The Great Northfield Minnesota Raid)
# Indexed 16100 movies (last Lotta Leaves Home)
# Indexed 16200 movies (last Just One of the Girls)
# Indexed 16300 movies (last Which Way Is The Front Line From Here? The Life and Time of Tim Hetherington)
# Indexed 16400 movies (last The Ladies Man)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 16500 movies (last Assassin of the Tsar)
# Indexed 16600 movies (last The Adventures of Tarzan)
# Indexed 16700 movies (last Vendetta)
# Indexed 16800 movies (last Trucker)
# Indexed 16900 movies (last Branded)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 17000 movies (last Mariage à Mendoza)
# Indexed 17100 movies (last Love Bites)
# Indexed 17200 movies (last The Ballad of Ramblin' Jack)
# Indexed 17300 movies (last Blade of the Ripper)
# Indexed 17400 movies (last Kiler)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 17500 movies (last Kaïrat)
# Indexed 17600 movies (last Body Bags)
# Indexed 17700 movies (last Dave Attell: Captain Miserable)
# Indexed 17800 movies (last Wodehouse In Exile)
# Indexed 17900 movies (last Duel in the Sun)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 18000 movies (last The Message)
# Indexed 18100 movies (last Shock)
# Indexed 18200 movies (last Harvey)
# Indexed 18300 movies (last The Worthless)
# Indexed 18400 movies (last Queen of the Mountains)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 18500 movies (last Urgh! A Music War)
# Indexed 18600 movies (last Wuthering Heights)
# Indexed 18700 movies (last Gabriel Over the White House)
# Indexed 18800 movies (last Friendship!)
# Indexed 18900 movies (last Mía)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 19000 movies (last Danger! 50,000 Zombies)
# Indexed 19100 movies (last Top Dog)
# Indexed 19200 movies (last Reaching for the Moon)
# Indexed 19300 movies (last A Child's Christmas in Wales)
# Indexed 19400 movies (last The Dog Who Stopped the War)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 19500 movies (last Police Python 357)
# Indexed 19600 movies (last Accidents Happen)
# Indexed 19700 movies (last Changing Times)
# Indexed 19800 movies (last The Ape)
# Indexed 19900 movies (last Heartbreak Hotel)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 20000 movies (last Left Behind III: World at War)
# Indexed 20100 movies (last Dragon Ball Z: Lord Slug)
# Indexed 20200 movies (last The Adventures of Sherlock Holmes)
# Indexed 20300 movies (last Billy's Hollywood Screen Kiss)
# Indexed 20400 movies (last Short Night of Glass Dolls)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 20500 movies (last Kawa)
# Indexed 20600 movies (last Bears)
# Indexed 20700 movies (last Pyrates)
# Indexed 20800 movies (last Bastard Out of Carolina)
# Indexed 20900 movies (last The Mole People)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 21000 movies (last Till Human Voices Wake Us)
# Indexed 21100 movies (last It's a Wonderful Afterlife)
# Indexed 21200 movies (last The Bingo Long Traveling All-Stars & Motor Kings)
# Indexed 21300 movies (last Ciao! Manhattan)
# Indexed 21400 movies (last The Night They Raided Minsky's)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 21500 movies (last The Girl Can't Help It)
# Indexed 21600 movies (last Sam Peckinpah's West: Legacy of a Hollywood Renegade)
# Indexed 21700 movies (last A Guy Named Joe)
# Indexed 21800 movies (last Odd Man Out)
# Indexed 21900 movies (last The Rise of Catherine the Great)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 22000 movies (last The Girl of the Golden West)
# Indexed 22100 movies (last The Killing of John Lennon)
# Indexed 22200 movies (last Twist)
# Indexed 22300 movies (last After Life)
# Indexed 22400 movies (last The Great Ecstasy of Robert Carmichael)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 22500 movies (last Do Not Disturb)
# Indexed 22600 movies (last Something Real and Good)
# Indexed 22700 movies (last CBGB)
# Indexed 22800 movies (last California Solo)
# Indexed 22900 movies (last Richard III)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 23000 movies (last She's Out of Control)
# Indexed 23100 movies (last Dead End Drive-In)
# Indexed 23200 movies (last Venus Boyz)
# Indexed 23300 movies (last My Giant)
# Indexed 23400 movies (last The Beekeeper)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 23500 movies (last The Bobo)
# Indexed 23600 movies (last Amen)
# Indexed 23700 movies (last Favela Rising)
# Indexed 23800 movies (last The 4th Floor)
# Indexed 23900 movies (last Chisum)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 24000 movies (last Boulevard)
# Indexed 24100 movies (last Ingmar Bergman Makes a Movie)
# Indexed 24200 movies (last The Play House)
# Indexed 24300 movies (last Of Mice and Men)
# Indexed 24400 movies (last Dr. Gillespie's New Assistant)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 24500 movies (last Rat)
# Indexed 24600 movies (last Unstrung Heroes)
# Indexed 24700 movies (last Crazy Sexy Cancer)
# Indexed 24800 movies (last High and Dizzy)
# Indexed 24900 movies (last The Murder of Fred Hampton)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 25000 movies (last Holiday for Drumsticks)
# Indexed 25100 movies (last China Blue)
# Indexed 25200 movies (last Pancho, el perro millonario)
# Indexed 25300 movies (last The Diary of Anne Frank)
# Indexed 25400 movies (last To Be Twenty)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 25500 movies (last Empire of Silver)
# Indexed 25600 movies (last Knockout)
# Indexed 25700 movies (last Speed & Angels)
# Indexed 25800 movies (last Meek's Cutoff)
# Indexed 25900 movies (last Sharpe's Sword)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 26000 movies (last May 18)
# Indexed 26100 movies (last Dealer)
# Indexed 26200 movies (last Carmen Miranda: Bananas Is My Business)
# Indexed 26300 movies (last Il figlio dello sceicco)
# Indexed 26400 movies (last Muddy River)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 26500 movies (last Judy Moody and the Not Bummer Summer)
# Indexed 26600 movies (last The Naughty Room)
# Indexed 26700 movies (last Time Without Pity)
# Indexed 26800 movies (last L'outremangeur)
# Indexed 26900 movies (last Buddha Collapsed Out of Shame)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 27000 movies (last Uno contro l'altro praticamente amici)
# Indexed 27100 movies (last The Talent Given Us)
# Indexed 27200 movies (last Paris Trout)
# Indexed 27300 movies (last The Crystal Ball)
# Indexed 27400 movies (last West Is West)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 27500 movies (last Breaktime)
# Indexed 27600 movies (last Two for the Seesaw)
# Indexed 27700 movies (last Fingers at the Window)
# Flushing 260 movies
# Done [Status: 200]
# Done

# %% [markdown]
# ## Features for movie titles
#
# We'll be searching movie titles (think searching for a specific movie on Netflix). And we have a set of judgments around the appropriatte movie to return. IE search for "Star Wars" return good star wars matches, in quality order...
#
# These cover various aspects of the problem (searching title by phrase, title bm25 score, release date, etc). We'll use this to explore and analyze a simple model

# %%
config = [
    #1
    {
      "name" : "title_has_phrase",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:\"${keywords})\"^=1"
      }
    },
    #2
    {
      "name" : "title_has_terms",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:(${keywords})^=1"
      }
    },
    #3
    {
      "name" : "title_bm25",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:(${keywords})"
      }
    },
    #4
    {
      "name" : "overview_bm25",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:(${keywords})"
      }
    },
    #5
    {
      "name" : "overview_phrase_bm25",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:\"${keywords}\""
      }
    },
    #6
    {
      "name" : "title_fuzzy",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!lucene df=title}${keywords}~"
      }
    },
    #7
    {
      "name" : "release_year",
      "store": "title",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!func}def(release_year,2000)"
      }
    }

]



from ltr import setup
setup(client, config=config, featureset='title')
# Out:
# Deleted title model [Status: 200]
# Deleted title Featurestore [Status: 200]
# Created title feature store under tmdb: [Status: 200]

# %% [markdown]
# ## Training Set Generation
#
# Log out features for each of the above queries out to a training set file

# %%
from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title_judgments_train.txt', 
                                        featureSet='title')
# Out:
# Recognizing 40 queries...
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rambo (0/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rocky (1/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for war games (2/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for crocodile dundee (3/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for matrix (4/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for contact (5/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for space jam (6/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for battlestar galactica (7/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for her (8/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for jobs (9/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for social network (10/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rocky horror (11/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for shawshank redemption (12/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for french connection (13/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for star wars new hope (14/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for lego batman (15/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for crouching tiger hidden dragon (16/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for fight club (17/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for die hard (18/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for last temptation of christ (19/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for tree of life (20/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for murray saves christmas (21/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for black swan (22/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for emma (23/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for mad max fury road (24/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for kung fury (25/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for mr smith goes to washington (26/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for kill bill (27/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for the godfather (28/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for pulp fiction (29/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for christmas vacation (30/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for psycho (31/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for life is beautiful (32/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for dark knight (33/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for the green mile (34/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for forrest gump (35/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for top gun (36/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for how to train your dragon (37/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for how to train your dragon 2 (38/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for star wars (39/40)
# Discarded 0 Keep 1390

# %% [markdown]
# ## Feature Search: which features work best?
#
# What combination of these features work best? Train a model with every combination, and use k-fold cross valudation (see `kcv=15` below). The combination with the best NDCG is output

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               features=[1,2,3,4,5,6,7],
                                               featureSet='title')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1] TEST NDCG@10=0.9071
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2] TEST NDCG@10=0.9064
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3] TEST NDCG@10=0.8482
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4] TEST NDCG@10=0.4683
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5] TEST NDCG@10=0.7153
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6] TEST NDCG@10=0.869
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [7] TEST NDCG@10=0.2794
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2] TEST NDCG@10=0.9064
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3] TEST NDCG@10=0.906
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4] TEST NDCG@10=0.8334
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5] TEST NDCG@10=0.8316
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 6] TEST NDCG@10=0.8995
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 7] TEST NDCG@10=0.792
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3] TEST NDCG@10=0.8482
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4] TEST NDCG@10=0.614
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5] TEST NDCG@10=0.8384
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 6] TEST NDCG@10=0.8611
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 7] TEST NDCG@10=0.5693
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4] TEST NDCG@10=0.8931
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5] TEST NDCG@10=0.8758
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 6] TEST NDCG@10=0.8627
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 7] TEST NDCG@10=0.8816
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5] TEST NDCG@10=0.4811
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 6] TEST NDCG@10=0.8584
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 7] TEST NDCG@10=0.3476
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 6] TEST NDCG@10=0.8801
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 7] TEST NDCG@10=0.3738
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6, 7] TEST NDCG@10=0.8574
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3] TEST NDCG@10=0.906
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4] TEST NDCG@10=0.8341
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5] TEST NDCG@10=0.8586
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 6] TEST NDCG@10=0.9001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 7] TEST NDCG@10=0.8016
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4] TEST NDCG@10=0.9068
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5] TEST NDCG@10=0.9036
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 6] TEST NDCG@10=0.9013
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 7] TEST NDCG@10=0.8894
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5] TEST NDCG@10=0.8597
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 6] TEST NDCG@10=0.9104
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 7] TEST NDCG@10=0.8183
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1,
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 6, 7] TEST NDCG@10=0.9094
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5, 6, 7] TEST NDCG@10=0.8893
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5, 6, 7] TEST NDCG@10=0.9071
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 6] TEST NDCG@10=0.8771
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 7] TEST NDCG@10=0.908
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 6, 7] TEST NDCG@10=0.9101
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 5, 6, 7] TEST NDCG@10=0.8878
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4, 5, 6, 7] TEST NDCG@10=0.875
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4, 5, 6, 7] TEST NDCG@10=0.9091
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 6] TEST NDCG@10=0.9051
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 7] TEST NDCG@10=0.92
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 6, 7] TEST NDCG@10=0.9094
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 5, 6, 7] TEST NDCG@10=0.8893
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4, 5, 6, 7] TEST NDCG@10=0.9071
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5, 6, 7] TEST NDCG@10=0.911
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 6, 7] TEST NDCG@10=0.9091
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 6, 7] TEST NDCG@10=0.911
#
# Impact of each feature on the model
# 7 - 17618.35445148437
# 4 - 16165.586045512271
# 3 - 10958.610341321868
# 5 - 9256.821192289186
# 1 - 1436.0640878600943
# 0.9135
# 0.9097
# 0.9111
# 0.9111
# 0.9111
# 0.9111
# 0.9111
# 0.9292
# 0.9284
# 0.9326
# 0.9326
# 0.9327
# 0.9404
# 0.9373
# 0.9394
# 0.9401
# 0.9398
# 0.9433
# 0.9401
# 0.9429
# Avg NDCG@10 when feature included:
# 1 => 0.8861281250000003
# 2 => 0.8564515625000003
# 3 => 0.89500625
# 4 => 0.8424765625000001
# 5 => 0.8450390625000002
# 6 => 0.890534375
# 7 => 0.8295687500000001
# Avg K-Fold NDCG@10 0.92

# %% [markdown]
# ## Compare to model w/ all features
#
# Compare the features output above (something like...)
#
# ```
# Impact of each feature on the model
# 3 - 17728.651362443747
# 4 - 10986.88505569509
# 7 - 7504.573843344015
# 1 - 1580.321225819952
# ```
#
# to one trained with the full model. Notice how features have different impacts. This is due to feature dependency

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=10,
                  trees=10,
                  features=[1,2,3,4,5,6,7],
                  featureSet='title',
                  modelName='title')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 10 -leaf 10 -train data/title_judgments_train.txt -save data/title_model.txt  -feature features.txt
# DONE
# Submit Model title Ftr Set title [Status: 200]
# Feature Set title... [Status: 200]
# Deleted Model title [Status: 200]
# Created Model title [Status: 200]
#
# Impact of each feature on the model
# 7 - 8981.831019283243
# 4 - 8532.518149563115
# 6 - 5038.846398759236
# 3 - 3348.1296893743006
# 1 - 1721.358188746177
# 2 - 0.0
# 5 - 0.0
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# 0.9157
# Train NDCG@10 0.9157

# %% [markdown]
# ## Bias towards fewer features
#
# By adding a 'cost', to feature search, we add a multiplier that punishes models with more features slightly. This results in a tiny bias towards simpler models all things being equal. As we'd prefer one that doesn't need to execute more features

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               featureCost=0.1,# 1.0-cost ^ num_features
                                               features=[1,2,3,4,5,6,7],
                                               featureSet='title')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1] TEST NDCG@10=0.9071 after cost 0.9071
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2] TEST NDCG@10=0.9064 after cost 0.9064
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3] TEST NDCG@10=0.8482 after cost 0.8482
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4] TEST NDCG@10=0.4683 after cost 0.4683
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5] TEST NDCG@10=0.7153 after cost 0.7153
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6] TEST NDCG@10=0.869 after cost 0.869
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [7] TEST NDCG@10=0.2794 after cost 0.2794
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2] TEST NDCG@10=0.9064 after cost 0.81576
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3] TEST NDCG@10=0.906 after cost 0.8154
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4] TEST NDCG@10=0.8334 after cost 0.7500600000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5] TEST NDCG@10=0.8316 after cost 0.74844
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 6] TEST NDCG@10=0.8995 after cost 0.80955
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 7] TEST NDCG@10=0.792 after cost 0.7128000000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3] TEST NDCG@10=0.8482 after cost 0.76338
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4] TEST NDCG@10=0.614 after cost 0.5526
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5] TEST NDCG@10=0.8384 after cost 0.75456
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 6] TEST NDCG@10=0.8611 after cost 0.77499
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 7] TEST NDCG@10=0.5693 after cost 0.51237
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 4] TEST NDCG@10=0.8931 after cost 0.80379
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 5] TEST NDCG@10=0.8758 after cost 0.78822
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 6] TEST NDCG@10=0.8627 after cost 0.7764300000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3, 7] TEST NDCG@10=0.8816 after cost 0.79344
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 5] TEST NDCG@10=0.4811 after cost 0.43299000000000004
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 6] TEST NDCG@10=0.8584 after cost 0.77256
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4, 7] TEST NDCG@10=0.3476 after cost 0.31284
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 6] TEST NDCG@10=0.8801 after cost 0.79209
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5, 7] TEST NDCG@10=0.3738 after cost 0.33642000000000005
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [6, 7] TEST NDCG@10=0.8574 after cost 0.77166
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3] TEST NDCG@10=0.906 after cost 0.7338600000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 4] TEST NDCG@10=0.8341 after cost 0.675621
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 5] TEST NDCG@10=0.8586 after cost 0.695466
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 6] TEST NDCG@10=0.9001 after cost 0.7290810000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 7] TEST NDCG@10=0.8016 after cost 0.649296
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4] TEST NDCG@10=0.9068 after cost 0.734508
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 5] TEST NDCG@10=0.9036 after cost 0.731916
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 6] TEST NDCG@10=0.9013 after cost 0.7300530000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 7] TEST NDCG@10=0.8894 after cost 0.720414
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 5] TEST NDCG@10=0.8597 after cost 0.6963570000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4, 6] TEST NDCG@10=0.9104 after cost 0.7374240000000001
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 
# 0.9433
# 0.9401
# 0.9429
# Avg NDCG@10 when feature included:
# 1 => 0.8861281250000003
# 2 => 0.8564515625000003
# 3 => 0.89500625
# 4 => 0.8424765625000001
# 5 => 0.8450390625000002
# 6 => 0.890534375
# 7 => 0.8295687500000001
# Avg K-Fold NDCG@10 0.92

# %% [markdown]
# # Evaluating the Model
#
# It's interesting to see what features our model makes use of, but we need guidance on adding additional features to the model. We know our model is an ensemble of decision trees. Wouldn't it be cool if we could trace where documents end up on that decision tree?
#
# Specifically, we care about problems. Or what we will call affectionately *whoopsies*.
#
# As a 'whoopsie' example, consider the query "Rambo". if a '0' document like 'First Daughter' ranked the same or higher than a '4' document ("Rambo")., that's a problem. It's also an opportunity for improvement. We'd want to isolate that, see if it's indicative of a broader trend, and thus worth adding a feature for.
#
# Let's see a concrete example

# %%
from ltr.client import ElasticClient
from ltr.MART_model import eval_model
from ltr.judgments import judgments_from_file, judgments_by_qid

features, _ = client.feature_set(index='tmdb', name='title')

judgmentDict = judgments_by_qid(judgments_from_file(filename='data/title_judgments_train.txt'))


rambo=judgmentDict[1]
model = eval_model(modelName='title',
                       features=features,
                       judgments=rambo)

print()
print("## Evaluating graded docs for search keywords '%s'" % rambo[0].keywords)
print()
print(model)
# Out:
# Feature Set title... [Status: 200]
# Recognizing 40 queries...
#
# ## Evaluating graded docs for search keywords 'rambo'
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if overview_bm25 > 0.0:
#         if overview_bm25 > 8.7690325:
#           if title_fuzzy > 19.553139:
#             <= 0.2000(0/0/)
#           else:
#             <= 0.1983(0/0/)
#         else:
#           <= 0.2000(0/0/)
#       else:
#         if title_bm25 > 15.621795:
#           <= 0.1993(0/0/)
#         else:
#           <= 0.1969(0/0/)
#     else:
#       <= 0.1944(1/0/)
#   else:
#     <= 0.1094(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 10.138651:
#       <= 0.1967(1/0/)
#     else:
#       <= 0.1092(1/0/)
#   else:
#     <= -0.1838(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         if release_year > 2009.0:
#           <= 0.1679(0/0/)
#         else:
#           <= 0.1541(0/0/)
#       else:
#         if release_year > 1990.0:
#           <= 0.1686(0/0/)
#         else:
#           if title_bm25 > 11.79394:
#             <= 0.1683(0/0/)
#           else:
#             <= 0.1682(0/0/)
#     else:
#       <= 0.1633(1/0/)
#   else:
#     <= 0.1096(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 10.138651:
#       <= 0.1659(1/0/)
#     else:
#       <= 0.0920(1/0/)
#   else:
#     <= -0.1563(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1483(0/0/)
#       else:
#         if release_year > 1990.0:
#           <= 0.1499(0/0/)
#         else:
#           if title_bm25 > 11.79394:
#             <= 0.1500(0/0/)
#           else:
#             <= 0.1494(0/0/)
#     else:
#       <= 0.1451(1/0/)
#   else:
#     <= 0.0934(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 10.138651:
#       <= 0.1477(1/0/)
#     else:
#       if title_bm25 > 8.06954:
#         <= 0.1405(0/0/)
#       else:
#         <= -0.1142(1/0/)
#   else:
#     <= -0.1381(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1361(0/0/)
#       else:
#         if release_year > 1990.0:
#           <= 0.1377(0/0/)
#         else:
#           if title_bm25 > 11.79394:
#             <= 0.1381(0/0/)
#           else:
#             <= 0.1372(0/0/)
#     else:
#       <= 0.1327(1/0/)
#   else:
#     <= 0.0808(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 10.138651:
#       <= 0.1354(1/0/)
#     else:
#       if release_year > 2012.0:
#         <= 0.1502(0/0/)
#       else:
#         <= 0.0343(1/0/)
#   else:
#     <= -0.1255(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1277(0/0/)
#       else:
#         if release_year > 1990.0:
#           <= 0.1294(0/0/)
#         else:
#           if title_bm25 > 11.79394:
#             <= 0.1299(0/0/)
#           else:
#             <= 0.1287(0/0/)
#     else:
#       <= 0.1239(1/0/)
#   else:
#     <= 0.0706(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 8.06954:
#       if title_bm25 > 10.138651:
#         <= 0.1268(1/0/)
#       else:
#         <= 0.1168(0/0/)
#     else:
#       <= -0.0981(1/0/)
#   else:
#     <= -0.1163(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1215(0/0/)
#       else:
#         if release_year > 1990.0:
#           <= 0.1233(0/0/)
#         else:
#           if title_bm25 > 11.79394:
#             <= 0.1241(0/0/)
#           else:
#             <= 0.1226(0/0/)
#     else:
#       <= 0.1170(1/0/)
#   else:
#     <= 0.0619(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 8.06954:
#       if title_bm25 > 10.138651:
#         <= 0.1203(1/0/)
#       else:
#         <= 0.1066(0/0/)
#     else:
#       <= -0.0869(1/0/)
#   else:
#     <= -0.1090(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1168(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1194(0/0/)
#         else:
#           <= 0.1184(0/0/)
#     else:
#       <= 0.1117(1/0/)
#   else:
#     <= 0.0544(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 8.06954:
#       if title_bm25 > 10.138651:
#         <= 0.1154(1/0/)
#       else:
#         if title_bm25 > 8.690273:
#           <= 0.0754(0/0/)
#         else:
#           <= 0.1287(0/0/)
#     else:
#       <= -0.0779(1/0/)
#   else:
#     <= -0.1030(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1131(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1161(0/0/)
#         else:
#           <= 0.1151(0/0/)
#     else:
#       <= 0.1072(1/0/)
#   else:
#     <= 0.0477(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 8.06954:
#       if title_bm25 > 10.138651:
#         <= 0.1114(1/0/)
#       else:
#         if title_bm25 > 8.690273:
#           <= 0.0680(0/0/)
#         else:
#           <= 0.1222(0/0/)
#     else:
#       <= -0.0695(1/0/)
#   else:
#     <= -0.0977(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1102(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1137(0/0/)
#         else:
#           <= 0.1125(0/0/)
#     else:
#       <= 0.1033(1/0/)
#   else:
#     <= 0.0417(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 8.06954:
#       if title_bm25 > 10.138651:
#         <= 0.1080(1/0/)
#       else:
#         if title_bm25 > 8.690273:
#           <= 0.0612(0/0/)
#         else:
#           <= 0.1171(0/0/)
#     else:
#       <= -0.0624(1/0/)
#   else:
#     <= -0.0930(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_bm25 > 11.069751:
#   if title_has_phrase > 0.0:
#     if title_fuzzy > 11.173206:
#       if release_year > 2003.0:
#         <= 0.1077(0/0/)
#       else:
#         if overview_bm25 > 0.0:
#           <= 0.1119(0/0/)
#         else:
#           <= 0.1105(0/0/)
#     else:
#       <= 0.0998(1/0/)
#   else:
#     <= 0.0365(0/0/)
# else:
#   if title_has_phrase > 0.0:
#     if title_bm25 > 6.828073:
#       if title_bm25 > 10.138651:
#         <= 0.1051(1/0/)
#       else:
#         if release_year > 2012.0:
#           <= 0.1081(0/0/)
#         else:
#           <= 0.0607(1/0/)
#     else:
#       <= -0.1256(0/0/)
#   else:
#     <= -0.0886(38/1/qid:1:0(319074)-4(1368))

# %% [markdown]
# ## Examining our evaluation for whoopsies
#
# Let's looks at one tree in our ensemble, te see how it was evaluated.
#
# ```
# if title_bm25 > 10.664251:
#   if title_phrase > 0.0:
#     if title_bm25 > 13.815164:
#       if release_year > 2000.0:
#         <= 0.1215(0/0/)
#       else:
#         <= 0.1240(0/0/)
#     else:
#       if title_bm25 > 10.667803:
#         if overview_bm25 > 0.0:
#           <= 0.1194(0/0/)
#         else:
#           <= 0.1161(1/0/)
#       else:
#         <= 0.1264(0/0/)
#   else:
#     <= 0.0800(0/0/)
# else:
#   if title_phrase > 0.0:
#     if title_bm25 > 8.115499:
#       if title_bm25 > 8.217656:
#         <= 0.1097(2/1/qid:40:2(12180)-3(140607))
#       else:
#         <= 0.1559(0/0/)
#     else:
#       <= -0.0021(2/1/qid:40:2(1895)-3(330459))
#   else:
#     <= -0.1093(25/1/qid:40:0(85783)-3(1892))
# ```
#
# You'll notice here this tree is represented by a series of if statements, where the feature's name is used. This is handy as it lets us take apart the structure of the tree.
#
# You'll also notice the leaf nodes starting with
#
# ```
# <=
# ```
#
# These leaf nodes have a floating point value, corresponding to the relevance score that documents ending up here will have. Each leaf also has three items in paranthesis, such as `(2/1/qid:40:2(1895)-3(330459))`. This is a report summarizing the result of evaluating the tree on the provided judgment list. Indicating:
#
#
# ```
#
#
#
#    +--- 2 Documents evaluated to this leaf node                   +-- max grade doc eval'd to this leaf
#    |                                                              |
#    | +----- 1 'whoopsie' occured                                  |  +-- corresp. doc id of max doc
#    | |                                                            |  |
#    | |   +--- details on each whoopsie ----------- qid:40:2(1985)-3(330459)
#    | |   |                                              | |  |
#   (2/1/qid:40:2(1895)-3(330459))                        | |  |
#                                                         | |  + doc id of min graded doc
#                                                         | |
#                                                         | + min grade of docs eval'd to this leaf
#                                                         |
#                                                         + query id of whoopsie from judgments
# ```
#
#
# Looking at Star Wars, our biggest issues in this tree are with the bottom-most leaf. Here
#
# ```
# if title_bm25 > 10.664251:
#   ...
# else:
#   if title_phrase > 0.0:
#     ...
#   else:
#     <= -0.1093(25/1/qid:40:0(85783)-3(1892))
# ```
#
#
# Document 85783 (a '0') and doc 1892 are given the same grade.

# %% [markdown]
# ### Whoopsie, from the query perspective
#
# Whoopsies can also be examined at the "query" level to see for a query id, how many whoopsies existed, and what was the evaluation for that query at each tree. This can help see if an error was fixed later in the ensemble of trees.

# %%
whoopsies = model.whoopsies()
for qid, whoopsie in whoopsies.items():
    print("== QID %s ==" % qid)
    print("%s - %s" % (whoopsie.count, whoopsie.totalMagnitude))
    print(whoopsie.perTreeReport())
# Out:
# == QID 1 ==
# 10 - 40
# tree:0=>0(319074)-4(1368);tree:1=>0(319074)-4(1368);tree:2=>0(319074)-4(1368);tree:3=>0(319074)-4(1368);tree:4=>0(319074)-4(1368);tree:5=>0(319074)-4(1368);tree:6=>0(319074)-4(1368);tree:7=>0(319074)-4(1368);tree:8=>0(319074)-4(1368);tree:9=>0(319074)-4(1368)

# %%
### Doc in index... (notice nothing mentions 'star wars')

client.get_doc(doc_id=319074)
# Out:
# {'id': '319074',
#  'title': ['In Football We Trust'],
#  'title_bidirect_syn': ['In Football We Trust'],
#  'title_directed_syn': ['In Football We Trust'],
#  'title_multiterm_syn': ['In Football We Trust'],
#  'title_idioms': ['In Football We Trust'],
#  'text_all_idioms': ['In Football We Trust',
#   '‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.',
#   '',
#   'Tony Vainuku',
#   'Erika Cohn',
#   '',
#   'Documentary'],
#  'title_taxonomy': ['In Football We Trust'],
#  'text_all_taxonomy': ['In Football We Trust',
#   '‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.',
#   '',
#   'Tony Vainuku',
#   'Erika Cohn',
#   '',
#   'Documentary'],
#  'title_en': ['In Football We Trust'],
#  'title_ws_syn': ['In Football We Trust'],
#  'title_auto_phrase_syn': ['In Football We Trust'],
#  'title_auto_phrase_bigram': ['In Football We Trust'],
#  'text_all': ['In Football We Trust',
#   '‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.',
#   '',
#   'Tony Vainuku',
#   'Erika Cohn',
#   '',
#   'Documentary'],
#  'overview': ['‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.'],
#  'overview_bidirect_syn': ['‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.'],
#  'overview_directed_syn': ['‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.'],
#  'overview_first_char': ['‘In Football We Trust’ captures a snapshot in time amid the rise of the Pacific Islander presence in the NFL. Presenting a new take on the American immigrant story, this feature length documentary transports viewers deep inside the tightly-knit Polynesian community in Salt Lake City, Utah. With unprecedented access and shot over a four-year time period, the film intimately portrays four young Polynesian men striving to overcome gang violence and near poverty through American football. Viewed as the "salvation" for their families, these young players reveal the culture clash they experience as they transform out of their adolescence and into the high stakes world of collegiate recruiting and rigors of societal expectations.'],
#  'tagline': [''],
#  'tagline_bidirect_syn': [''],
#  'tagline_directed_syn': [''],
#  'tagline_multiterm_syn': [''],
#  'tagline_idioms': [''],
#  'tagline_taxonomy': [''],
#  'tagline_en': [''],
#  'tagline_ws_syn': [''],
#  'tagline_auto_phrase_syn': [''],
#  'directors': ['Tony Vainuku', 'Erika Cohn'],
#  'directors_idioms': ['Tony Vainuku', 'Erika Cohn'],
#  'directors_taxonomy': ['Tony Vainuku', 'Erika Cohn'],
#  'directors_en': ['Tony Vainuku', 'Erika Cohn'],
#  'directors_ws_syn': ['Tony Vainuku', 'Erika Cohn'],
#  'directors_auto_phrase_syn': ['Tony Vainuku', 'Erika Cohn'],
#  'text_people': ['Tony Vainuku', 'Erika Cohn', ''],
#  'text_people_notf': ['Tony Vainuku', 'Erika Cohn', ''],
#  'text_people_notf_first10': ['Tony Vainuku', 'Erika Cohn', ''],
#  'cast': [''],
#  'cast_idioms': [''],
#  'cast_taxonomy': [''],
#  'cast_en': [''],
#  'cast_ws_syn': [''],
#  'cast_auto_phrase_syn': [''],
#  'genres': ['Documentary'],
#  'genres_idioms': ['Documentary'],
#  'genres_taxonomy': ['Documentary'],
#  'genres_en': ['Documentary'],
#  'genres_ws_syn': ['Documentary'],
#  'genres_auto_phrase_syn': ['Documentary'],
#  'release_date': '2015-01-23T00:00:00Z',
#  'release_year': 2015,
#  'vote_average': 5.0,
#  'vote_count': 1,
#  '_version_': 1635349237284732928}

# %% [markdown]
# ## Add a feature: collection name
#
# We have an intuition about our data, there is a field for the movies "collection name". See it here below:

# %%
from ltr.helpers.movies import get_movie
get_movie(1892)
# Out:
# {'id': 1892,
#  'title': 'Return of the Jedi',
#  'video': False,
#  'mlensId': '1210',
#  'vote_average': 7.8,
#  'backdrop_path': '/koE7aMeR2ATivI18mCbscLsI0Nm.jpg',
#  'tagline': 'The Empire Falls...',
#  'directors': [{'id': 19800,
#    'department': 'Directing',
#    'credit_id': '52fe431ec3a36847f803bbfd',
#    'name': 'Richard Marquand',
#    'profile_path': '/wuO69rNp2mMG9unvRpZhbccoAh9.jpg',
#    'job': 'Director'}],
#  'release_date': '1983-05-23',
#  'belongs_to_collection': {'poster_path': '/ghd5zOQnDaDW1mxO7R5fXXpZMu.jpg',
#   'id': 10,
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg',
#   'name': 'Star Wars Collection'},
#  'runtime': 135,
#  'popularity': 3.914347,
#  'status': 'Released',
#  'original_language': 'en',
#  'cast': [{'order': 0,
#    'id': 2,
#    'cast_id': 8,
#    'credit_id': '52fe431ec3a36847f803bc13',
#    'name': 'Mark Hamill',
#    'profile_path': '/ws544EgE5POxGJqq9LUfhnDrHtV.jpg',
#    'character': 'Luke Skywalker'},
#   {'order': 1,
#    'id': 3,
#    'cast_id': 9,
#    'credit_id': '52fe431ec3a36847f803bc17',
#    'name': 'Harrison Ford',
#    'profile_path': '/z6P1gr55zNp3fDd7YU3F55WVlVI.jpg',
#    'character': 'Han Solo'},
#   {'order': 2,
#    'id': 4,
#    'cast_id': 10,
#    'credit_id': '52fe431ec3a36847f803bc1b',
#    'name': 'Carrie Fisher',
#    'profile_path': '/pbleNurCYdrLFQMEnlQB2nkOR1O.jpg',
#    'character': 'Princess Leia'},
#   {'order': 3,
#    'id': 3799,
#    'cast_id': 11,
#    'credit_id': '52fe431ec3a36847f803bc1f',
#    'name': 'Billy Dee Williams',
#    'profile_path': '/sDuo82Mb5o3ZGt4SuV9dR0lAh8P.jpg',
#    'character': 'Lando Calrissian'},
#   {'order': 4,
#    'id': 6,
#    'cast_id': 12,
#    'credit_id': '52fe431ec3a36847f803bc23',
#    'name': 'Anthony Daniels',
#    'profile_path': '/cljvryjb3VwTsNR7fjQKjNPMaBB.jpg',
#    'character': 'C-3PO'},
#   {'order': 5,
#    'id': 24342,
#    'cast_id': 20,
#    'credit_id': '52fe431ec3a36847f803bc3b',
#    'name': 'David Prowse',
#    'profile_path': '/cJtmBVrjYwawh2cCiAfZkEjPeqc.jpg',
#    'character': 'Darth Vader'},
#   {'order': 6,
#    'id': 130,
#    'cast_id': 22,
#    'credit_id': '52fe431ec3a36847f803bc43',
#    'name': 'Kenny Baker',
#    'profile_path': '/sdd9rgifNF9C51RejG7sUGU8Bka.jpg',
#    'character': 'R2-D2 / Paploo'},
#   {'order': 7,
#    'id': 24343,
#    'cast_id': 13,
#    'credit_id': '52fe431ec3a36847f803bc27',
#    'name': 'Peter Mayhew',
#    'profile_path': '/din1s5H4C4CfcnkHfEeRcdFlsVj.jpg',
#    'character': 'Chewbacca'},
#   {'order': 8,
#    'id': 7908,
#    'cast_id': 15,
#    'credit_id': '52fe431ec3a36847f803bc2f',
#    'name': 'Frank Oz',
#    'profile_path': '/9KqCa2wS4EO2yymrVIgMiFHh6M4.jpg',
#    'character': 'Yoda (voice)'},
#   {'order': 9,
#    'id': 27762,
#    'cast_id': 16,
#    'credit_id': '52fe431ec3a36847f803bc33',
#    'name': 'Ian McDiarmid',
#    'profile_path': '/yQYNxIjSVYp2Hli7IHOq182NoIJ.jpg',
#    'character': 'The Emperor'},
#   {'order': 10,
#    'id': 15152,
#    'cast_id': 14,
#    'credit_id': '52fe431ec3a36847f803bc2b',
#    'name': 'James Earl Jones',
#    'profile_path': '/2ZuBf3ip2RXhkiQqGUjbUzAf4Nx.jpg',
#    'character': 'Voice of Darth Vader (voice)'},
#   {'order': 11,
#    'id': 28235,
#    'cast_id': 17,
#    'credit_id': '52fe431ec3a36847f803bc37',
#    'name': 'Sebastian Shaw',
#    'profile_path': '/j6SFQiU0isXWNfMK6Cq4XQPdJDl.jpg',
#    'character': 'Anakin Skywalker'},
#   {'order': 12,
#    'id': 17244,
#    'cast_id': 127,
#    'credit_id': '586574ed9251412b87020d03',
#    'name': 'Hayden Christensen',
#    'profile_path': '/lz6mI2hhVrGu640fxm9GQkv4V7l.jpg',
#    'character': 'Ghost Anakin Skywalker'},
#   {'order': 13,
#    'id': 12248,
#    'cast_id': 21,
#    'credit_id': '52fe431ec3a36847f803bc3f',
#    'name': 'Alec Guinness',
#    'profile_path': '/nv3ppxgUQJytFGXZNde4f9ZlshB.jpg',
#    'character': "Ben 'Obi-Wan' Kenobi"},
#   {'order': 14,
#    'id': 11184,
#    'cast_id': 23,
#    'credit_id': '52fe431ec3a36847f803bc47',
#    'name': 'Warwick Davis',
#    'profile_path': '/5xBunTQJexQOuCmtlh8MNJerbaM.jpg',
#    'character': 'Wicket'},
#   {'order': 15,
#    'id': 37442,
#    'cast_id': 26,
#    'credit_id': '52fe431ec3a36847f803bc57',
#    'name': 'Caroline Blakiston',
#    'profile_path': '/tbABMp1c3zgiJKOoRaIkw9XWQ2Y.jpg',
#    'character': 'Mon Mothma'},
#   {'order': 16,
#    'id': 1230989,
#    'cast_id': 28,
#    'credit_id': '54e9c09a92514111b80030b8',
#    'name': 'Michael Pennington',
#    'profile_path': '/jreFHCg8golvAEbcwzKtPoqg6YZ.jpg',
#    'character': 'Moff Jerjerrod'},
#   {'order': 17,
#    'id': 10734,
#    'cast_id': 29,
#    'credit_id': '54e9c0e8c3a3684ea60030b6',
#    'name': 'Kenneth Colley',
#    'profile_path': '/yNZF27tBauzUcg6Fw7M2xsRD8IC.jpg',
#    'character': 'Admiral Piett'},
#   {'order': 18,
#    'id': 199055,
#    'cast_id': 30,
#    'credit_id': '54e9c2519251412eb1003c6a',
#    'name': 'Michael Carter',
#    'profile_path': '/rYVKZQ4uYLf7cpAGfdFzDcRNJXw.jpg',
#    'character': 'Bib Fortuna'},
#   {'order': 19,
#    'id': 47698,
#    'cast_id': 31,
#    'credit_id': '54e9c284c3a36836ea003dd3',
#    'name': 'Denis Lawson',
#    'profile_path': '/78Yl1gcn5TpS6WsZ1tjwdX8j7Vd.jpg',
#    'character': 'Wedge'},
#   {'order': 20,
#    'id': 114761,
#    'cast_id': 32,
#    'credit_id': '54e9c457c3a36836ea003df9',
#    'name': 'Tim Rose',
#    'profile_path': '/oIJel5ldcVQew5XpTG4lne5fvkA.jpg',
#    'character': 'Admiral Ackbar'},
#   {'order': 21,
#    'id': 17484,
#    'cast_id': 33,
#    'credit_id': '54e9c57bc3a36836d6003757',
#    'name': 'Dermot Crowley',
#    'profile_path': '/z2flyEd3eV8Ho8mXa8rXOHZw9Yg.jpg',
#    'character': 'General Madine'},
#   {'order': 22,
#    'id': 33185,
#    'cast_id': 34,
#    'credit_id': '54e9ef85c3a36836ed0043c2',
#    'name': 'Jeremy Bulloch',
#    'profile_path': '/yRnHoDmmWKdoLdiscCFfRpzzqMa.jpg',
#    'character': 'Boba Fett'},
#   {'order': 23,
#    'id': 137295,
#    'cast_id': 35,
#    'credit_id': '54e9f1219251412eb1004102',
#    'name': 'Femi Taylor',
#    'profile_path': '/565XzSM9ytiM62tUsY9lEsPMZSy.jpg',
#    'character': 'Oola'},
#   {'order': 24,
#    'id': 1430215,
#    'cast_id': 36,
#    'credit_id': '54e9f1769251412ebd0040c7',
#    'name': 'Annie Arbogast',
#    'profile_path': None,
#    'character': 'Sy Snootles'},
#   {'order': 25,
#    'id': 1218876,
#    'cast_id': 37,
#    'credit_id': '54e9f3c992514111b800358c',
#    'name': 'Claire Davenport',
#    'profile_path': '/AtPzM3Ot5jpO1CAHe92stDzebjI.jpg',
#    'character': 'Fat Dancer'},
#   {'order': 26,
#    'id': 132538,
#    'cast_id': 38,
#    'credit_id': '54e9f40ec3a36836d6003bc5',
#    'name': 'Jack Purvis',
#    'profile_path': '/tuFTY1jhlEgZm3vM80KdAEvHwNI.jpg',
#    'character': 'Teebo'},
#   {'order': 27,
#    'id': 1220451,
#    'cast_id': 39,
#    'credit_id': '54e9f5eec3a36836e00041c3',
#    'name': 'Mike Edmonds',
#    'profile_path': '/2sjtnY8P7OZF5L9smPK1grhZmCy.jpg',
#    'character': 'Logray'},
#   {'order': 28,
#    'id': 1430217,
#    'cast_id': 40,
#    'credit_id': '54e9f6cc9251412eae00428a',
#    'name': 'Jane Busby',
#    'profile_path': None,
#    'character': 'Chief Chirpa'},
#   {'order': 29,
#    'id': 995639,
#    'cast_id': 41,
#    'credit_id': '54e9f8fbc3a36836e0004210',
#    'name': 'Malcolm Dixon',
#    'profile_path': '/9Z4ZDKXe6S6gH9S361mM8wJd9Ai.jpg',
#    'character': 'Ewok Warrior'},
#   {'order': 30,
#    'id': 1430487,
#    'cast_id': 42,
#    'credit_id': '54eafc329251412ebd006453',
#    'name': 'Mike Cottrell',
#    'profile_path': None,
#    'character': 'Ewok Warrior'},
#   {'order': 31,
#    'id': 1430492,
#    'cast_id': 43,
#    'credit_id': '54eafe14c3a36836ea00661a',
#    'name': 'Nicki Reade',
#    'profile_path': None,
#    'character': 'Nicki'},
#   {'order': 32,
#    'id': 1430494,
#    'cast_id': 44,
#    'credit_id': '54eafec79251412eb40060b8',
#    'name': 'Adam Bareham',
#    'profile_path': None,
#    'character': 'Jhoff, a traffic control officer on the Executor'},
#   {'order': 33,
#    'id': 1430499,
#    'cast_id': 45,
#    'credit_id': '54eb00499251416824003867',
#    'name': 'Jonathan Oliver',
#    'profile_path': None,
#    'character': 'Stardestroyer Controller #2'},
#   {'order': 34,
#    'id': 110422,
#    'cast_id': 46,
#    'credit_id': '54eb0296c3a36836ea006699',
#    'name': 'Pip Miller',
#    'profile_path': None,
#    'character': 'Stardestroyer Captain #1'},
#   {'order': 35,
#    'id': 147482,
#    'cast_id': 47,
#    'credit_id': '54eb11d5c3a36836ed006b59',
#    'name': 'Tom Mannion',
#    'profile_path': '/fjJPHD96Jsko9w1M3vwINRVYoi9.jpg',
#    'character': 'Stardestroyer Captain #2'},
#   {'order': 36,
#    'id': 1430525,
#    'cast_id': 48,
#    'credit_id': '54eb1268c3a36836dc0069f6',
#    'name': 'Margo Apostolos',
#    'profile_path': '/g40OAFZPuOrRBDDfdpmofaNEarD.jpg',
#    'character': 'Ewok Tokkat'},
#   {'order': 37,
#    'id': 1430526,
#    'cast_id': 49,
#    'credit_id': '54eb139bc3a36836ed006b8b',
#    'name': 'Ray Armstrong',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 38,
#    'id': 1430527,
#    'cast_id': 50,
#    'credit_id': '54eb1439c3a36836e7006c0c',
#    'name': 'Eileen Baker',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 39,
#    'id': 1430528,
#    'cast_id': 51,
#    'credit_id': '54eb1525c3a36836ea006832',
#    'name': 'Michael Henbury Ballan',
#    'profile_path': '/FGuHVLOjg2im8TdKAgq5QqUmpP.jpg',
#    'character': 'Ewok'},
#   {'order': 40,
#    'id': 81414,
#    'cast_id': 52,
#    'credit_id': '54eb191ac3a36836dc006a91',
#    'name': 'Bobby Bell',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 41,
#    'id': 1430556,
#    'cast_id': 53,
#    'credit_id': '54eb1974c3a36836e0006773',
#    'name': 'Patty Bell',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 42,
#    'id': 1430564,
#    'cast_id': 54,
#    'credit_id': '54eb1afc9251412eb1006701',
#    'name': 'Alan Bennett',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 43,
#    'id': 1430565,
#    'cast_id': 55,
#    'credit_id': '54eb1c82c3a36836ea0068e6',
#    'name': 'Sarah Bennett',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 44,
#    'id': 1430566,
#    'cast_id': 56,
#    'credit_id': '54eb1d64c3a36810020010df',
#    'name': 'Pamela Betts',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 45,
#    'id': 1430567,
#    'cast_id': 57,
#    'credit_id': '54eb1de3c3a36810020010eb',
#    'name': 'Danny Blackner',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 46,
#    'id': 1430568,
#    'cast_id': 58,
#    'credit_id': '54eb1e4bc3a36836e7006d24',
#    'name': 'Linda Bowley',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 47,
#    'id': 1430569,
#    'cast_id': 59,
#    'credit_id': '54eb1f0fc3a36836ea006931',
#    'name': 'Peter Burroughs',
#    'profile_path': '/tsvjxgE4XdmuKTxQxF0s7ThQmkd.jpg',
#    'character': 'Ewok'},
#   {'order': 48,
#    'id': 19753,
#    'cast_id': 60,
#    'credit_id': '54eb207fc3a36836e000680e',
#    'name': 'Debbie Lee Carrington',
#    'profile_path': '/xMynWwkjNbBJsiPdjs8aJ977oBq.jpg',
#    'character': 'Romba an Ewok'},
#   {'order': 49,
#    'id': 1430576,
#    'cast_id': 61,
#    'credit_id': '54eb20d4c3a36836dc006b6b',
#    'name': 'Maureen Charlton',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 50,
#    'id': 1430580,
#    'cast_id': 62,
#    'credit_id': '54eb213e925141117c005f95',
#    'name': 'Willie Coppen',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 51,
#    'id': 121478,
#    'cast_id': 63,
#    'credit_id': '54eb22ca9251416824003b58',
#    'name': 'Sadie Corre',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 52,
#    'id': 19754,
#    'cast_id': 64,
#    'credit_id': '54eb2400c3a36836d9006559',
#    'name': 'Tony Cox',
#    'profile_path': '/5b7fTm33ZblMhMhnwK8KqTJ3nry.jpg',
#    'character': "Ewok Wicket's younger brother Widdle"},
#   {'order': 53,
#    'id': 1430588,
#    'cast_id': 65,
#    'credit_id': '54eb2b6d9251416824003c13',
#    'name': 'John Cumming',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 54,
#    'id': 1430590,
#    'cast_id': 66,
#    'credit_id': '54eb2be092514111b8005ba0',
#    'name': "Jean D'Agostino",
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 55,
#    'id': 106406,
#    'cast_id': 67,
#    'credit_id': '54eb2d909251416824003c4c',
#    'name': 'Luis De Jesus',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 56,
#    'id': 1430594,
#    'cast_id': 68,
#    'credit_id': '54eb2e06c3a36836d900661d',
#    'name': 'Debbie Dixon',
#    'profile_path': '/yQAcft0HcCx6GzYjNktnyff7LHp.jpg',
#    'character': 'Ewok Wijunkee'},
#   {'order': 57,
#    'id': 19756,
#    'cast_id': 69,
#    'credit_id': '54eb30749251412eb10068c8',
#    'name': 'Margarita Fernández',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 58,
#    'id': 12662,
#    'cast_id': 70,
#    'credit_id': '54eb30f09251412ebd00698b',
#    'name': 'Phil Fondacaro',
#    'profile_path': '/3Ao8VPvlytIm3DWFffdSPxwxFdC.jpg',
#    'character': 'Ewok'},
#   {'order': 59,
#    'id': 1430595,
#    'cast_id': 71,
#    'credit_id': '54eb316a92514111b8005c13',
#    'name': 'Sal Fondacaro',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 60,
#    'id': 1430596,
#    'cast_id': 72,
#    'credit_id': '54eb333fc3a36836d60062a8',
#    'name': 'Tony Friel',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 61,
#    'id': 19751,
#    'cast_id': 73,
#    'credit_id': '54eb3570c3a36836d90066b8',
#    'name': 'Daniel Frishman',
#    'profile_path': '/ly1pZwHpG74yXjAbjOFDgJqbVQS.jpg',
#    'character': 'Ewok'},
#   {'order': 62,
#    'id': 1430610,
#    'cast_id': 74,
#    'credit_id': '54eb49ca925141117c00634a',
#    'name': 'John Ghavan',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 63,
#    'id': 1224317,
#    'cast_id': 75,
#    'credit_id': '54eb4b5f9251412ebd006bfe',
#    'name': 'Michael Gilden',
#    'profile_path': '/lIF4AHqkogLnCO3xGDVKDPuHKOh.jpg',
#    'character': 'Ewok'},
#   {'order': 64,
#    'id': 1430611,
#    'cast_id': 76,
#    'credit_id': '54eb4c0cc3a36836dc006f4c',
#    'name': 'Paul Grant',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 65,
#    'id': 1430613,
#    'cast_id': 77,
#    'credit_id': '54eb4c899251412ebd006c19',
#    'name': 'Lydia Green',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 66,
#    'id': 1430615,
#    'cast_id': 78,
#    'credit_id': '54eb4cecc3a36810020014d0',
#    'name': 'Lars Green',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 67,
#    'id': 1430857,
#    'cast_id': 79,
#    'credit_id': '54ebb5bfc3a368676d00038a',
#    'name': 'Pam Grizz',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 68,
#    'id': 1430858,
#    'cast_id': 80,
#    'credit_id': '54ebb6639251417961000006',
#    'name': 'Andrew Herd',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 69,
#    'id': 1430859,
#    'cast_id': 81,
#    'credit_id': '54ebb779c3a3686d56000017',
#    'name': 'J.J. Jackson',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 70,
#    'id': 1430860,
#    'cast_id': 82,
#    'credit_id': '54ebb8639251417965000030',
#    'name': 'Richard Jones',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 71,
#    'id': 1430915,
#    'cast_id': 83,
#    'credit_id': '54ec25a9c3a3686d5e000ed1',
#    'name': 'Trevor Jones',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 72,
#    'id': 1430916,
#    'cast_id': 84,
#    'credit_id': '54ec2648c3a3686d58000f2a',
#    'name': 'Glynn Jones',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 73,
#    'id': 1430917,
#    'cast_id': 85,
#    'credit_id': '54ec28709251417971000fad',
#    'name': 'Karen Lay',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 74,
#    'id': 1430918,
#    'cast_id': 86,
#    'credit_id': '54ec28d9925141796100100a',
#    'name': 'John Lummiss',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 75,
#    'id': 1430919,
#    'cast_id': 87,
#    'credit_id': '54ec2970c3a3686d58000f8d',
#    'name': 'Nancy MacLean',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 76,
#    'id': 362851,
#    'cast_id': 88,
#    'credit_id': '54ec2a4fc3a3686d660011e0',
#    'name': 'Peter Mandell',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 77,
#    'id': 1430920,
#    'cast_id': 89,
#    'credit_id': '54ec2ab69251417971000fe4',
#    'name': 'Carole Morris',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 78,
#    'id': 1430921,
#    'cast_id': 90,
#    'credit_id': '54ec2affc3a3686d6d0010f8',
#    'name': 'Stacie Nichols',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 79,
#    'id': 1430922,
#    'cast_id': 91,
#    'credit_id': '54ec2ba3c3a3686d6400126d',
#    'name': 'Chris Nunn',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 80,
#    'id': 1430923,
#    'cast_id': 92,
#    'credit_id': '54ec2c05c3a3686d5600101b',
#    'name': "Barbara O'Laughlin",
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 81,
#    'id': 1430924,
#    'cast_id': 93,
#    'credit_id': '54ec2c68c3a3686d6400128b',
#    'name': 'Brian Orenstein',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 82,
#    'id': 1430925,
#    'cast_id': 94,
#    'credit_id': '54ec2cb1925141796e00108f',
#    'name': 'Harrell Parker Jr.',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 83,
#    'id': 1430926,
#    'cast_id': 95,
#    'credit_id': '54ec2d13c3a3686d6400129f',
#    'name': 'John Pedrick',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 84,
#    'id': 1430950,
#    'cast_id': 96,
#    'credit_id': '54ec33d1c3a3686d6d00120c',
#    'name': 'April Perkins',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 85,
#    'id': 1430951,
#    'cast_id': 97,
#    'credit_id': '54ec3433c3a3686d64001364',
#    'name': 'Ronnie Phillips',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 86,
#    'id': 1430952,
#    'cast_id': 98,
#    'credit_id': '54ec3593c3a3686d66001357',
#    'name': 'Katie Purvis',
#    'profile_path': '/2xCF8e5v7RwDaBYCpDAKVTFWFuf.jpg',
#    'character': 'Ewok'},
#   {'order': 87,
#    'id': 1430955,
#    'cast_id': 99,
#    'credit_id': '54ec3648c3a3680be600103a',
#    'name': 'Carol Read',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 88,
#    'id': 1430957,
#    'cast_id': 100,
#    'credit_id': '54ec36dfc3a3680be600104f',
#    'name': 'Nicholas Read',
#    'profile_path': '/7j0jdzXtTMARV9AD9zpMKmAYXJk.jpg',
#    'character': 'Ewok'},
#   {'order': 89,
#    'id': 1430958,
#    'cast_id': 101,
#    'credit_id': '54ec389dc3a3686d660013c2',
#    'name': 'Diana Reynolds',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 90,
#    'id': 1430961,
#    'cast_id': 102,
#    'credit_id': '54ec3aa9c3a3680be600109d',
#    'name': 'Danielle Rodgers',
#    'profile_path': None,
#    'character': 'Ewok Graak'},
#   {'order': 91,
#    'id': 1370759,
#    'cast_id': 103,
#    'credit_id': '54ec3c01c3a3686d6d001304',
#    'name': 'Chris Romano',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 92,
#    'id': 1430964,
#    'cast_id': 104,
#    'credit_id': '54ec3c3ac3a3680be60010cf',
#    'name': 'Dean Shackelford',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 93,
#    'id': 5531,
#    'cast_id': 105,
#    'credit_id': '54ec3ce3c3a3686d64001485',
#    'name': 'Kiran Shah',
#    'profile_path': '/oQer3lBnxD8gKFHoz7o7eJMF6od.jpg',
#    'character': 'Ewok'},
#   {'order': 94,
#    'id': 33853,
#    'cast_id': 106,
#    'credit_id': '54ec3e0fc3a3680b80001297',
#    'name': 'Felix Silla',
#    'profile_path': '/blKYI3w0lf124hvCaHiVcjhQpZ5.jpg',
#    'character': 'Ewok'},
#   {'order': 95,
#    'id': 1430978,
#    'cast_id': 107,
#    'credit_id': '54ec3e62c3a3686d5e001143',
#    'name': 'Linda Spriggs',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 96,
#    'id': 1430979,
#    'cast_id': 108,
#    'credit_id': '54ec3f34925141797100127a',
#    'name': 'Gerald Staddon',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 97,
#    'id': 1430980,
#    'cast_id': 109,
#    'credit_id': '54ec3fbb92514179710012a5',
#    'name': 'Josephine Staddon',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 98,
#    'id': 53760,
#    'cast_id': 110,
#    'credit_id': '54ec40ce9251417965001400',
#    'name': 'Kevin Thompson',
#    'profile_path': '/pUKpoqEjQg7Isu0dJFBtootlWad.jpg',
#    'character': 'Ewok'},
#   {'order': 99,
#    'id': 1430983,
#    'cast_id': 111,
#    'credit_id': '54ec4129c3a3686d660014ea',
#    'name': 'Kendra Wall',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 100,
#    'id': 224526,
#    'cast_id': 112,
#    'credit_id': '54ec4214c3a3680be6001170',
#    'name': 'Brian Wheeler',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 101,
#    'id': 1430984,
#    'cast_id': 113,
#    'credit_id': '54ec423b92514179680012dc',
#    'name': 'Butch Wilhelm',
#    'profile_path': None,
#    'character': 'Ewok'},
#   {'order': 102,
#    'id': 1430987,
#    'cast_id': 114,
#    'credit_id': '54ec4316c3a3686d56001369',
#    'name': 'Dalyn Chew',
#    'profile_path': '/weeQGjh3zA9uWmqoyixVAFXoVqg.jpg',
#    'character': 'Jedi Rocks Dancer (special edition)'},
#   {'order': 103,
#    'id': 1430991,
#    'cast_id': 115,
#    'credit_id': '54ec448fc3a3686d5600138c',
#    'name': 'Celia Fushille-Burke',
#    'profile_path': None,
#    'character': 'Greeata Jendowanian a Jedi Rocks Dancer (special edition)'},
#   {'order': 104,
#    'id': 1430994,
#    'cast_id': 116,
#    'credit_id': '54ec451b925141796100136a',
#    'name': 'Mercedes Ngoh',
#    'profile_path': None,
#    'character': 'Rystáll Sant a Jedi Rocks Dancer (special edition)'},
#   {'order': 105,
#    'id': 1430996,
#    'cast_id': 117,
#    'credit_id': '54ec460f925141796e001390',
#    'name': 'Jennifer Jaffe',
#    'profile_path': None,
#    'character': 'Jedi Rocks Dancer (special edition)'},
#   {'order': 106,
#    'id': 1473715,
#    'cast_id': 118,
#    'credit_id': '556f67909251410872000934',
#    'name': 'Mark Dodson',
#    'profile_path': None,
#    'character': 'Salacious B. Crumb'},
#   {'order': 107,
#    'id': 1473716,
#    'cast_id': 119,
#    'credit_id': '556f67fe9251413c01000594',
#    'name': 'Simon J. Williamson',
#    'profile_path': None,
#    'character': 'Max Rebo'},
#   {'order': 108,
#    'id': 1473717,
#    'cast_id': 120,
#    'credit_id': '556f6834c3a368106500078c',
#    'name': 'Richard Bonehill',
#    'profile_path': None,
#    'character': 'Nien Nunb'},
#   {'order': 109,
#    'id': 1473722,
#    'cast_id': 121,
#    'credit_id': '556f68db9251410861000841',
#    'name': 'David Gonzales',
#    'profile_path': None,
#    'character': 'Ak-rev'},
#   {'order': 110,
#    'id': 1473724,
#    'cast_id': 122,
#    'credit_id': '556f697bc3a3681062000916',
#    'name': 'Barrie Holland',
#    'profile_path': None,
#    'character': 'Renz'},
#   {'order': 111,
#    'id': 3307,
#    'cast_id': 124,
#    'credit_id': '5755d3809251412d6b0003b8',
#    'name': 'Peter Roy',
#    'profile_path': '/mKXyIKpFiD1hVU18jT7EeaVCeJT.jpg',
#    'character': 'Major Olander Brit - Rebel (uncredited)'},
#   {'order': 112,
#    'id': 1729665,
#    'cast_id': 128,
#    'credit_id': '58657539c3a36852c00254a5',
#    'name': 'Erik Bauersfeld',
#    'profile_path': None,
#    'character': 'Bib Fortuna (voice)'},
#   {'order': 113,
#    'id': 1249957,
#    'cast_id': 129,
#    'credit_id': '58657573c3a36852ba022b75',
#    'name': 'Mike Quinn',
#    'profile_path': '/2cZDfz3lUM23OVrapFFqSXjPe8j.jpg',
#    'character': 'Nein Nunb'},
#   {'order': 114,
#    'id': 1729666,
#    'cast_id': 130,
#    'credit_id': '586575979251412b87020d90',
#    'name': 'Bill Kipsang Rotich',
#    'profile_path': None,
#    'character': 'Nein Numb (voice)'},
#   {'order': 115,
#    'id': 1295,
#    'cast_id': 131,
#    'credit_id': '586575abc3a36852c9020e01',
#    'name': 'Deep Roy',
#    'profile_path': '/rCg84FP1x5tOutHKRB4OKhQeR4N.jpg',
#    'character': 'Droopy McCool'},
#   {'order': 116,
#    'id': 1729667,
#    'cast_id': 132,
#    'credit_id': '586575b89251412b840220d1',
#    'name': 'Alisa Berk',
#    'profile_path': None,
#    'character': 'Amanaman'},
#   {'order': 117,
#    'id': 1729668,
#    'cast_id': 133,
#    'credit_id': '586575d3c3a36852d201ebe7',
#    'name': 'Hugh Spight',
#    'profile_path': None,
#    'character': 'Gameorrean Guard/Elom/Mon Calamari'},
#   {'order': 118,
#    'id': 1729669,
#    'cast_id': 134,
#    'credit_id': '586575e29251412b8d021597',
#    'name': 'Swee Lim',
#    'profile_path': None,
#    'character': 'Attark the Hoover'},
#   {'order': 119,
#    'id': 106053,
#    'cast_id': 135,
#    'credit_id': '586575f09251412b84022110',
#    'name': 'Richard Robinson',
#    'profile_path': None,
#    'character': 'Yuzzum'},
#   {'order': 120,
#    'id': 1250666,
#    'cast_id': 136,
#    'credit_id': '58657600c3a36852c30253f7',
#    'name': 'Gerald Home',
#    'profile_path': None,
#    'character': 'Tessek'},
#   {'order': 121,
#    'id': 1436476,
#    'cast_id': 137,
#    'credit_id': '586576119251412b84022128',
#    'name': 'Phil Herbert',
#    'profile_path': None,
#    'character': 'Hermi Odle'},
#   {'order': 122,
#    'id': 1729670,
#    'cast_id': 138,
#    'credit_id': '58657620c3a3680ab601cf49',
#    'name': 'Tim Dry',
#    'profile_path': None,
#    'character': 'Whiphid'},
#   {'order': 123,
#    'id': 1729671,
#    'cast_id': 139,
#    'credit_id': '58657636c3a36852c0025571',
#    'name': 'Sean Crawford',
#    'profile_path': None,
#    'character': 'Whiphid'},
#   {'order': 124,
#    'id': 7727,
#    'cast_id': 140,
#    'credit_id': '5865b0c39251412b87024392',
#    'name': 'Phil Tippett',
#    'profile_path': '/2uQ0B7fN5cDQk17J1X3pxDSf9y.jpg',
#    'character': 'Rancor'},
#   {'order': 125,
#    'id': 163839,
#    'cast_id': 141,
#    'credit_id': '5865b0d49251412b7d023cbc',
#    'name': 'Michael McCormick',
#    'profile_path': None,
#    'character': 'Rancor'},
#   {'order': 126,
#    'id': 1590529,
#    'cast_id': 142,
#    'credit_id': '5865b2409251412b8d024b45',
#    'name': 'Toby Philpott',
#    'profile_path': None,
#    'character': 'Jabba the Hutt'},
#   {'order': 127,
#    'id': 1329519,
#    'cast_id': 143,
#    'credit_id': '5865b24e9251413cd6020d0f',
#    'name': 'David Alan Barclay',
#    'profile_path': None,
#    'character': 'Jabba the Hutt'},
#   {'order': 128,
#    'id': 159108,
#    'cast_id': 144,
#    'credit_id': '5865b2699251412b7b0269a0',
#    'name': 'Larry Ward',
#    'profile_path': '/zRqHcr0ySV1IJiDVmpciCokzn3h.jpg',
#    'character': 'Jabba the Hutt (voice)'}],
#  'budget': 32350000,
#  'production_countries': [{'name': 'United States of America',
#    'iso_3166_1': 'US'}],
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'vote_count': 3703,
#  'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#  'original_title': 'Return of the Jedi',
#  'overview': "As Rebel leaders map their strategy for an all-out attack on the Emperor's newer, bigger Death Star. Han Solo remains frozen in the cavernous desert fortress of Jabba the Hutt, the most loathsome outlaw in the universe, who is also keeping Princess Leia as a slave girl. Now a master of the Force, Luke Skywalker rescues his friends, but he cannot become a true Jedi Knight until he wages his own crucial battle against Darth Vader, who has sworn to win Luke over to the dark side of the Force.",
#  'adult': False,
#  'poster_path': '/jx5p0aHlbPXqe3AH9G15NvmWaqQ.jpg',
#  'production_companies': [{'name': 'Lucasfilm', 'id': 1},
#   {'name': 'Twentieth Century Fox Film Corporation', 'id': 306}],
#  'imdb_id': 'tt0086190',
#  'revenue': 572700000,
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vi-return-of-the-jedi'}

# %% [markdown]
# We'll add collection name, and reindex.

# %%
def add_collection_name(src_movie, base_doc):
    if 'belongs_to_collection' in src_movie and src_movie['belongs_to_collection'] is not None:
        if 'name' in src_movie['belongs_to_collection']:
            base_doc['collection_name_en'] = src_movie['belongs_to_collection']['name']
    return base_doc

from ltr.index import rebuild_tmdb
rebuild_tmdb(client, enrich=add_collection_name)
# Out:
# Deleted index tmdb [Status: 200]
# Created index tmdb [Status: 200]
# Reindexing...
# Indexed 0 movies (last Black Mirror: White Christmas)
# Indexed 100 movies (last Apocalypse Now)
# Indexed 200 movies (last Crooks in Clover)
# Indexed 300 movies (last For a Few Dollars More)
# Indexed 400 movies (last Downfall)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 500 movies (last Finding Nemo)
# Indexed 600 movies (last Platoon)
# Indexed 700 movies (last Night of the Living Dead)
# Indexed 800 movies (last Evangelion: 1.0: You Are (Not) Alone)
# Indexed 900 movies (last Batman: Assault on Arkham)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 1000 movies (last Riley's First Date?)
# Indexed 1100 movies (last The Raid)
# Indexed 1200 movies (last Falling Down)
# Indexed 1300 movies (last Kal Ho Naa Ho)
# Indexed 1400 movies (last Elizabeth)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 1500 movies (last Irreversible)
# Indexed 1600 movies (last Friday Night Lights)
# Indexed 1700 movies (last Ben X)
# Indexed 1800 movies (last Pump up the Volume)
# Indexed 1900 movies (last Armour of God)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 2000 movies (last Swingers)
# Indexed 2100 movies (last The Guard)
# Indexed 2200 movies (last Win Win)
# Indexed 2300 movies (last Where the Heart Is)
# Indexed 2400 movies (last UHF)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 2500 movies (last Jerry Maguire)
# Indexed 2600 movies (last Cloud Atlas)
# Indexed 2700 movies (last Rango)
# Indexed 2800 movies (last Rosewater)
# Indexed 2900 movies (last Kalifornia)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 3000 movies (last Bad Santa)
# Indexed 3100 movies (last Defendor)
# Indexed 3200 movies (last The Pirates! Band of Misfits)
# Indexed 3300 movies (last Sister Act)
# Indexed 3400 movies (last Live and Let Die)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 3500 movies (last Hours)
# Indexed 3600 movies (last Monsters)
# Indexed 3700 movies (last MouseHunt)
# Indexed 3800 movies (last Olympus Has Fallen)
# Indexed 3900 movies (last Godzilla)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 4000 movies (last Arbitrage)
# Indexed 4100 movies (last Under Siege)
# Indexed 4200 movies (last Underdogs)
# Indexed 4300 movies (last The Duke of Burgundy)
# Indexed 4400 movies (last Bambi II)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 4500 movies (last Solaris)
# Indexed 4600 movies (last The Stuff)
# Indexed 4700 movies (last Tales from the Darkside: The Movie)
# Indexed 4800 movies (last Final Fantasy: The Spirits Within)
# Indexed 4900 movies (last The Back-Up Plan)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 5000 movies (last Absolutely Anything)
# Indexed 5100 movies (last Funny People)
# Indexed 5200 movies (last Tad, the Lost Explorer)
# Indexed 5300 movies (last Fiston)
# Indexed 5400 movies (last The Reaping)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 5500 movies (last American Pie Presents: Beta House)
# Indexed 5600 movies (last Casino Royale)
# Indexed 5700 movies (last Jennifer's Body)
# Indexed 5800 movies (last Caligula)
# Indexed 5900 movies (last Alex Cross)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 6000 movies (last Rapture Palooza)
# Indexed 6100 movies (last The Seeker: The Dark Is Rising)
# Indexed 6200 movies (last Boogeyman)
# Indexed 6300 movies (last Fifty Shades of Black)
# Indexed 6400 movies (last Wilbur Wants to Kill Himself)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 6500 movies (last A Cruel Romance)
# Indexed 6600 movies (last La discrète)
# Indexed 6700 movies (last The Rapture)
# Indexed 6800 movies (last Ricky Gervais Live 3: Fame)
# Indexed 6900 movies (last Bunny Lake Is Missing)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 7000 movies (last Alice in the Cities)
# Indexed 7100 movies (last Le pélican)
# Indexed 7200 movies (last 20,000 Leagues Under the Sea)
# Indexed 7300 movies (last Deuces Wild)
# Indexed 7400 movies (last Lost Horizon)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 7500 movies (last The Detective 2)
# Indexed 7600 movies (last Absolute Aggression)
# Indexed 7700 movies (last A Fairly Odd Movie: Grow Up, Timmy Turner!)
# Indexed 7800 movies (last How Much Do You Love Me?)
# Indexed 7900 movies (last The Snows of Kilimanjaro)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 8000 movies (last The Wrong Guys)
# Indexed 8100 movies (last BFFs)
# Indexed 8200 movies (last Foreverland)
# Indexed 8300 movies (last Rebellion)
# Indexed 8400 movies (last Air Crew)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 8500 movies (last Down in the Valley)
# Indexed 8600 movies (last Female Agents)
# Indexed 8700 movies (last Come Dance with Me!)
# Indexed 8800 movies (last Versailles)
# Indexed 8900 movies (last Girls on Top)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 9000 movies (last Voll Normaaal)
# Indexed 9100 movies (last Unrated II: Scary as Hell)
# Indexed 9200 movies (last The Flight of the Phoenix)
# Indexed 9300 movies (last DragonHeart: A New Beginning)
# Indexed 9400 movies (last Empire of the Wolves)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 9500 movies (last Searching for Debra Winger)
# Indexed 9600 movies (last Swimming Pool)
# Indexed 9700 movies (last Bomber)
# Indexed 9800 movies (last Bullet in the Head)
# Indexed 9900 movies (last Club Fed)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 10000 movies (last Titus)
# Indexed 10100 movies (last Revolution)
# Indexed 10200 movies (last The Last Dispatch)
# Indexed 10300 movies (last Wings of Courage)
# Indexed 10400 movies (last Gaslight)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 10500 movies (last Frenchmen 2)
# Indexed 10600 movies (last Closing the Ring)
# Indexed 10700 movies (last 3:10 to Yuma)
# Indexed 10800 movies (last Harvest)
# Indexed 10900 movies (last Song of the Thin Man)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 11000 movies (last Nobody Knows Anything!)
# Indexed 11100 movies (last Dirty Deeds)
# Indexed 11200 movies (last The Adventure of Faustus Bidgood)
# Indexed 11300 movies (last Running Time)
# Indexed 11400 movies (last While She Was Out)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 11500 movies (last What?)
# Indexed 11600 movies (last The Legend of Hell House)
# Indexed 11700 movies (last When Worlds Collide)
# Indexed 11800 movies (last The Girl in the Red Velvet Swing)
# Indexed 11900 movies (last 9 Souls)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 12000 movies (last Paradise Lost 2: Revelations)
# Indexed 12100 movies (last Riki-Oh: The Story of Ricky)
# Indexed 12200 movies (last In Vogue: The Editor’s Eye)
# Indexed 12300 movies (last Smart Money)
# Indexed 12400 movies (last Manda Bala (Send a Bullet))
# Flushing 500 movies
# Done [Status: 200]
# Indexed 12500 movies (last Something to Talk About)
# Indexed 12600 movies (last Donald Glover: Weirdo)
# Indexed 12700 movies (last Demon Seed)
# Indexed 12800 movies (last Zig Zag)
# Indexed 12900 movies (last Going Overboard)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 13000 movies (last Mahler)
# Indexed 13100 movies (last Carriage to Vienna)
# Indexed 13200 movies (last The Big Clock)
# Indexed 13300 movies (last Arsenal)
# Indexed 13400 movies (last First Descent)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 13500 movies (last Deep Cover)
# Indexed 13600 movies (last Mixed Blood)
# Indexed 13700 movies (last Red Psalm)
# Indexed 13800 movies (last Bad Biology)
# Indexed 13900 movies (last Shirin)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 14000 movies (last Rhyme & Reason)
# Indexed 14100 movies (last Tuareg: Desert Warrior)
# Indexed 14200 movies (last Havoc)
# Indexed 14300 movies (last Fire Over England)
# Indexed 14400 movies (last Impulse)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 14500 movies (last Cheers For Miss Bishop)
# Indexed 14600 movies (last Don't Bother to Knock)
# Indexed 14700 movies (last Brides)
# Indexed 14800 movies (last The Land Before Time XI: Invasion of the Tinysauruses)
# Indexed 14900 movies (last The Gnome-Mobile)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 15000 movies (last Miracles: Mr. Canton and Lady Rose)
# Indexed 15100 movies (last An Occurrence at Owl Creek Bridge)
# Indexed 15200 movies (last 16 to Life)
# Indexed 15300 movies (last Week-End at the Waldorf)
# Indexed 15400 movies (last Made in Hong Kong)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 15500 movies (last Viva Cuba)
# Indexed 15600 movies (last Big Pun: The Legacy)
# Indexed 15700 movies (last Hurt)
# Indexed 15800 movies (last The Mudge Boy)
# Indexed 15900 movies (last The Hollywood Complex)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 16000 movies (last The Great Northfield Minnesota Raid)
# Indexed 16100 movies (last Lotta Leaves Home)
# Indexed 16200 movies (last Just One of the Girls)
# Indexed 16300 movies (last Which Way Is The Front Line From Here? The Life and Time of Tim Hetherington)
# Indexed 16400 movies (last The Ladies Man)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 16500 movies (last Assassin of the Tsar)
# Indexed 16600 movies (last The Adventures of Tarzan)
# Indexed 16700 movies (last Vendetta)
# Indexed 16800 movies (last Trucker)
# Indexed 16900 movies (last Branded)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 17000 movies (last Mariage à Mendoza)
# Indexed 17100 movies (last Love Bites)
# Indexed 17200 movies (last The Ballad of Ramblin' Jack)
# Indexed 17300 movies (last Blade of the Ripper)
# Indexed 17400 movies (last Kiler)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 17500 movies (last Kaïrat)
# Indexed 17600 movies (last Body Bags)
# Indexed 17700 movies (last Dave Attell: Captain Miserable)
# Indexed 17800 movies (last Wodehouse In Exile)
# Indexed 17900 movies (last Duel in the Sun)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 18000 movies (last The Message)
# Indexed 18100 movies (last Shock)
# Indexed 18200 movies (last Harvey)
# Indexed 18300 movies (last The Worthless)
# Indexed 18400 movies (last Queen of the Mountains)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 18500 movies (last Urgh! A Music War)
# Indexed 18600 movies (last Wuthering Heights)
# Indexed 18700 movies (last Gabriel Over the White House)
# Indexed 18800 movies (last Friendship!)
# Indexed 18900 movies (last Mía)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 19000 movies (last Danger! 50,000 Zombies)
# Indexed 19100 movies (last Top Dog)
# Indexed 19200 movies (last Reaching for the Moon)
# Indexed 19300 movies (last A Child's Christmas in Wales)
# Indexed 19400 movies (last The Dog Who Stopped the War)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 19500 movies (last Police Python 357)
# Indexed 19600 movies (last Accidents Happen)
# Indexed 19700 movies (last Changing Times)
# Indexed 19800 movies (last The Ape)
# Indexed 19900 movies (last Heartbreak Hotel)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 20000 movies (last Left Behind III: World at War)
# Indexed 20100 movies (last Dragon Ball Z: Lord Slug)
# Indexed 20200 movies (last The Adventures of Sherlock Holmes)
# Indexed 20300 movies (last Billy's Hollywood Screen Kiss)
# Indexed 20400 movies (last Short Night of Glass Dolls)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 20500 movies (last Kawa)
# Indexed 20600 movies (last Bears)
# Indexed 20700 movies (last Pyrates)
# Indexed 20800 movies (last Bastard Out of Carolina)
# Indexed 20900 movies (last The Mole People)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 21000 movies (last Till Human Voices Wake Us)
# Indexed 21100 movies (last It's a Wonderful Afterlife)
# Indexed 21200 movies (last The Bingo Long Traveling All-Stars & Motor Kings)
# Indexed 21300 movies (last Ciao! Manhattan)
# Indexed 21400 movies (last The Night They Raided Minsky's)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 21500 movies (last The Girl Can't Help It)
# Indexed 21600 movies (last Sam Peckinpah's West: Legacy of a Hollywood Renegade)
# Indexed 21700 movies (last A Guy Named Joe)
# Indexed 21800 movies (last Odd Man Out)
# Indexed 21900 movies (last The Rise of Catherine the Great)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 22000 movies (last The Girl of the Golden West)
# Indexed 22100 movies (last The Killing of John Lennon)
# Indexed 22200 movies (last Twist)
# Indexed 22300 movies (last After Life)
# Indexed 22400 movies (last The Great Ecstasy of Robert Carmichael)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 22500 movies (last Do Not Disturb)
# Indexed 22600 movies (last Something Real and Good)
# Indexed 22700 movies (last CBGB)
# Indexed 22800 movies (last California Solo)
# Indexed 22900 movies (last Richard III)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 23000 movies (last She's Out of Control)
# Indexed 23100 movies (last Dead End Drive-In)
# Indexed 23200 movies (last Venus Boyz)
# Indexed 23300 movies (last My Giant)
# Indexed 23400 movies (last The Beekeeper)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 23500 movies (last The Bobo)
# Indexed 23600 movies (last Amen)
# Indexed 23700 movies (last Favela Rising)
# Indexed 23800 movies (last The 4th Floor)
# Indexed 23900 movies (last Chisum)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 24000 movies (last Boulevard)
# Indexed 24100 movies (last Ingmar Bergman Makes a Movie)
# Indexed 24200 movies (last The Play House)
# Indexed 24300 movies (last Of Mice and Men)
# Indexed 24400 movies (last Dr. Gillespie's New Assistant)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 24500 movies (last Rat)
# Indexed 24600 movies (last Unstrung Heroes)
# Indexed 24700 movies (last Crazy Sexy Cancer)
# Indexed 24800 movies (last High and Dizzy)
# Indexed 24900 movies (last The Murder of Fred Hampton)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 25000 movies (last Holiday for Drumsticks)
# Indexed 25100 movies (last China Blue)
# Indexed 25200 movies (last Pancho, el perro millonario)
# Indexed 25300 movies (last The Diary of Anne Frank)
# Indexed 25400 movies (last To Be Twenty)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 25500 movies (last Empire of Silver)
# Indexed 25600 movies (last Knockout)
# Indexed 25700 movies (last Speed & Angels)
# Indexed 25800 movies (last Meek's Cutoff)
# Indexed 25900 movies (last Sharpe's Sword)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 26000 movies (last May 18)
# Indexed 26100 movies (last Dealer)
# Indexed 26200 movies (last Carmen Miranda: Bananas Is My Business)
# Indexed 26300 movies (last Il figlio dello sceicco)
# Indexed 26400 movies (last Muddy River)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 26500 movies (last Judy Moody and the Not Bummer Summer)
# Indexed 26600 movies (last The Naughty Room)
# Indexed 26700 movies (last Time Without Pity)
# Indexed 26800 movies (last L'outremangeur)
# Indexed 26900 movies (last Buddha Collapsed Out of Shame)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 27000 movies (last Uno contro l'altro praticamente amici)
# Indexed 27100 movies (last The Talent Given Us)
# Indexed 27200 movies (last Paris Trout)
# Indexed 27300 movies (last The Crystal Ball)
# Indexed 27400 movies (last West Is West)
# Flushing 500 movies
# Done [Status: 200]
# Indexed 27500 movies (last Breaktime)
# Indexed 27600 movies (last Two for the Seesaw)
# Indexed 27700 movies (last Fingers at the Window)
# Flushing 260 movies
#  'release_year': 1983,
#  'vote_average': 7.8,
#  'vote_count': 3703,
#  'collection_name_en': ['Star Wars Collection'],
#  '_version_': 1636163743022841856}

# %% [markdown]
# Add it to the features, and retrain....

# %%
config = [
    #1
    {
      "name" : "title_has_phrase",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:\"${keywords})\"^=1"
      }
    },
    #2
    {
      "name" : "title_has_terms",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:(${keywords})^=1"
      }
    },
    #3
    {
      "name" : "title_bm25",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "title:(${keywords})"
      }
    },
    #4
    {
      "name" : "overview_bm25",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:(${keywords})"
      }
    },
    #5
    {
      "name" : "overview_phrase_bm25",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "overview:\"${keywords}\""
      }
    },
    #6
    {
      "name" : "title_fuzzy",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!lucene df=title}${keywords}~"
      }
    },
    #7
    {
      "name" : "release_year",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "{!func}def(release_year,2000)"
      }
    },
    #8
    {
      "name" : "coll_name_bm25",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "collection_name_en:(${keywords})"
      }
    },
    #9
    {
      "name" : "coll_name_phrase_bm25",
      "store": "title2",
      "class" : "org.apache.solr.ltr.feature.SolrFeature",
      "params" : {
        "q" : "collection_name_en:\"${keywords}\""
      }
    }

]




from ltr import setup
setup(client, config=config, featureset='title2')

from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title2_judgments_train.txt', 
                                        featureSet='title2')
# Out:
# Deleted title Featurestore [Status: 200]
# Created title2 feature store under tmdb: [Status: 200]
# Recognizing 40 queries...
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rambo (0/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rocky (1/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for war games (2/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for crocodile dundee (3/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for matrix (4/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for contact (5/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for space jam (6/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for battlestar galactica (7/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for her (8/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for jobs (9/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for social network (10/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for rocky horror (11/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for shawshank redemption (12/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for french connection (13/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for star wars new hope (14/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for lego batman (15/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for crouching tiger hidden dragon (16/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for fight club (17/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for die hard (18/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for last temptation of christ (19/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for tree of life (20/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for murray saves christmas (21/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for black swan (22/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for emma (23/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for mad max fury road (24/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for kung fury (25/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for mr smith goes to washington (26/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for kill bill (27/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for the godfather (28/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for pulp fiction (29/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for christmas vacation (30/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for psycho (31/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for life is beautiful (32/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for dark knight (33/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for the green mile (34/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for forrest gump (35/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for top gun (36/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA for how to train your dragon (37/40)
# Searching tmdb [Status: 200]
# REBUILDING TRAINING DATA
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3, 4, 5, 6, 7, 8] TEST NDCG@10=0.9203
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3, 4, 5, 6, 7, 8] TEST NDCG@10=0.8961
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2, 3, 4, 5, 6, 7, 8] TEST NDCG@10=0.9203
#
# Impact of each feature on the model
# 4 - 18032.527656827504
# 3 - 9801.409052757816
# 5 - 8051.741259194476
# 7 - 5711.964176322393
# 8 - 3798.6132329430748
# 1 - 1439.2180228991883
# 0.9128
# 0.9169
# 0.9169
# 0.9169
# 0.9169
# 0.9169
# 0.9169
# 0.9219
# 0.9442
# 0.9441
# 0.9443
# 0.9445
# 0.9445
# 0.9445
# 0.9446
# 0.9453
# 0.9453
# 0.9459
# 0.9508
# 0.952
# Avg NDCG@10 when feature included:
# 1 => 0.8914843750000001
# 2 => 0.8640437499999999
# 3 => 0.8950625000000003
# 4 => 0.8539117187499999
# 5 => 0.8542335937500001
# 6 => 0.8903828125000001
# 7 => 0.8428093749999997
# 8 => 0.8637312499999996
# Avg K-Fold NDCG@10 0.9371

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title2_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=20,
                  trees=20,
                  features=[1,3,4,5,7,8],
                  featureSet='title2',
                  modelName='title2')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/title2_model.txt  -feature features.txt
# DONE
# Submit Model title2 Ftr Set title2 [Status: 200]
# Feature Set title2... [Status: 200]
# Deleted Model title2 [Status: 200]
# Created Model title2 [Status: 200]
#
# Impact of each feature on the model
# 3 - 45970.19084259676
# 4 - 14863.915643776061
# 5 - 6010.83353619383
# 8 - 5937.817286358266
# 1 - 1747.9503211101292
# 7 - 903.9746857424649
# 0.9169
# 0.9261
# 0.9226
# 0.9259
# 0.9265
# 0.9265
# 0.9265
# 0.9282
# 0.9282
# 0.9282
# 0.9422
# 0.9463
# 0.9465
# 0.9469
# 0.9465
# 0.9474
# 0.9482
# 0.9508
# 0.9508
# 0.951
# Train NDCG@10 0.951

# %%
from ltr import search
search(client, "cartoon with basketball aliens", modelName='title2')
# Out:
# Query {'fl': '*,... [Status: 200]
# ['Aliens']
# 0.3851549
# 1986
# ['Horror', 'Action', 'Thriller', 'Science Fiction']
# ["When Ripley's lifepod is found by a salvage crew over 50 years later, she finds that terra-formers are on the very planet they found the alien species. When the company sends a family of colonists out to investigate her story, all contact is lost with the planet and colonists. They enlist Ripley and the colonial marines to return and search for answers."]
# ---------------------------------------
# ['Strange Invaders']
# -0.009316988
# 1983
# ['Horror', 'Mystery', 'Science Fiction']
# ["Charlie's ex-wife disappears, and he goes to where she grew up--a rural town in the midwest--to look for her. But, surprisingly, nobody knows about her or any of her many relatives, the Newmans. He meets aliens; but when he contacts the FBI, they don't believe him. He tells his story to a tabloid; and suddenly, he is chased by the aliens."]
# ---------------------------------------
# ['Aliens in the Attic']
# -0.9036377
# 2009
# ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Science Fiction']
# ["It's summer vacation, but the Pearson family kids are stuck at a boring lake house with their nerdy parents. That is until feisty, little, green aliens crash-land on the roof, with plans to conquer the house AND Earth! Using only their wits, courage and video game-playing skills, the youngsters must band together to defeat the aliens and save the world - but the toughest part might be keeping the whole thing a secret from their parents! Featuring an all-star cast including Ashley Tisdale, Andy Richter, Kevin Nealon, Tim Meadows and Doris Roberts, Aliens In The Attic is the most fun you can have on this planet!"]
# ---------------------------------------
# ['Evil Aliens']
# -0.9036377
# 2006
# ['Comedy', 'Horror', 'Science Fiction']
# ['The sensationalist reporter Michelle Fox presents the TV show Weird World, with phony matters about UFOS and aliens. When she hears about Cat, a young woman that claims that have been abducted with her boyfriend and become pregnant by aliens, she convinces her chief to travel with a team to the remote Welsh island of Scalled to interview Cat. She invites the cameraman Ricky Anderson with his sound technician partner; the nerd expert in "ufology" and "ley lines" Gavin Gorman; the actress Candy Vixen and an obscure gay actor to prepare the matter. They get a van and wait for the low tide to reach the island, and when they find evidences that aliens are really landed in the location, the ambitious Michelle decides to film her way to fame and wealth.']
# ---------------------------------------
# ['Repo Man']
# -1.125594
# 1984
# ['Comedy', 'Drama', 'Science Fiction']
# ["A down and out young punk gets a job working with a seasoned repo man, but what awaits him in his new career is a series of outlandish adventures revolving around aliens, the CIA, and a most wanted '64 Chevy."]
# ---------------------------------------

# %%
config = {"validation": {
              "index": "tmdb",
              "params": {
                  "keywords": "rambo"
              }
    
           },
           "featureset": {
            "features": [
            {
                "name": "title_phrase",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                        "filter": {
                            "match_phrase": {"title": "{{keywords}}"}
                        },
                        "boost": 1.0
                    }  
                }
            },
 
            {
                "name": "overview_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"overview": "{{keywords}}"}
                }
            },
   
            {
                "name": "title_fuzzy",
                "params": ["keywords"],
                "template": {
                    "match": {"title": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            },
             {
                "name": "release_year",
                "params": [],
                "template": {
                    "function_score": {
                        "field_value_factor": {
                            "field": "release_year",
                            "missing": 2000
                        },
                        "query": { "match_all": {} }
                    }
                }
            },
            {
                "name": "coll_name_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {"collection_name": 
                                {"query": "{{keywords}}"}}
                }
            },
            {
                "name": "title_fuzzy_2",
                "params": ["keywords"],
                "template": {
                       "match": {"title.as_str": 
                                {"query": "{{keywords}}",
                                 "fuzziness": "AUTO"}}
                }
            }
            ]
    }}




from ltr import setup
setup(client, config=config, featureset='title2')

from ltr.log import judgments_to_training_set
trainingSet = judgments_to_training_set(client, 
                                        judgmentInFile='data/title_judgments.txt', 
                                        trainingOutFile='data/title2_judgments_train.txt', 
                                        featureSet='title2')
# Out:
# Removed Default LTR feature store [Status: 200]
# Initialize Default LTR feature store [Status: 200]
# Create title2 feature set [Status: 201]
# Recognizing 40 queries...
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for rambo (0/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for rocky (1/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for war games (2/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA for crocodile dundee (3/40)
# Searching tmdb - [{'terms': {'_id': [ [Status: 200]
# REBUILDING TRAINING DATA
#  'genres': ['Adventure', 'Action', 'Science Fiction'],
#  'release_date': '1983-05-23',
#  'release_year': '1983',
#  'vote_average': 7.8,
#  'vote_count': 3703,
#  'collection_name': 'Star Wars Collection'}

# %%
from ltr.train import feature_search
rankLibResult, ndcgPerFeature = feature_search(client,
                                               trainingInFile='data/title2_judgments_train.txt',
                                               metric2t='NDCG@10',
                                               leafs=20,
                                               trees=20,
                                               kcv=15,
                                               features=[1,2,3,4,5],
                                               featureSet='title2')

print()
print("Impact of each feature on the model")
trainLogs = rankLibResult.trainingLogs
for ftrId, impact in trainLogs[-1].impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLogs[-1].rounds:
    print(roundDcg)
    
print("Avg NDCG@10 when feature included:")
for ftrId, ndcg in ndcgPerFeature.items():
    print("%s => %s" % (ftrId, ndcg))
    
print("Avg K-Fold NDCG@10 %s" % rankLibResult.kcvTestAvg)
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1] TEST NDCG@10=0.8768
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2] TEST NDCG@10=0.6466
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [3] TEST NDCG@10=0.8244
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [4] TEST NDCG@10=0.5848
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [5] TEST NDCG@10=0.8231
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 2] TEST NDCG@10=0.8183
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 3] TEST NDCG@10=0.8739
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 4] TEST NDCG@10=0.8164
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [1, 5] TEST NDCG@10=0.8603
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 3] TEST NDCG@10=0.8209
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 4] TEST NDCG@10=0.6547
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# DONE
# Trying features [2, 5] TEST NDCG@10=0.7763
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/temp_model.txt  -feature features.txt  -kcv 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-6ba202dc3350> in <module>
#       7                                                kcv=15,
#       8                                                features=[1,2,3,4,5],
# ----> 9                                                featureSet='title2')
#      10
#      11 print()
#
# ~/ws/hello-ltr/ltr/train.py in feature_search(client, trainingInFile, featureSet, features, featureCost, metric2t, kcv, leafs, trees)
#      66                                        features=combination,
#      67                                        leafs=leafs,
# ---> 68                                        trees=trees)
#      69             kcvTestMetric = ranklibResult.kcvTestAvg
#      70             if featureCost != 0.0:
#
# ~/ws/hello-ltr/ltr/train.py in trainModel(training, out, features, kcv, leafs, trees, metric2t)
#      16
#      17     print("Running %s" % cmd)
# ---> 18     result = os.popen(cmd).read()
#      19     print("DONE")
#      20     return parse_training_log(result)
#
# KeyboardInterrupt:

# %%
from ltr import train
trainLog  = train(client,
                  trainingInFile='data/title2_judgments_train.txt',
                  metric2t='NDCG@10',
                  leafs=20,
                  trees=20,
                  featureSet='title2',
                  modelName='title2')

print()
print("Impact of each feature on the model")
for ftrId, impact in trainLog.impacts.items():
    print("{} - {}".format(ftrId, impact))
    
for roundDcg in trainLog.rounds:
    print(roundDcg)
    
print("Train NDCG@10 %s" % trainLog.rounds[-1])
# Out:
# Running java -jar data/RankyMcRankFace.jar -ranker 6 -metric2t NDCG@10 -tree 20 -leaf 20 -train data/title2_judgments_train.txt -save data/title2_model.txt
# DONE
# Delete model title2: 200
# Created Model title2 [Status: 201]
#
# Impact of each feature on the model
# 5 - 50.7142782913672
# 3 - 28.68541536598395
# 4 - 10.564775053159446
# 2 - 9.106621674916335
# 1 - 0.10494122264518205
# 0.9265
# 0.9269
# 0.9269
# 0.9269
# 0.9266
# 0.9266
# 0.9266
# 0.9374
# 0.9374
# 0.9374
# 0.9373
# 0.9363
# 0.9367
# 0.9402
# 0.9403
# 0.9466
# 0.9472
# 0.9474
# 0.9474
# 0.9474
# Train NDCG@10 0.9474

# %%
from ltr.client import ElasticClient
from ltr.MART_model import eval_model
from ltr.judgments import judgments_from_file, judgments_by_qid

features, _ = client.feature_set(index='tmdb', name='title2')

judgmentDict = judgments_by_qid(judgments_from_file(filename='data/title_judgments_train.txt'))

for qid, judgments in judgmentDict.items():

    model = eval_model(modelName='title2',
                           features=features,
                           judgments=judgments)

    print()
    print("## Evaluating graded docs for search keywords '%s'" % judgments[0].keywords)
    print()
    print(model)
# Out:
# Fetched FeatureSet title2 [Status: 200]
# Recognizing 40 queries...
#
# ## Evaluating graded docs for search keywords 'rambo'
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.2000(0/0/)
#       else:
#         <= 0.2000(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1662(0/0/)
#         else:
#           <= 0.2000(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1986.0:
#             <= 0.1551(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.2000(0/0/)
#             else:
#               <= 0.2000(2/1/qid:1:3(1370)-4(7555))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.2000(0/0/)
#           else:
#             if overview_bm25 > 0.0:
#               <= 0.2000(0/0/)
#             else:
#               <= 0.2000(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1750(0/0/)
#     else:
#       <= -0.0400(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.1329(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.1123(0/0/)
#       else:
#         <= 0.2000(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         <= -0.1533(0/0/)
#       else:
#         if title_fuzzy > 0.0:
#           <= -0.1997(0/0/)
#         else:
#           if release_year > 1975.0:
#             if release_year > 2004.0:
#               <= -0.1977(0/0/)
#             else:
#               <= -0.1708(0/0/)
#           else:
#             <= -0.1993(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1679(0/0/)
#       else:
#         <= 0.1702(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1402(0/0/)
#         else:
#           if release_year > 1999.0:
#             <= 0.1687(0/0/)
#           else:
#             <= 0.1678(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1988.0:
#             <= 0.0974(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.1710(0/0/)
#             else:
#               <= 0.1719(2/1/qid:1:3(1370)-4(7555))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1675(0/0/)
#           else:
#             if overview_bm25 > 0.0:
#               <= 0.1694(0/0/)
#             else:
#               <= 0.1717(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1508(0/0/)
#     else:
#       <= -0.0263(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0834(2/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.1731(1/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0847(0/0/)
#       else:
#         <= 0.1691(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.561186:
#           <= -0.1516(0/0/)
#         else:
#           <= 0.0632(0/0/)
#       else:
#         <= -0.1641(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1493(0/0/)
#       else:
#         <= 0.1525(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if title_fuzzy > 10.205917:
#           <= 0.1112(1/0/)
#         else:
#           <= 0.1486(1/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1501(0/0/)
#           else:
#             <= 0.1501(0/0/)
#         else:
#           if coll_name_bm25 > 5.534442:
#             if release_year > 1989.0:
#               <= 0.1289(0/0/)
#             else:
#               <= 0.1542(0/0/)
#           else:
#             if title_fuzzy > 10.351015:
#               <= 0.1488(0/0/)
#             else:
#               if overview_bm25 > 0.0:
#                 <= 0.1507(0/0/)
#               else:
#                 <= 0.1537(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1347(0/0/)
#     else:
#       <= -0.0219(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0716(2/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.1523(1/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0726(0/0/)
#       else:
#         <= 0.1504(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.561186:
#           <= -0.1394(0/0/)
#         else:
#           <= 0.0905(0/0/)
#       else:
#         <= -0.1456(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1372(0/0/)
#       else:
#         <= 0.1411(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1100(0/0/)
#         else:
#           if release_year > 1999.0:
#             <= 0.1382(0/0/)
#           else:
#             <= 0.1368(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1988.0:
#             <= 0.0698(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.1420(0/0/)
#             else:
#               <= 0.1439(2/1/qid:1:3(1370)-4(7555))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1367(0/0/)
#           else:
#             <= 0.1387(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1230(0/0/)
#     else:
#       <= -0.0183(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0624(2/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.1388(1/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0626(0/0/)
#       else:
#         <= 0.1383(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1312(0/0/)
#         else:
#           if title_fuzzy > 0.0:
#             <= -0.0393(0/0/)
#           else:
#             <= 0.1601(0/0/)
#       else:
#         <= -0.1332(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1290(0/0/)
#       else:
#         <= 0.1334(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if title_fuzzy > 9.627222:
#           <= 0.0890(1/0/)
#         else:
#           <= 0.1276(1/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 4.4819407:
#             <= 0.1301(0/0/)
#           else:
#             <= 0.1293(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1303(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.1090(0/0/)
#             else:
#               if release_year > 1960.0:
#                 <= 0.1301(0/0/)
#               else:
#                 <= 0.1359(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1140(0/0/)
#     else:
#       <= -0.0155(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0548(2/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.1299(1/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0550(0/0/)
#       else:
#         <= 0.1296(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1224(0/0/)
#         else:
#           <= 0.0617(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1289(0/0/)
#         else:
#           <= -0.1216(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 11.039184:
#         <= 0.1231(0/0/)
#       else:
#         <= 0.1279(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0423(0/0/)
#         else:
#           <= 0.1269(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1245(0/0/)
#           else:
#             <= 0.1230(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1247(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.1012(0/0/)
#             else:
#               if release_year > 1960.0:
#                 <= 0.1241(0/0/)
#               else:
#                 <= 0.1301(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1066(0/0/)
#     else:
#       <= -0.0130(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0741(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0481(0/0/)
#       else:
#         <= 0.1237(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1159(0/0/)
#         else:
#           <= 0.0535(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1227(0/0/)
#         else:
#           if release_year > 2004.0:
#             <= -0.1245(0/0/)
#           else:
#             <= -0.1052(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1187(0/0/)
#       else:
#         <= 0.1242(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0363(0/0/)
#         else:
#           <= 0.1225(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1202(0/0/)
#           else:
#             <= 0.1184(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1207(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0947(0/0/)
#             else:
#               if release_year > 1960.0:
#                 <= 0.1196(0/0/)
#               else:
#                 <= 0.1256(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1004(0/0/)
#     else:
#       <= -0.0108(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0672(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0418(0/0/)
#       else:
#         <= 0.1195(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1106(0/0/)
#         else:
#           <= 0.0460(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1181(0/0/)
#         else:
#           if release_year > 2007.0:
#             <= -0.1199(0/0/)
#           else:
#             <= -0.1001(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1155(0/0/)
#       else:
#         <= 0.1216(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0311(0/0/)
#         else:
#           <= 0.1194(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1157(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1178(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0891(0/0/)
#             else:
#               <= 0.1165(0/0/)
#   else:
#     if release_year > 2013.0:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0001(0/0/)
#       else:
#         <= 0.1282(0/0/)
#     else:
#       <= -0.0090(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0612(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0364(0/0/)
#       else:
#         <= 0.1163(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1179(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           if overview_bm25 > 5.561186:
#             <= -0.0781(0/0/)
#           else:
#             <= 0.1264(0/0/)
#         else:
#           if title_fuzzy > 4.4997454:
#             <= -0.1101(0/0/)
#           else:
#             if release_year > 1994.0:
#               <= -0.0626(0/0/)
#             else:
#               <= -0.1166(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1131(0/0/)
#       else:
#         <= 0.1198(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0264(0/0/)
#         else:
#           <= 0.1171(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1132(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1154(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0843(0/0/)
#             else:
#               <= 0.1138(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0905(0/0/)
#     else:
#       <= -0.0066(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0554(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       <= 0.0346(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1158(0/0/)
#       else:
#         if overview_bm25 > 5.0484333:
#           if overview_bm25 > 5.561186:
#             <= -0.0705(0/0/)
#           else:
#             <= 0.0621(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0919(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1123(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1247(0/0/)
#                 else:
#                   <= 0.0859(0/0/)
#           else:
#             <= -0.1151(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1129(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         <= 0.0716(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1114(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1137(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0795(0/0/)
#             else:
#               <= 0.1118(0/0/)
#   else:
#     if release_year > 2013.0:
#       if coll_name_bm25 > 7.0169497:
#         <= -0.0104(0/0/)
#       else:
#         <= 0.1224(0/0/)
#     else:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0592(1/0/)
#       else:
#         <= -0.1234(0/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0505(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0341(0/0/)
#       else:
#         <= 0.1123(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1132(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           <= -0.0223(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0862(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1100(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1218(0/0/)
#                 else:
#                   <= 0.0741(0/0/)
#           else:
#             <= -0.1089(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1118(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0151(0/0/)
#         else:
#           <= 0.1151(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1101(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1124(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0754(0/0/)
#             else:
#               <= 0.1101(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0798(0/0/)
#     else:
#       <= -0.0046(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0458(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0303(0/0/)
#       else:
#         <= 0.1102(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1110(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           if overview_bm25 > 5.561186:
#             <= -0.0621(0/0/)
#           else:
#             <= 0.1160(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0810(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1082(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1190(0/0/)
#                 else:
#                   <= 0.0647(0/0/)
#           else:
#             <= -0.1059(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1109(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0128(0/0/)
#         else:
#           <= 0.1141(2/1/qid:1:3(1370)-4(7555))
#       else:
#         if coll_name_bm25 > 8.589021:
#           <= 0.1214(0/0/)
#         else:
#           if title_fuzzy > 12.438508:
#             <= 0.1072(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0712(0/0/)
#             else:
#               <= 0.1077(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0760(0/0/)
#     else:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0530(1/0/)
#       else:
#         <= -0.1156(0/0/)
# else:
#   if coll_name_bm25 > 4.7166743:
#     if overview_bm25 > 9.023443:
#       <= 0.0863(0/0/)
#     else:
#       <= -0.0061(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if release_year > 2008.0:
#       <= -0.1103(0/0/)
#     else:
#       if overview_bm25 > 5.480549:
#         if overview_bm25 > 5.561186:
#           <= -0.0323(0/0/)
#         else:
#           <= 0.1129(0/0/)
#       else:
#         if release_year > 1994.0:
#           if release_year > 1995.0:
#             <= -0.0815(0/0/)
#           else:
#             if title_fuzzy > 0.0:
#               <= -0.1068(0/0/)
#             else:
#               if overview_bm25 > 0.0:
#                 <= -0.1174(0/0/)
#               else:
#                 <= 0.0566(0/0/)
#         else:
#           <= -0.1094(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1102(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0112(0/0/)
#         else:
#           if coll_name_bm25 > 8.589021:
#             <= 0.1110(0/0/)
#           else:
#             <= 0.1029(0/0/)
#       else:
#         <= 0.1128(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if overview_bm25 > 2.7658174:
#       <= 0.0523(0/0/)
#     else:
#       <= -0.0247(1/0/)
# else:
#   if coll_name_bm25 > 4.7166743:
#     <= 0.0229(3/1/qid:1:1(31362)-4(1368))
#   else:
#     if release_year > 2016.0:
#       <= -0.1393(0/0/)
#     else:
#       if overview_bm25 > 10.231711:
#         <= 0.0096(0/0/)
#       else:
#         if release_year > 2009.0:
#           <= -0.1069(0/0/)
#         else:
#           if overview_bm25 > 5.480549:
#             <= -0.0178(0/0/)
#           else:
#             if release_year > 1989.0:
#               if release_year > 2000.0:
#                 <= -0.0951(0/0/)
#               else:
#                 if release_year > 1999.0:
#                   <= 0.0848(0/0/)
#                 else:
#                   if release_year > 1995.0:
#                     <= -0.1139(0/0/)
#                   else:
#                     if release_year > 1994.0:
#                       if title_fuzzy > 0.0:
#                         <= -0.1057(0/0/)
#                       else:
#                         if overview_bm25 > 0.0:
#                           <= -0.1156(0/0/)
#                         else:
#                           <= 0.0496(0/0/)
#                     else:
#                       <= -0.0950(0/0/)
#             else:
#               <= -0.1086(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1097(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0098(0/0/)
#         else:
#           if coll_name_bm25 > 8.589021:
#             <= 0.1104(0/0/)
#           else:
#             <= 0.1016(0/0/)
#       else:
#         <= 0.1121(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if overview_bm25 > 2.7658174:
#       if overview_bm25 > 4.1906004:
#         <= 0.0210(0/0/)
#       else:
#         <= 0.1129(0/0/)
#     else:
#       <= -0.0272(1/0/)
# else:
#   if overview_bm25 > 9.023443:
#     if overview_bm25 > 11.016212:
#       <= -0.0916(0/0/)
#     else:
#       <= 0.0708(0/0/)
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0648(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1335(0/0/)
#       else:
#         if release_year > 2009.0:
#           <= -0.1060(0/0/)
#         else:
#           if overview_bm25 > 5.480549:
#             <= -0.0159(0/0/)
#           else:
#             if release_year > 1989.0:
#               if release_year > 1995.0:
#                 <= -0.0753(0/0/)
#               else:
#                 if release_year > 1994.0:
#                   if title_fuzzy > 0.0:
#                     <= -0.1048(0/0/)
#                   else:
#                     if overview_bm25 > 0.0:
#                       <= -0.1155(0/0/)
#                     else:
#                       <= 0.0427(0/0/)
#                 else:
#                   <= -0.0781(0/0/)
#             else:
#               <= -0.0987(38/1/qid:1:0(319074)-4(1368))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if title_fuzzy > 15.242714:
#       <= 0.1096(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0092(0/0/)
#         else:
#           <= 0.1016(0/0/)
#       else:
#         <= 0.1114(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0751(0/0/)
#     else:
#       <= -0.1044(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0809(3/1/qid:1:1(31362)-4(1368))
#     else:
#       if overview_bm25 > 9.023443:
#         <= 0.1024(0/0/)
#       else:
#         <= 0.0423(1/0/)
#   else:
#     if release_year > 2016.0:
#       <= -0.1311(0/0/)
#     else:
#       if overview_bm25 > 12.559557:
#         <= -0.1219(0/0/)
#       else:
#         if overview_bm25 > 10.231711:
#           <= 0.0373(0/0/)
#         else:
#           if overview_bm25 > 4.1612325:
#             if overview_bm25 > 4.1906004:
#               <= -0.0615(0/0/)
#             else:
#               <= 0.1115(0/0/)
#           else:
#             if title_phrase > 0.0:
#               <= -0.1079(0/0/)
#             else:
#               if release_year > 1989.0:
#                 if release_year > 2000.0:
#                   <= -0.0996(0/0/)
#                 else:
#                   if release_year > 1999.0:
#                     <= 0.1651(0/0/)
#                   else:
#                     if release_year > 1995.0:
#                       <= -0.1125(0/0/)
#                     else:
#                       <= -0.0017(0/0/)
#               else:
#                 <= -0.1045(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if title_fuzzy > 15.242714:
#       <= 0.1097(0/0/)
#     else:
#       if overview_bm25 > 7.6434507:
#         <= 0.0571(0/0/)
#       else:
#         if title_fuzzy > 14.381322:
#           <= 0.1036(0/0/)
#         else:
#           <= 0.1029(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0685(0/0/)
#     else:
#       <= -0.1038(0/0/)
# else:
#   if title_phrase > 0.0:
#     if overview_bm25 > 5.267714:
#       <= 0.0908(0/0/)
#     else:
#       if release_year > 2013.0:
#         <= 0.0641(0/0/)
#       else:
#         <= -0.0254(1/0/)
#   else:
#     if overview_bm25 > 9.023443:
#       <= 0.0206(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1258(0/0/)
#       else:
#         if coll_name_bm25 > 6.483505:
#           <= -0.0973(3/1/qid:1:1(31362)-4(1368))
#         else:
#           if release_year > 2009.0:
#             <= -0.1036(0/0/)
#           else:
#             if overview_bm25 > 5.1374836:
#               <= -0.0082(0/0/)
#             else:
#               if release_year > 1989.0:
#                 if release_year > 1995.0:
#                   <= -0.0703(0/0/)
#                 else:
#                   if release_year > 1994.0:
#                     if title_fuzzy > 0.0:
#                       <= -0.1039(0/0/)
#                     else:
#                       if overview_bm25 > 0.0:
#                         <= -0.1148(0/0/)
#                       else:
#                         <= 0.0355(0/0/)
#                   else:
#                     <= -0.0652(0/0/)
#               else:
#                 <= -0.0967(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.7032495:
#       <= 0.0649(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1208(0/0/)
#       else:
#         <= 0.0960(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0641(0/0/)
#     else:
#       <= -0.1034(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0694(3/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.0458(1/0/)
#   else:
#     if release_year > 2016.0:
#       <= -0.1240(0/0/)
#     else:
#       if overview_bm25 > 12.559557:
#         <= -0.1184(0/0/)
#       else:
#         if overview_bm25 > 10.231711:
#           <= 0.0286(0/0/)
#         else:
#           if release_year > 1982.0:
#             if release_year > 1983.0:
#               if title_phrase > 0.0:
#                 <= 0.0076(0/0/)
#               else:
#                 if release_year > 1989.0:
#                   if release_year > 2009.0:
#                     <= -0.1023(0/0/)
#                   else:
#                     if coll_name_bm25 > 0.0:
#                       <= -0.0877(0/0/)
#                     else:
#                       if overview_bm25 > 2.8000448:
#                         <= -0.0659(0/0/)
#                       else:
#                         if release_year > 2003.0:
#                           <= -0.0972(0/0/)
#                         else:
#                           if release_year > 1998.0:
#                             <= 0.0854(0/0/)
#                           else:
#                             <= -0.0177(0/0/)
#                 else:
#                   <= -0.1087(0/0/)
#             else:
#               <= 0.0733(0/0/)
#           else:
#             <= -0.0937(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0612(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1211(0/0/)
#       else:
#         <= 0.0942(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if coll_name_bm25 > 0.0:
#       <= 0.0582(0/0/)
#     else:
#       <= -0.1028(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0634(3/1/qid:1:1(31362)-4(1368))
#     else:
#       <= 0.0417(1/0/)
#   else:
#     if overview_bm25 > 4.1612325:
#       if overview_bm25 > 4.1906004:
#         if release_year > 1988.0:
#           <= -0.0878(0/0/)
#         else:
#           if release_year > 1986.0:
#             <= 0.1062(0/0/)
#           else:
#             <= -0.0111(0/0/)
#       else:
#         <= 0.1084(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1209(0/0/)
#       else:
#         if title_phrase > 0.0:
#           <= -0.1029(0/0/)
#         else:
#           if release_year > 1987.0:
#             if release_year > 2001.0:
#               <= -0.0947(0/0/)
#             else:
#               if release_year > 1999.0:
#                 <= 0.1159(0/0/)
#               else:
#                 if release_year > 1995.0:
#                   <= -0.1106(0/0/)
#                 else:
#                   if release_year > 1994.0:
#                     if overview_bm25 > 0.0:
#                       <= -0.1121(0/0/)
#                     else:
#                       <= 0.0202(0/0/)
#                   else:
#                     <= -0.0758(0/0/)
#           else:
#             <= -0.1011(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0577(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1214(0/0/)
#       else:
#         if release_year > 1989.0:
#           <= 0.0681(0/0/)
#         else:
#           <= 0.1094(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if release_year > 1977.0:
#       <= -0.0379(0/0/)
#     else:
#       if title_fuzzy > 8.941582:
#         <= 0.1377(0/0/)
#       else:
#         <= -0.1021(0/0/)
# else:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.0602207:
#       <= 0.0913(0/0/)
#     else:
#       if release_year > 2013.0:
#         <= 0.0621(0/0/)
#       else:
#         <= -0.0204(1/0/)
#   else:
#     if overview_bm25 > 9.023443:
#       <= 0.0133(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1175(0/0/)
#       else:
#         if coll_name_bm25 > 6.483505:
#           <= -0.0751(3/1/qid:1:1(31362)-4(1368))
#         else:
#           if overview_bm25 > 5.1374836:
#             <= -0.0260(0/0/)
#           else:
#             if release_year > 1987.0:
#               if release_year > 1995.0:
#                 <= -0.0836(0/0/)
#               else:
#                 if release_year > 1994.0:
#                   if overview_bm25 > 0.0:
#                     <= -0.1117(0/0/)
#                   else:
#                     if title_fuzzy > 0.0:
#                       <= -0.1027(0/0/)
#                     else:
#                       <= 0.0322(0/0/)
#                 else:
#                   <= -0.0779(0/0/)
#             else:
#               <= -0.0915(35/1/qid:1:0(319074)-1(61410))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0547(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1210(0/0/)
#       else:
#         <= 0.0906(2/1/qid:1:3(1370)-4(7555))
#   else:
#     if release_year > 1977.0:
#       <= -0.0324(0/0/)
#     else:
#       <= 0.0962(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if overview_bm25 > 5.8483677:
#       <= 0.0578(0/0/)
#     else:
#       <= -0.0158(4/1/qid:1:1(31362)-4(1368))
#   else:
#     if overview_bm25 > 12.559557:
#       <= -0.1143(0/0/)
#     else:
#       if overview_bm25 > 4.1612325:
#         if overview_bm25 > 4.1906004:
#           if release_year > 1988.0:
#             <= -0.0796(0/0/)
#           else:
#             if release_year > 1980.0:
#               <= 0.0768(0/0/)
#             else:
#               <= -0.0755(0/0/)
#         else:
#           <= 0.1065(0/0/)
#       else:
#         if release_year > 2016.0:
#           <= -0.1163(0/0/)
#         else:
#           if title_phrase > 0.0:
#             <= -0.0957(0/0/)
#           else:
#             if release_year > 1987.0:
#               if release_year > 2000.0:
#                 <= -0.0912(0/0/)
#               else:
#                 if release_year > 1999.0:
#                   <= 0.1320(0/0/)
#                 else:
#                   if release_year > 1995.0:
#                     <= -0.1099(0/0/)
#                   else:
#                     if release_year > 1994.0:
#                       <= 0.0107(0/0/)
#                     else:
#                       <= -0.0743(0/0/)
#             else:
#               <= -0.0973(35/1/qid:1:0(319074)-1(61410))
#
#
#
#
# ## Evaluating graded docs for search keywords 'rocky'
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.2000(0/0/)
#       else:
#         <= 0.2000(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1662(0/0/)
#         else:
#           <= 0.2000(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1986.0:
#             <= 0.1551(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.2000(0/0/)
#             else:
#               <= 0.2000(7/1/qid:2:3(1374)-4(1366))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.2000(0/0/)
#           else:
#             if overview_bm25 > 0.0:
#               <= 0.2000(0/0/)
#             else:
#               <= 0.2000(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1750(0/0/)
#     else:
#       <= -0.0400(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.1329(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.1123(0/0/)
#       else:
#         <= 0.2000(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         <= -0.1533(0/0/)
#       else:
#         if title_fuzzy > 0.0:
#           <= -0.1997(0/0/)
#         else:
#           if release_year > 1975.0:
#             if release_year > 2004.0:
#               <= -0.1977(0/0/)
#             else:
#               <= -0.1708(0/0/)
#           else:
#             <= -0.1993(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1679(0/0/)
#       else:
#         <= 0.1702(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1402(0/0/)
#         else:
#           if release_year > 1999.0:
#             <= 0.1687(0/0/)
#           else:
#             <= 0.1678(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1988.0:
#             <= 0.0974(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.1710(0/0/)
#             else:
#               <= 0.1719(7/1/qid:2:3(1374)-4(1366))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1675(0/0/)
#           else:
#             if overview_bm25 > 0.0:
#               <= 0.1694(0/0/)
#             else:
#               <= 0.1717(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1508(0/0/)
#     else:
#       <= -0.0263(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0834(0/0/)
#     else:
#       <= 0.1731(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0847(0/0/)
#       else:
#         <= 0.1691(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.561186:
#           <= -0.1516(0/0/)
#         else:
#           <= 0.0632(0/0/)
#       else:
#         <= -0.1641(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1493(0/0/)
#       else:
#         <= 0.1525(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if title_fuzzy > 10.205917:
#           <= 0.1112(0/0/)
#         else:
#           <= 0.1486(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1501(0/0/)
#           else:
#             <= 0.1501(0/0/)
#         else:
#           if coll_name_bm25 > 5.534442:
#             if release_year > 1989.0:
#               <= 0.1289(0/0/)
#             else:
#               <= 0.1542(7/1/qid:2:3(1374)-4(1366))
#           else:
#             if title_fuzzy > 10.351015:
#               <= 0.1488(0/0/)
#             else:
#               if overview_bm25 > 0.0:
#                 <= 0.1507(0/0/)
#               else:
#                 <= 0.1537(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1347(0/0/)
#     else:
#       <= -0.0219(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0716(0/0/)
#     else:
#       <= 0.1523(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0726(0/0/)
#       else:
#         <= 0.1504(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.561186:
#           <= -0.1394(0/0/)
#         else:
#           <= 0.0905(0/0/)
#       else:
#         <= -0.1456(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1372(0/0/)
#       else:
#         <= 0.1411(0/0/)
#     else:
#       if title_fuzzy > 12.438508:
#         if overview_bm25 > 6.635092:
#           <= 0.1100(0/0/)
#         else:
#           if release_year > 1999.0:
#             <= 0.1382(0/0/)
#           else:
#             <= 0.1368(0/0/)
#       else:
#         if coll_name_bm25 > 5.534442:
#           if release_year > 1988.0:
#             <= 0.0698(0/0/)
#           else:
#             if release_year > 1960.0:
#               <= 0.1420(0/0/)
#             else:
#               <= 0.1439(7/1/qid:2:3(1374)-4(1366))
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1367(0/0/)
#           else:
#             <= 0.1387(0/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1230(0/0/)
#     else:
#       <= -0.0183(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0624(0/0/)
#     else:
#       <= 0.1388(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0626(0/0/)
#       else:
#         <= 0.1383(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1312(0/0/)
#         else:
#           if title_fuzzy > 0.0:
#             <= -0.0393(0/0/)
#           else:
#             <= 0.1601(0/0/)
#       else:
#         <= -0.1332(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1290(0/0/)
#       else:
#         <= 0.1334(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if title_fuzzy > 9.627222:
#           <= 0.0890(0/0/)
#         else:
#           <= 0.1276(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 4.4819407:
#             <= 0.1301(0/0/)
#           else:
#             <= 0.1293(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1303(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.1090(6/1/qid:2:3(1374)-4(1366))
#             else:
#               if release_year > 1960.0:
#                 <= 0.1301(0/0/)
#               else:
#                 <= 0.1359(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1140(0/0/)
#     else:
#       <= -0.0155(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     if coll_name_bm25 > 7.098384:
#       <= 0.0548(0/0/)
#     else:
#       <= 0.1299(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0550(0/0/)
#       else:
#         <= 0.1296(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1224(0/0/)
#         else:
#           <= 0.0617(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1289(0/0/)
#         else:
#           <= -0.1216(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 11.039184:
#         <= 0.1231(0/0/)
#       else:
#         <= 0.1279(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0423(0/0/)
#         else:
#           <= 0.1269(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1245(0/0/)
#           else:
#             <= 0.1230(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1247(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.1012(6/1/qid:2:3(1374)-4(1366))
#             else:
#               if release_year > 1960.0:
#                 <= 0.1241(0/0/)
#               else:
#                 <= 0.1301(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1066(0/0/)
#     else:
#       <= -0.0130(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0741(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0481(0/0/)
#       else:
#         <= 0.1237(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1159(0/0/)
#         else:
#           <= 0.0535(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1227(0/0/)
#         else:
#           if release_year > 2004.0:
#             <= -0.1245(0/0/)
#           else:
#             <= -0.1052(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1187(0/0/)
#       else:
#         <= 0.1242(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0363(0/0/)
#         else:
#           <= 0.1225(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           if coll_name_bm25 > 0.0:
#             <= 0.1202(0/0/)
#           else:
#             <= 0.1184(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1207(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0947(6/1/qid:2:3(1374)-4(1366))
#             else:
#               if release_year > 1960.0:
#                 <= 0.1196(0/0/)
#               else:
#                 <= 0.1256(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.1004(0/0/)
#     else:
#       <= -0.0108(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0672(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0418(0/0/)
#       else:
#         <= 0.1195(0/0/)
#     else:
#       if overview_bm25 > 5.124458:
#         if overview_bm25 > 5.6021028:
#           <= -0.1106(0/0/)
#         else:
#           <= 0.0460(0/0/)
#       else:
#         if title_fuzzy > 4.4997454:
#           <= -0.1181(0/0/)
#         else:
#           if release_year > 2007.0:
#             <= -0.1199(0/0/)
#           else:
#             <= -0.1001(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.623374:
#         <= 0.1155(0/0/)
#       else:
#         <= 0.1216(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0311(0/0/)
#         else:
#           <= 0.1194(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1157(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1178(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0891(6/1/qid:2:3(1374)-4(1366))
#             else:
#               <= 0.1165(1/0/)
#   else:
#     if release_year > 2013.0:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0001(0/0/)
#       else:
#         <= 0.1282(0/0/)
#     else:
#       <= -0.0090(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0612(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0364(0/0/)
#       else:
#         <= 0.1163(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1179(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           if overview_bm25 > 5.561186:
#             <= -0.0781(0/0/)
#           else:
#             <= 0.1264(0/0/)
#         else:
#           if title_fuzzy > 4.4997454:
#             <= -0.1101(0/0/)
#           else:
#             if release_year > 1994.0:
#               <= -0.0626(0/0/)
#             else:
#               <= -0.1166(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       if coll_name_bm25 > 10.359029:
#         <= 0.1131(0/0/)
#       else:
#         <= 0.1198(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0264(0/0/)
#         else:
#           <= 0.1171(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1132(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1154(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0843(6/1/qid:2:3(1374)-4(1366))
#             else:
#               <= 0.1138(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0905(0/0/)
#     else:
#       <= -0.0066(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0554(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       <= 0.0346(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1158(0/0/)
#       else:
#         if overview_bm25 > 5.0484333:
#           if overview_bm25 > 5.561186:
#             <= -0.0705(0/0/)
#           else:
#             <= 0.0621(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0919(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1123(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1247(0/0/)
#                 else:
#                   <= 0.0859(0/0/)
#           else:
#             <= -0.1151(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1129(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         <= 0.0716(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1114(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1137(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0795(6/1/qid:2:3(1374)-4(1366))
#             else:
#               <= 0.1118(1/0/)
#   else:
#     if release_year > 2013.0:
#       if coll_name_bm25 > 7.0169497:
#         <= -0.0104(0/0/)
#       else:
#         <= 0.1224(0/0/)
#     else:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0592(2/0/)
#       else:
#         <= -0.1234(1/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0505(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0341(0/0/)
#       else:
#         <= 0.1123(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1132(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           <= -0.0223(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0862(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1100(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1218(0/0/)
#                 else:
#                   <= 0.0741(0/0/)
#           else:
#             <= -0.1089(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1118(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0151(0/0/)
#         else:
#           <= 0.1151(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1101(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1124(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0754(6/1/qid:2:3(1374)-4(1366))
#             else:
#               <= 0.1101(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0798(0/0/)
#     else:
#       <= -0.0046(3/0/)
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0458(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0303(0/0/)
#       else:
#         <= 0.1102(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1110(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           if overview_bm25 > 5.561186:
#             <= -0.0621(0/0/)
#           else:
#             <= 0.1160(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0810(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1082(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1190(0/0/)
#                 else:
#                   <= 0.0647(0/0/)
#           else:
#             <= -0.1059(31/1/qid:2:0(2153)-1(47059))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1109(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0128(0/0/)
#         else:
#           <= 0.1141(0/0/)
#       else:
#         if coll_name_bm25 > 8.589021:
#           <= 0.1214(4/1/qid:2:3(1374)-4(1366))
#         else:
#           if title_fuzzy > 12.438508:
#             <= 0.1072(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0712(2/0/)
#             else:
#               <= 0.1077(1/0/)
#   else:
#     if release_year > 2013.0:
#       <= 0.0760(0/0/)
#     else:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0530(2/0/)
#       else:
#         <= -0.1156(1/0/)
# else:
# ...
#                 else:
#                   <= 0.0741(0/0/)
#           else:
#             <= -0.1089(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1118(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0151(0/0/)
#         else:
#           <= 0.1151(0/0/)
#       else:
#         if title_fuzzy > 12.438508:
#           <= 0.1101(0/0/)
#         else:
#           if title_fuzzy > 10.351015:
#             <= 0.1124(1/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0754(0/0/)
#             else:
#               <= 0.1101(2/1/qid:40:2(12180)-3(140607))
#   else:
#     if release_year > 2013.0:
#       <= 0.0798(0/0/)
#     else:
#       <= -0.0046(2/1/qid:40:2(1895)-3(330459))
# else:
#   if coll_name_bm25 > 6.483505:
#     <= 0.0458(0/0/)
#   else:
#     if overview_bm25 > 10.231711:
#       if overview_bm25 > 10.630764:
#         <= -0.0303(0/0/)
#       else:
#         <= 0.1102(0/0/)
#     else:
#       if release_year > 2007.0:
#         <= -0.1110(0/0/)
#       else:
#         if overview_bm25 > 5.1374836:
#           if overview_bm25 > 5.561186:
#             <= -0.0621(0/0/)
#           else:
#             <= 0.1160(0/0/)
#         else:
#           if release_year > 1994.0:
#             if release_year > 1995.0:
#               <= -0.0810(0/0/)
#             else:
#               if title_fuzzy > 0.0:
#                 <= -0.1082(0/0/)
#               else:
#                 if overview_bm25 > 0.0:
#                   <= -0.1190(0/0/)
#                 else:
#                   <= 0.0647(0/0/)
#           else:
#             <= -0.1059(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1109(0/0/)
#     else:
#       if coll_name_bm25 > 10.0618925:
#         if release_year > 1988.0:
#           <= 0.0128(0/0/)
#         else:
#           <= 0.1141(0/0/)
#       else:
#         if coll_name_bm25 > 8.589021:
#           <= 0.1214(0/0/)
#         else:
#           if title_fuzzy > 12.438508:
#             <= 0.1072(0/0/)
#           else:
#             if coll_name_bm25 > 6.6532726:
#               <= 0.0712(0/0/)
#             else:
#               <= 0.1077(3/1/qid:40:2(12180)-4(11))
#   else:
#     if release_year > 2013.0:
#       <= 0.0760(0/0/)
#     else:
#       if coll_name_bm25 > 4.836267:
#         <= 0.0530(0/0/)
#       else:
#         <= -0.1156(2/1/qid:40:2(1895)-3(330459))
# else:
#   if coll_name_bm25 > 4.7166743:
#     if overview_bm25 > 9.023443:
#       <= 0.0863(0/0/)
#     else:
#       <= -0.0061(0/0/)
#   else:
#     if release_year > 2008.0:
#       <= -0.1103(0/0/)
#     else:
#       if overview_bm25 > 5.480549:
#         if overview_bm25 > 5.561186:
#           <= -0.0323(0/0/)
#         else:
#           <= 0.1129(0/0/)
#       else:
#         if release_year > 1994.0:
#           if release_year > 1995.0:
#             <= -0.0815(0/0/)
#           else:
#             if title_fuzzy > 0.0:
#               <= -0.1068(0/0/)
#             else:
#               if overview_bm25 > 0.0:
#                 <= -0.1174(0/0/)
#               else:
#                 <= 0.0566(0/0/)
#         else:
#           <= -0.1094(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1102(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0112(0/0/)
#         else:
#           if coll_name_bm25 > 8.589021:
#             <= 0.1110(0/0/)
#           else:
#             <= 0.1029(0/0/)
#       else:
#         <= 0.1128(3/1/qid:40:2(12180)-4(11))
#   else:
#     if overview_bm25 > 2.7658174:
#       <= 0.0523(0/0/)
#     else:
#       <= -0.0247(2/1/qid:40:2(1895)-3(330459))
# else:
#   if coll_name_bm25 > 4.7166743:
#     <= 0.0229(0/0/)
#   else:
#     if release_year > 2016.0:
#       <= -0.1393(0/0/)
#     else:
#       if overview_bm25 > 10.231711:
#         <= 0.0096(0/0/)
#       else:
#         if release_year > 2009.0:
#           <= -0.1069(0/0/)
#         else:
#           if overview_bm25 > 5.480549:
#             <= -0.0178(0/0/)
#           else:
#             if release_year > 1989.0:
#               if release_year > 2000.0:
#                 <= -0.0951(0/0/)
#               else:
#                 if release_year > 1999.0:
#                   <= 0.0848(0/0/)
#                 else:
#                   if release_year > 1995.0:
#                     <= -0.1139(0/0/)
#                   else:
#                     if release_year > 1994.0:
#                       if title_fuzzy > 0.0:
#                         <= -0.1057(0/0/)
#                       else:
#                         if overview_bm25 > 0.0:
#                           <= -0.1156(0/0/)
#                         else:
#                           <= 0.0496(0/0/)
#                     else:
#                       <= -0.0950(0/0/)
#             else:
#               <= -0.1086(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_phrase > 0.0:
#   if title_fuzzy > 7.637577:
#     if title_fuzzy > 15.242714:
#       <= 0.1097(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0098(0/0/)
#         else:
#           if coll_name_bm25 > 8.589021:
#             <= 0.1104(0/0/)
#           else:
#             <= 0.1016(0/0/)
#       else:
#         <= 0.1121(3/1/qid:40:2(12180)-4(11))
#   else:
#     if overview_bm25 > 2.7658174:
#       if overview_bm25 > 4.1906004:
#         <= 0.0210(0/0/)
#       else:
#         <= 0.1129(0/0/)
#     else:
#       <= -0.0272(2/1/qid:40:2(1895)-3(330459))
# else:
#   if overview_bm25 > 9.023443:
#     if overview_bm25 > 11.016212:
#       <= -0.0916(0/0/)
#     else:
#       <= 0.0708(0/0/)
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0648(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1335(0/0/)
#       else:
#         if release_year > 2009.0:
#           <= -0.1060(0/0/)
#         else:
#           if overview_bm25 > 5.480549:
#             <= -0.0159(0/0/)
#           else:
#             if release_year > 1989.0:
#               if release_year > 1995.0:
#                 <= -0.0753(0/0/)
#               else:
#                 if release_year > 1994.0:
#                   if title_fuzzy > 0.0:
#                     <= -0.1048(0/0/)
#                   else:
#                     if overview_bm25 > 0.0:
#                       <= -0.1155(0/0/)
#                     else:
#                       <= 0.0427(0/0/)
#                 else:
#                   <= -0.0781(0/0/)
#             else:
#               <= -0.0987(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if title_fuzzy > 15.242714:
#       <= 0.1096(0/0/)
#     else:
#       if release_year > 1989.0:
#         if coll_name_bm25 > 10.0618925:
#           <= 0.0092(0/0/)
#         else:
#           <= 0.1016(0/0/)
#       else:
#         <= 0.1114(3/1/qid:40:2(12180)-4(11))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0751(0/0/)
#     else:
#       <= -0.1044(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0809(0/0/)
#     else:
#       if overview_bm25 > 9.023443:
#         <= 0.1024(0/0/)
#       else:
#         <= 0.0423(0/0/)
#   else:
#     if release_year > 2016.0:
#       <= -0.1311(0/0/)
#     else:
#       if overview_bm25 > 12.559557:
#         <= -0.1219(0/0/)
#       else:
#         if overview_bm25 > 10.231711:
#           <= 0.0373(0/0/)
#         else:
#           if overview_bm25 > 4.1612325:
#             if overview_bm25 > 4.1906004:
#               <= -0.0615(0/0/)
#             else:
#               <= 0.1115(0/0/)
#           else:
#             if title_phrase > 0.0:
#               <= -0.1079(2/1/qid:40:2(1895)-3(330459))
#             else:
#               if release_year > 1989.0:
#                 if release_year > 2000.0:
#                   <= -0.0996(0/0/)
#                 else:
#                   if release_year > 1999.0:
#                     <= 0.1651(0/0/)
#                   else:
#                     if release_year > 1995.0:
#                       <= -0.1125(0/0/)
#                     else:
#                       <= -0.0017(0/0/)
#               else:
#                 <= -0.1045(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if title_fuzzy > 15.242714:
#       <= 0.1097(0/0/)
#     else:
#       if overview_bm25 > 7.6434507:
#         <= 0.0571(0/0/)
#       else:
#         if title_fuzzy > 14.381322:
#           <= 0.1036(0/0/)
#         else:
#           <= 0.1029(3/1/qid:40:2(12180)-4(11))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0685(0/0/)
#     else:
#       <= -0.1038(0/0/)
# else:
#   if title_phrase > 0.0:
#     if overview_bm25 > 5.267714:
#       <= 0.0908(0/0/)
#     else:
#       if release_year > 2013.0:
#         <= 0.0641(0/0/)
#       else:
#         <= -0.0254(2/1/qid:40:2(1895)-3(330459))
#   else:
#     if overview_bm25 > 9.023443:
#       <= 0.0206(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1258(0/0/)
#       else:
#         if coll_name_bm25 > 6.483505:
#           <= -0.0973(0/0/)
#         else:
#           if release_year > 2009.0:
#             <= -0.1036(0/0/)
#           else:
#             if overview_bm25 > 5.1374836:
#               <= -0.0082(0/0/)
#             else:
#               if release_year > 1989.0:
#                 if release_year > 1995.0:
#                   <= -0.0703(0/0/)
#                 else:
#                   if release_year > 1994.0:
#                     if title_fuzzy > 0.0:
#                       <= -0.1039(0/0/)
#                     else:
#                       if overview_bm25 > 0.0:
#                         <= -0.1148(0/0/)
#                       else:
#                         <= 0.0355(0/0/)
#                   else:
#                     <= -0.0652(0/0/)
#               else:
#                 <= -0.0967(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.7032495:
#       <= 0.0649(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1208(0/0/)
#       else:
#         <= 0.0960(3/1/qid:40:2(12180)-4(11))
#   else:
#     if title_fuzzy > 9.683941:
#       <= 0.0641(0/0/)
#     else:
#       <= -0.1034(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0694(0/0/)
#     else:
#       <= 0.0458(0/0/)
#   else:
#     if release_year > 2016.0:
#       <= -0.1240(0/0/)
#     else:
#       if overview_bm25 > 12.559557:
#         <= -0.1184(0/0/)
#       else:
#         if overview_bm25 > 10.231711:
#           <= 0.0286(0/0/)
#         else:
#           if release_year > 1982.0:
#             if release_year > 1983.0:
#               if title_phrase > 0.0:
#                 <= 0.0076(0/0/)
#               else:
#                 if release_year > 1989.0:
#                   if release_year > 2009.0:
#                     <= -0.1023(0/0/)
#                   else:
#                     if coll_name_bm25 > 0.0:
#                       <= -0.0877(0/0/)
#                     else:
#                       if overview_bm25 > 2.8000448:
#                         <= -0.0659(0/0/)
#                       else:
#                         if release_year > 2003.0:
#                           <= -0.0972(0/0/)
#                         else:
#                           if release_year > 1998.0:
#                             <= 0.0854(0/0/)
#                           else:
#                             <= -0.0177(0/0/)
#                 else:
#                   <= -0.1087(0/0/)
#             else:
#               <= 0.0733(0/0/)
#           else:
#             <= -0.0937(27/1/qid:40:0(85783)-3(330459))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0612(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1211(0/0/)
#       else:
#         <= 0.0942(3/1/qid:40:2(12180)-4(11))
#   else:
#     if coll_name_bm25 > 0.0:
#       <= 0.0582(0/0/)
#     else:
#       <= -0.1028(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if coll_name_bm25 > 7.098384:
#       <= -0.0634(0/0/)
#     else:
#       <= 0.0417(0/0/)
#   else:
#     if overview_bm25 > 4.1612325:
#       if overview_bm25 > 4.1906004:
#         if release_year > 1988.0:
#           <= -0.0878(0/0/)
#         else:
#           if release_year > 1986.0:
#             <= 0.1062(0/0/)
#           else:
#             <= -0.0111(0/0/)
#       else:
#         <= 0.1084(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1209(0/0/)
#       else:
#         if title_phrase > 0.0:
#           <= -0.1029(2/1/qid:40:2(1895)-3(330459))
#         else:
#           if release_year > 1987.0:
#             if release_year > 2001.0:
#               <= -0.0947(0/0/)
#             else:
#               if release_year > 1999.0:
#                 <= 0.1159(0/0/)
#               else:
#                 if release_year > 1995.0:
#                   <= -0.1106(0/0/)
#                 else:
#                   if release_year > 1994.0:
#                     if overview_bm25 > 0.0:
#                       <= -0.1121(0/0/)
#                     else:
#                       <= 0.0202(0/0/)
#                   else:
#                     <= -0.0758(0/0/)
#           else:
#             <= -0.1011(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0577(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1214(0/0/)
#       else:
#         if release_year > 1989.0:
#           <= 0.0681(0/0/)
#         else:
#           <= 0.1094(3/1/qid:40:2(12180)-4(11))
#   else:
#     if release_year > 1977.0:
#       <= -0.0379(0/0/)
#     else:
#       if title_fuzzy > 8.941582:
#         <= 0.1377(0/0/)
#       else:
#         <= -0.1021(0/0/)
# else:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.0602207:
#       <= 0.0913(0/0/)
#     else:
#       if release_year > 2013.0:
#         <= 0.0621(0/0/)
#       else:
#         <= -0.0204(2/1/qid:40:2(1895)-3(330459))
#   else:
#     if overview_bm25 > 9.023443:
#       <= 0.0133(0/0/)
#     else:
#       if release_year > 2016.0:
#         <= -0.1175(0/0/)
#       else:
#         if coll_name_bm25 > 6.483505:
#           <= -0.0751(0/0/)
#         else:
#           if overview_bm25 > 5.1374836:
#             <= -0.0260(0/0/)
#           else:
#             if release_year > 1987.0:
#               if release_year > 1995.0:
#                 <= -0.0836(0/0/)
#               else:
#                 if release_year > 1994.0:
#                   if overview_bm25 > 0.0:
#                     <= -0.1117(0/0/)
#                   else:
#                     if title_fuzzy > 0.0:
#                       <= -0.1027(0/0/)
#                     else:
#                       <= 0.0322(0/0/)
#                 else:
#                   <= -0.0779(0/0/)
#             else:
#               <= -0.0915(25/1/qid:40:0(85783)-3(1892))
#
#
# if title_fuzzy > 8.181669:
#   if title_phrase > 0.0:
#     if overview_bm25 > 7.6434507:
#       <= 0.0547(0/0/)
#     else:
#       if release_year > 2000.0:
#         <= 0.1210(0/0/)
#       else:
#         <= 0.0906(3/1/qid:40:2(12180)-4(11))
#   else:
#     if release_year > 1977.0:
#       <= -0.0324(0/0/)
#     else:
#       <= 0.0962(0/0/)
# else:
#   if coll_name_bm25 > 4.836267:
#     if overview_bm25 > 5.8483677:
#       <= 0.0578(0/0/)
#     else:
#       <= -0.0158(0/0/)
#   else:
#     if overview_bm25 > 12.559557:
#       <= -0.1143(0/0/)
#     else:
#       if overview_bm25 > 4.1612325:
#         if overview_bm25 > 4.1906004:
#           if release_year > 1988.0:
#             <= -0.0796(0/0/)
#           else:
#             if release_year > 1980.0:
#               <= 0.0768(0/0/)
#             else:
#               <= -0.0755(0/0/)
#         else:
#           <= 0.1065(0/0/)
#       else:
#         if release_year > 2016.0:
#           <= -0.1163(0/0/)
#         else:
#           if title_phrase > 0.0:
#             <= -0.0957(2/1/qid:40:2(1895)-3(330459))
#           else:
#             if release_year > 1987.0:
#               if release_year > 2000.0:
#                 <= -0.0912(0/0/)
#               else:
#                 if release_year > 1999.0:
#                   <= 0.1320(0/0/)
#                 else:
#                   if release_year > 1995.0:
#                     <= -0.1099(0/0/)
#                   else:
#                     if release_year > 1994.0:
#                       <= 0.0107(0/0/)
#                     else:
#                       <= -0.0743(0/0/)
#             else:
#               <= -0.0973(25/1/qid:40:0(85783)-3(1892))

# %%
client.get_doc(doc_id=860)
# Out:
# {'id': '860',
#  'title': 'WarGames',
#  'overview': "High School student David Lightman (Matthew Broderick) has a talent for hacking. But while trying to hack into a computer system to play unreleased video games, he unwittingly taps into the Defense Department's war computer and initiates a confrontation of global proportions! Together with his girlfriend (Ally Sheedy) and a wizardly computer genius (John Wood), David must race against time to outwit his opponent...and prevent a nuclear Armageddon.",
#  'tagline': 'Is it a game, or is it real?',
#  'directors': ['John Badham'],
#  'cast': 'Matthew Broderick Dabney Coleman Ally Sheedy John Wood Barry Corbin Juanin Clay Kent Williams Dennis Lipscomb Joe Dorsey Irving Metzman Michael Ensign William Bogert Susan Davis James Tolkan David Clover Drew Snyder John Garber Duncan Wilmore Billy Ray Sharkey John Spencer Michael Madsen Erik Stern Gary Bisig Gary Sexton Jason Bernard Frankie Hill Jesse D. Goins Alan Blumenfeld Len Lawson Maury Chaykin Eddie Deezen Stack Pierce William H. Macy',
#  'genres': ['Thriller', 'Science Fiction'],
#  'release_date': '1983-06-03',
#  'release_year': '1983',
#  'vote_average': 7.0,
#  'vote_count': 400,
#  'collection_name': 'WarGames Collection'}
