# %% [markdown]
# Download corpus, judgments, etc

# %%
from ltr import download
corpus='http://es-learn-to-rank.labs.o19s.com/blog.jsonl'
judgments='http://es-learn-to-rank.labs.o19s.com/osc_judgments.txt'

download([corpus, judgments], dest='data/');
# Out:
# data/blog.jsonl already exists
# data/osc_judgments.txt already exists

# %% [markdown]
# Parse out OSC's blog into `articles`

# %%
import json

articles = []

with open('data/blog.jsonl') as f:
    for line in f:
        blog = json.loads(line)
        articles.append(blog)

articles[-7]
# Out:
# {'title': "Lets Stop Saying 'Cognitive Search'",
#  'url': 'https://opensourceconnections.com/blog/2019/05/28/lets-stop-saying-cognitive-search/',
#  'author': 'doug-turnbull',
#  'content': ' I consume a lot of search materials: blogs, webinars, papers, and marketing collateral. There’s a consistent theme that crops up over the years: buzzwords! I understand why this happens, and it’s not all negative. We want to invite others outside our community into what we do. Heck I write my own marketing collateral, so I get the urge to jump on a buzzword bandwagon from time-to-time. \n\n That being said, I want to tell you a dirty little secret. Nobody really knows what ‘cognitive search’ means in any concrete sense. Sit two people down, and ask them what problem ‘cognitive search’ solves, and you’ll get two different answers. Most likely they imagine some kind of silver-bullet solution to a unique, painful search relevance problem they’re experiencing. Problems that require careful, deep thought where there truly isn’t an easy, one-size-fits-all, silver-bullet solution. As this inevitably leads to disappointment, buzzwords like this ultimately disenchant those brought into the community. Let’s go over why it’s important to scrub buzzwords from our language if we want to help each other solve our relevance problems. \n\n 1. The ML techniques applied to search are extremely varied \n\n ‘Cognitive search’ implies a single machine learning technique. But there’s such a broad range of potential machine learning ‘lego bricks’ that just saying ‘cognitive search’ doesn’t concretely convey how a problem is solved. You might as well say the problem is solved with ‘computers.’ It could mean learning to rank to optimize relevance ranking. It might mean embeddings or knowledge graphs to improve semantic understanding of queries and content. Maybe they use contextual bandits or neural language models? \n\n As many Haystack talks on these subjects attest many of these solutions can just as easily create a disaster as they might be a perfect fit for the problem. The takeaway is if someone says they’re going to apply ‘cognitive search’ to a problem, ask them to get specific about the techniques they use and why they’ll be appropriate to your problems. \n\n 2. Expect customization, not turn-key solutions \n\n Search relevance requirements have subtly unique requirements that are hard for users to consciously express. An internal enterprise search engine has not much in common with Google. Even within domains, one job search experience (ie general purpose Careerbuilder) might have little resemblance to another’s (ie hourly-wage oriented Snag). None of which look anything like E-Commerce Search or Patent Examiner Search. \n\n Matching the machine learning lego pieces to the subtle, hard to capture specifics of an application is hard. You should expect a lot of customization. I’ve noticed that search engine product companies have A LOT of professional services. If you care about the problem, you’ll either need a competent internal team or a long-term implementation relationship with a vendor. An honest question is whether you would rather own that customization yourself? Or outsource it to an external entity? If getting it right is core value, tread carefully. Don’t assume because it’s all just ‘cognitive search’ that you don’t need to think very deeply about the problem. \n\n 3. ‘Cognitive Search’ is a hypothesis, not a solution. Can you measure it? \n\n The silver bullet to improving search quality is not machine learning, its measurement and experimental methodology. With so many possible ways of applying machine learning to relevance, you need a system for evaluating which will work, and which won’t. It’s not as simple as getting a ‘cognitive search’ engine and saying its done and dusted. Every proposed solution should be approached as a hypothesis, not a guarantee. \n\n Can your organization scientifically study how a hypothesis impacts your business? Do you have KPIs tied to business value, that demonstrate search relevance’s impact on your business? Do you have a way to systematically measure what search results were good/ ...
#  'excerpt': ' We won’t address machine learning illiteracy in search if we can’t go beyond buzzwords. We need to teach concrete, specific techniques. \n',
#  'post_date': '2019-05-28T00:00:00-0400',
#  'categories': ['blog', 'Relevancy', 'Learning-to-rank'],
#  'id': 2883614620}

# %% [markdown]
# Instantiate an OpenSearch client.

# %%
from ltr.client import OpenSearchClient
client=OpenSearchClient()
# Out:
# http://localhost:9201/_ltr; <OpenSearch([{'host': 'localhost', 'port': 9201}])>

# %% [markdown]
# Reindex from the corpus into the `blog` index. The JSON file at `docker/elasticsearch/<index_name>_settings.json` is loaded to configure the index.

# %%
from ltr.index import rebuild
rebuild(client, index='blog', doc_src=articles)
# Out:
# Index blog already exists. Use `force = True` to delete and recreate

# %% [markdown]
# A set of features that we've come up with that seems to work well for OSC's blog. Note here, these are Elasticsearch specific

# %%
client.reset_ltr(index='blog')

config = {
    "featureset": {
        "features": [
            {
                "name": "title_term_match",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                       "filter": {
                            "match": {
                                "title": "{{keywords}}"
                            }
                       },
                       "boost": 1.0
                    }
                }
            },
           {
                "name": "content_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {
                       "content": {
                          "query": "{{keywords}}"
                        }
                    }
                }
            },
            {
                "name": "title_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {
                       "title": "{{ keywords }}"
                    }
                }
            },
            {
                "name": "title_phrase_match",
                "params": ["keywords"],
                "template": {
                    "constant_score": {
                       "filter": {
                            "match_phrase": {
                                "title": "{{keywords}}"
                            }
                       },
                       "boost": 1.0
                    }
                }
            },
            
            {
                "name": "stepwise_post_date",
                "params": ["keywords"],
                "template": {
                  "function_score": {
                     "query": {
                        "match_all": {
                        }
                     },
                     "boost_mode": "replace",
                     "score_mode": "sum",
                     "functions": [
                        {
                            "filter": {
                                "range": {
                                    "post_date": {
                                        "gte": "now-180d"
                                    }
                                }
                            },
                            "weight": "100"               
                        },
                        {
                            "filter": {
                                "range": {
                                    "post_date": {
                                        "gte": "now-360d"
                                    }
                                }
                            },
                            "weight": "100"               
                        },
                          {
                            "filter": {
                                "range": {
                                    "post_date": {
                                        "gte": "now-90d"
                                    }
                                }
                            },
                            "weight": "100"               
                        }

                     ]
                  }
                }
            },
            {
                "name": "category_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {
                       "categories": "{{ keywords }}"
                    }
                }
            },
            {
                "name": "excerpt_bm25",
                "params": ["keywords"],
                "template": {
                    "match": {
                       "excerpt": "{{ keywords }}"
                    }
                }
            },
            {
                "name": "excerpt_phrase_bm25",
                "params": ["keywords"],
                "template": {
                    "match_phrase": {
                       "excerpt": "{{ keywords }}"
                    }
                }
            },
        ]
    },
    "validation": {
      "index": "blog",
      "params": {
          "keywords": "rambo"
      }

   }
}

client.create_featureset(index='blog', name='test', ftr_config=config)
# Out:
# Removed Default LTR feature store [Status: 200]
# Initialize Default LTR feature store [Status: 200]
# Create test feature set [Status: 201]

# %% [markdown]
# With features loaded, transform the judgment list (`query,doc,label`) into a full training set with `query,doc,label,ftr1,ftr2,...` to prepare for training

# %%
from ltr.judgments import judgments_open
from ltr.log import FeatureLogger
from itertools import groupby

ftr_logger=FeatureLogger(client, index='blog', feature_set='test')
with judgments_open('data/osc_judgments.txt') as judgment_list:
    for qid, query_judgments in groupby(judgment_list, key=lambda j: j.qid):
        ftr_logger.log_for_qid(judgments=query_judgments, 
                               qid=qid,
                               keywords=judgment_list.keywords(qid))
# Out:
# Recognizing 47 queries

# %% [markdown]
# # Judgement List Definition
#
# from https://opensourceconnections.com/blog/2019/08/13/hello-ltr-sandbox-for-learning-to-rank/
# The judgment list is expressed as a ‘stub’ RankSVM file format. This file format, common to learning to rank tasks tracks the grade in the first column. In our example, we use the standard of a 0 meaning most irrelevant and a 4 meaning perfectly relevant for the query. The second column is a unique identifier for the query, prefixed with qid. A comment with the document identifier follows.

# %%
with judgments_open('data/osc_judgments.txt') as print_judgement_list:
    for line in print_judgement_list:
        print(line)
# Out:
# Recognizing 47 queries
# grade:4 qid:1 (solr) docid:4036602523
# grade:4 qid:1 (solr) docid:2349740828
# grade:4 qid:1 (solr) docid:2307460466
# grade:4 qid:1 (solr) docid:4021588268
# grade:3 qid:1 (solr) docid:3873568549
# grade:3 qid:1 (solr) docid:2721405712
# grade:3 qid:1 (solr) docid:3780360030
# grade:3 qid:1 (solr) docid:3941005933
# grade:3 qid:1 (solr) docid:1686720823
# grade:3 qid:1 (solr) docid:3394242689
# grade:3 qid:1 (solr) docid:2916170833
# grade:2 qid:1 (solr) docid:3245818064
# grade:2 qid:1 (solr) docid:3913088476
# grade:2 qid:1 (solr) docid:3501843710
# grade:2 qid:1 (solr) docid:4124823494
# grade:2 qid:1 (solr) docid:3225155378
# grade:2 qid:1 (solr) docid:1502936313
# grade:2 qid:1 (solr) docid:3252179363
# grade:2 qid:1 (solr) docid:2848549888
# grade:2 qid:1 (solr) docid:417217470
# grade:2 qid:1 (solr) docid:3986527021
# grade:3 qid:1 (solr) docid:3369505975
# grade:2 qid:1 (solr) docid:3252179363
# grade:2 qid:1 (solr) docid:2502109327
# grade:2 qid:1 (solr) docid:3440818580
# grade:1 qid:1 (solr) docid:78637494
# grade:1 qid:1 (solr) docid:254683007
# grade:0 qid:1 (solr) docid:4177290998
# grade:0 qid:1 (solr) docid:2579852587
# grade:0 qid:1 (solr) docid:2926247873
# grade:0 qid:1 (solr) docid:3065216762
# grade:0 qid:1 (solr) docid:14036114
# grade:0 qid:1 (solr) docid:1765487539
# grade:4 qid:2 (elasticsearch) docid:1265938948
# grade:3 qid:2 (elasticsearch) docid:3123649443
# grade:2 qid:2 (elasticsearch) docid:3252179363
# grade:3 qid:2 (elasticsearch) docid:254683007
# grade:3 qid:2 (elasticsearch) docid:2993628421
# grade:3 qid:2 (elasticsearch) docid:2689407214
# grade:3 qid:2 (elasticsearch) docid:17925372
# grade:2 qid:2 (elasticsearch) docid:417217470
# grade:3 qid:2 (elasticsearch) docid:3477505197
# grade:3 qid:2 (elasticsearch) docid:1891056050
# grade:3 qid:2 (elasticsearch) docid:578157694
# grade:4 qid:2 (elasticsearch) docid:4062359014
# grade:0 qid:2 (elasticsearch) docid:4177290998
# grade:3 qid:2 (elasticsearch) docid:3252179363
# grade:0 qid:3 (cassandra) docid:2992260052
# grade:4 qid:3 (cassandra) docid:1664871216
# grade:0 qid:3 (cassandra) docid:2606121430
# grade:2 qid:3 (cassandra) docid:3464168716
# grade:2 qid:3 (cassandra) docid:2741197519
# grade:2 qid:3 (cassandra) docid:1373706671
# grade:4 qid:3 (cassandra) docid:1357425427
# grade:4 qid:3 (cassandra) docid:2264869487
# grade:4 qid:3 (cassandra) docid:1839943486
# grade:2 qid:3 (cassandra) docid:180421401
# grade:2 qid:4 (camel) docid:422034358
# grade:4 qid:4 (camel) docid:1257472028
# grade:4 qid:4 (camel) docid:3501843710
# grade:4 qid:4 (camel) docid:1477529249
# grade:0 qid:4 (camel) docid:3738480096
# grade:0 qid:4 (camel) docid:2073248876
# grade:4 qid:5 (elastic graph) docid:17925372
# grade:3 qid:5 (elastic graph) docid:1891056050
# grade:2 qid:5 (elastic graph) docid:1948242641
# grade:2 qid:5 (elastic graph) docid:578157694
# grade:2 qid:5 (elastic graph) docid:2201657261
# grade:1 qid:5 (elastic graph) docid:2642574926
# grade:3 qid:5 (elastic graph) docid:2223776635
# grade:2 qid:5 (elastic graph) docid:78637494
# grade:0 qid:5 (elastic graph) docid:3464168716
# grade:0 qid:5 (elastic graph) docid:2741197519
# grade:4 qid:6 (ebook) docid:4266372689
# grade:3 qid:6 (ebook) docid:3889254213
# grade:2 qid:6 (ebook) docid:576003762
# grade:4 qid:7 (e-book) docid:4266372689
# grade:3 qid:7 (e-book) docid:3889254213
# grade:2 qid:7 (e-book) docid:576003762
# grade:3 qid:8 (elastic-graph) docid:1891056050
# grade:2 qid:8 (elastic-graph) docid:1948242641
# grade:2 qid:8 (elastic-graph) docid:578157694
# grade:2 qid:8 (elastic-graph) docid:2201657261
# grade:1 qid:8 (elastic-graph) docid:2642574926
# grade:3 qid:8 (elastic-graph) docid:2223776635
# grade:2 qid:8 (elastic-graph) docid:78637494
# grade:0 qid:8 (elastic-graph) docid:3464168716
# grade:0 qid:8 (elastic-graph) docid:2741197519
# grade:4 qid:9 (learning to rank) docid:4062359014
# grade:4 qid:9 (learning to rank) docid:3252179363
# grade:4 qid:9 (learning to rank) docid:2642574926
# grade:3 qid:9 (learning to rank) docid:3477505197
# grade:3 qid:9 (learning to rank) docid:578157694
# grade:4 qid:9 (learning to rank) docid:1265938948
# grade:3 qid:9 (learning to rank) docid:2201657261
# grade:1 qid:9 (learning to rank) docid:3123649443
# grade:0 qid:9 (learning to rank) docid:1080984974
# grade:1 qid:9 (learning to rank) docid:1891056050
# grade:2 qid:10 (semantic) docid:2307460466
# grade:4 qid:10 (semantic) docid:3123649443
# grade:4 qid:10 (semantic) docid:254683007
# grade:4 qid:10 (semantic) docid:1757170846
# grade:3 qid:10 (semantic) docid:1502936313
# grade:4 qid:10 (semantic) docid:770893293
# grade:2 qid:10 (semantic) docid:480393712
# grade:0 qid:10 (semantic) docid:723702291
# grade:2 qid:10 (semantic) docid:2217914528
# grade:4 qid:11 (bm25f) docid:162357220
# grade:4 qid:12 (taming search) docid:4278858718
# grade:3 qid:12 (taming search) docid:2806202279
# grade:1 qid:12 (taming search) docid:3477505197
# grade:1 qid:12 (taming search) docid:578157694
# grade:1 qid:12 (taming search) docid:3986527021
# grade:1 qid:12 (taming search) docid:3252179363
# grade:1 qid:12 (taming search) docid:4062359014
# grade:1 qid:12 (taming search) docid:1265938948
# grade:1 qid:12 (taming search) docid:2642574926
# grade:1 qid:12 (taming search) docid:2349740828
# grade:1 qid:12 (taming search) docid:2307460466
# grade:1 qid:12 (taming search) docid:1891056050
# grade:4 qid:13 (bm25) docid:162357220
# grade:0 qid:13 (bm25) docid:1757170846
# grade:4 qid:13 (bm25) docid:82610579
# grade:4 qid:14 (lunch and learn) docid:3071151997
# grade:0 qid:14 (lunch and learn) docid:3477505197
# grade:0 qid:14 (lunch and learn) docid:578157694
# grade:0 qid:14 (lunch and learn) docid:4062359014
# grade:0 qid:14 (lunch and learn) docid:2642574926
# grade:0 qid:14 (lunch and learn) docid:3252179363
# grade:0 qid:14 (lunch and learn) docid:1265938948
# grade:0 qid:14 (lunch and learn) docid:1080984974
# grade:0 qid:14 (lunch and learn) docid:1891056050
# grade:0 qid:14 (lunch and learn) docid:2201657261
# grade:0 qid:14 (lunch and learn) docid:2992260052
# grade:4 qid:15 (basket analysis) docid:373776490
# grade:0 qid:15 (basket analysis) docid:2307460466
# grade:3 qid:15 (basket analysis) docid:2223776635
# grade:1 qid:15 (basket analysis) docid:254683007
# grade:1 qid:15 (basket analysis) docid:3123649443
# grade:0 qid:15 (basket analysis) docid:3629971547
# grade:0 qid:15 (basket analysis) docid:421331994
# grade:0 qid:15 (basket analysis) docid:2579852587
# grade:1 qid:15 (basket analysis) docid:4038633349
# grade:0 qid:15 (basket analysis) docid:3440818580
# grade:4 qid:16 (graph) docid:1261816617
# grade:3 qid:16 (graph) docid:1891056050
# grade:1 qid:16 (graph) docid:2642574926
# grade:4 qid:16 (graph) docid:17925372
# grade:3 qid:16 (graph) docid:2223776635
# grade:1 qid:16 (graph) docid:78637494
# grade:1 qid:16 (graph) docid:3464168716
# grade:1 qid:16 (graph) docid:2741197519
# grade:1 qid:16 (graph) docid:1373706671
# grade:2 qid:16 (graph) docid:373776490
# grade:1 qid:16 (graph) docid:2916170833
# grade:4 qid:17 (indexing chinese) docid:2502109327
# grade:1 qid:17 (indexing chinese) docid:2349740828
# grade:0 qid:17 (indexing chinese) docid:3252179363
# grade:0 qid:17 (indexing chinese) docid:4062359014
# grade:0 qid:17 (indexing chinese) docid:1265938948
# grade:0 qid:17 (indexing chinese) docid:2307460466
# grade:0 qid:17 (indexing chinese) docid:254683007
# grade:0 qid:17 (indexing chinese) docid:162357220
# grade:1 qid:17 (indexing chinese) docid:3123649443
# grade:0 qid:17 (indexing chinese) docid:417217470
# grade:4 qid:18 (elasticsearch recommendation system) docid:17925372
# grade:4 qid:18 (elasticsearch recommendation system) docid:2223776635
# grade:3 qid:18 (elasticsearch recommendation system) docid:373776490
# grade:3 qid:18 (elasticsearch recommendation system) docid:1891056050
# grade:2 qid:18 (elasticsearch recommendation system) docid:1265938948
# grade:2 qid:18 (elasticsearch recommendation system) docid:3252179363
# grade:2 qid:18 (elasticsearch recommendation system) docid:3477505197
# grade:2 qid:18 (elasticsearch recommendation system) docid:578157694
# grade:2 qid:18 (elasticsearch recommendation system) docid:4062359014
# grade:2 qid:18 (elasticsearch recommendation system) docid:2201657261
# grade:0 qid:18 (elasticsearch recommendation system) docid:2307460466
# grade:0 qid:18 (elasticsearch recommendation system) docid:2642574926
# grade:1 qid:18 (elasticsearch recommendation system) docid:3123649443
# grade:4 qid:19 (elasticsearch recsys) docid:17925372
# grade:4 qid:19 (elasticsearch recsys) docid:2223776635
# grade:3 qid:19 (elasticsearch recsys) docid:373776490
# grade:3 qid:19 (elasticsearch recsys) docid:1891056050
# grade:2 qid:19 (elasticsearch recsys) docid:1265938948
# grade:2 qid:19 (elasticsearch recsys) docid:3252179363
# grade:2 qid:19 (elasticsearch recsys) docid:3477505197
# grade:2 qid:19 (elasticsearch recsys) docid:578157694
# grade:2 qid:19 (elasticsearch recsys) docid:4062359014
# grade:2 qid:19 (elasticsearch recsys) docid:2201657261
# grade:0 qid:19 (elasticsearch recsys) docid:2307460466
# grade:0 qid:19 (elasticsearch recsys) docid:2642574926
# grade:1 qid:19 (elasticsearch recsys) docid:3123649443
# grade:4 qid:20 (elasticsearch recommender) docid:17925372
# grade:4 qid:20 (elasticsearch recommender) docid:2223776635
# grade:3 qid:20 (elasticsearch recommender) docid:373776490
# grade:3 qid:20 (elasticsearch recommender) docid:1891056050
# grade:2 qid:20 (elasticsearch recommender) docid:1265938948
# grade:2 qid:20 (elasticsearch recommender) docid:3252179363
# grade:2 qid:20 (elasticsearch recommender) docid:3477505197
# grade:2 qid:20 (elasticsearch recommender) docid:578157694
# grade:2 qid:20 (elasticsearch recommender) docid:4062359014
# grade:2 qid:20 (elasticsearch recommender) docid:2201657261
# grade:0 qid:20 (elasticsearch recommender) docid:2307460466
# grade:0 qid:20 (elasticsearch recommender) docid:2642574926
# grade:1 qid:20 (elasticsearch recommender) docid:3123649443
# grade:4 qid:21 (solr synonym) docid:2307460466
# grade:4 qid:21 (solr synonym) docid:4221484365
# grade:4 qid:21 (solr synonym) docid:4038633349
# grade:2 qid:21 (solr synonym) docid:3123649443
# grade:2 qid:21 (solr synonym) docid:254683007
# grade:1 qid:21 (solr synonym) docid:3986527021
# grade:1 qid:21 (solr synonym) docid:4021588268
# grade:1 qid:21 (solr synonym) docid:4036602523
# grade:0 qid:21 (solr synonym) docid:2349740828
# grade:0 qid:21 (solr synonym) docid:2225179329
# grade:0 qid:21 (solr synonym) docid:4062359014
# grade:0 qid:21 (solr synonym) docid:2992260052
# grade:3 qid:22 (machine learning) docid:1095227228
# grade:4 qid:22 (machine learning) docid:3252179363
# grade:4 qid:22 (machine learning) docid:1265938948
# grade:3 qid:22 (machine learning) docid:4062359014
# grade:3 qid:22 (machine learning) docid:2642574926
# grade:3 qid:22 (machine learning) docid:3477505197
# grade:0 qid:41 (utf 8) docid:1984801189
# grade:2 qid:41 (utf 8) docid:4020043048
# grade:0 qid:41 (utf 8) docid:2165998155
# grade:4 qid:41 (utf 8) docid:2349740828
# grade:1 qid:41 (utf 8) docid:1080984974
# grade:0 qid:41 (utf 8) docid:17925372
# grade:0 qid:41 (utf 8) docid:2993628421
# grade:0 qid:41 (utf 8) docid:4028652739
# grade:1 qid:41 (utf 8) docid:2217914528
# grade:0 qid:41 (utf 8) docid:82610579
# grade:0 qid:41 (utf 8) docid:1984801189
# grade:2 qid:41 (utf 8) docid:4020043048
# grade:0 qid:41 (utf 8) docid:2165998155
# grade:4 qid:42 (linear models) docid:2642574926
# grade:4 qid:42 (linear models) docid:4062359014
# grade:2 qid:42 (linear models) docid:3252179363
# grade:2 qid:42 (linear models) docid:1265938948
# grade:2 qid:42 (linear models) docid:3477505197
# grade:1 qid:42 (linear models) docid:578157694
# grade:0 qid:42 (linear models) docid:422034358
# grade:1 qid:42 (linear models) docid:3123649443
# grade:0 qid:42 (linear models) docid:1664871216
# grade:1 qid:42 (linear models) docid:162357220
# grade:4 qid:43 (data hackers) docid:3477505197
# grade:3 qid:43 (data hackers) docid:3276672333
# grade:3 qid:43 (data hackers) docid:652349051
# grade:0 qid:43 (data hackers) docid:3252179363
# grade:0 qid:43 (data hackers) docid:2642574926
# grade:0 qid:43 (data hackers) docid:4062359014
# grade:1 qid:43 (data hackers) docid:1891056050
# grade:0 qid:43 (data hackers) docid:2992260052
# grade:0 qid:43 (data hackers) docid:422034358
# grade:4 qid:44 (becamp) docid:1754464133
# grade:2 qid:44 (becamp) docid:2599472181
# grade:2 qid:44 (becamp) docid:3854160298
# grade:1 qid:44 (becamp) docid:2399734688
# grade:0 qid:44 (becamp) docid:3257141456
# grade:2 qid:44 (becamp) docid:1870385244
# grade:2 qid:44 (becamp) docid:2065293359
# grade:0 qid:44 (becamp) docid:2932203182
# grade:1 qid:44 (becamp) docid:752675227
# grade:4 qid:45 (beswarm) docid:1080984974
# grade:3 qid:45 (beswarm) docid:14036114
# grade:3 qid:45 (beswarm) docid:1172819280
# grade:4 qid:47 (ama) docid:3225155378
# grade:4 qid:48 (relevancy) docid:2642574926
# grade:4 qid:48 (relevancy) docid:4062359014
# grade:4 qid:48 (relevancy) docid:1265938948
# grade:4 qid:48 (relevancy) docid:3252179363
# grade:4 qid:48 (relevancy) docid:2307460466
# grade:4 qid:48 (relevancy) docid:254683007
# grade:4 qid:48 (relevancy) docid:3123649443
# grade:3 qid:48 (relevancy) docid:3419956617
# grade:3 qid:48 (relevancy) docid:162357220
# grade:3 qid:48 (relevancy) docid:17925372
# grade:4 qid:49 (match query parser) docid:2307460466
# grade:1 qid:49 (match query parser) docid:4062359014
# grade:1 qid:49 (match query parser) docid:2642574926
# grade:1 qid:49 (match query parser) docid:1265938948
# grade:1 qid:49 (match query parser) docid:2349740828
# grade:1 qid:49 (match query parser) docid:3252179363
# grade:1 qid:49 (match query parser) docid:3477505197
# grade:1 qid:49 (match query parser) docid:578157694
# grade:2 qid:49 (match query parser) docid:254683007
# grade:2 qid:49 (match query parser) docid:3123649443

# %% [markdown]
# Train using RankyMcRankFace with the training set, optimizing search for a specific metric (here `NDCG@10`). Note `ltr.train` has additional capabilities for performing k-fold cross validaiton to ensure the model isn't overfit to training data.
#
# The model is stored in the search engine named `test` which can be referred to later for searching.

# %%
from ltr.ranklib import train
trainLog = train(client,
                 training_set=ftr_logger.logged,
                 metric2t='NDCG@10',
                 featureSet='test',
                 index='blog',
                 modelName='test')
# Out:
# /var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/RankyMcRankFace.jar already exists
# Running java -jar /var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 50 -bag 1 -leaf 10 -frate 1.0 -srate 1.0 -train /var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/training.txt -save data/test_model.txt
# Delete model test: 404
# Created Model test [Status: 201]
# Model saved

# %%
# !java -jar /var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/RankyMcRankFace.jar -ranker 6 -shrinkage 0.1 -metric2t NDCG@10 -tree 50 -bag 1 -leaf 10 -frate 1.0 -srate 1.0 -train
# Out:
# Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 17 out of bounds for length 17
# 	at ciir.umass.edu.eval.Evaluator.main(Evaluator.java:223)

# %%
/var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/RankyMcRankFace.jar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 var/folders/33/jx0mw87156q2hmtrr_r82s7r0000gs/T/RankyMcRankFace.jar()
#
# NameError: name 'var' is not defined

# %% [markdown]
# Search! Pass some configuration in (`blog_fields`) for display purposes.

# %%
blog_fields = {
    'title': 'title',
    'display_fields': ['url', 'author', 'categories', 'post_date']
}

from ltr import search
search(client, "haystack ml", modelName='test', 
       index='blog', fields=blog_fields)
# Out:
# {"size": 5, "query": {"sltr": {"params": {"keywords": "haystack ml", "keywordsList": ["haystack ml"]}, "model": "test"}}}
# {'size': 5, 'query': {'sltr': {'params': {'keywords': 'haystack ml', 'keywordsList': ['haystack ml']}, 'model': 'test'}}}
# Scott Stults to Speak on Solr Security at the Solr and Text Analytics Conference
# 2.0238843
# https://opensourceconnections.com/blog/2011/03/21/scott-stults-to-speak-on-solr-security-at-the-solr-and-text-analytics-conference/
# jason-hull
# ['blog', 'Conference', 'Government', 'News', 'Speaking']
# 2011-03-21T00:00:00-0400
# ---------------------------------------
# Recap of Activate 2018
# 0.88978434
# https://opensourceconnections.com/blog/2018/11/09/recap-of-activate-2018/
# elizabeth-haubert
# ['blog', 'Solr', 'Machine-learning']
# 2018-11-09T00:00:00-0500
# ---------------------------------------
# Haystack - The Search Relevance Conference.
# 0.78783745
# https://opensourceconnections.com/blog/2019/04/24/haystack/
# eric-pugh
# ['events']
# 2019-04-24T00:00:00-0400
# ---------------------------------------
# Multi-Level Security in Solr
# 0.6376177
# https://opensourceconnections.com/blog/2011/06/17/multi-level-security-in-solr/
# scott-stults
# ['blog', 'Conference', 'Government', 'solr', 'Speaking']
# 2011-06-17T00:00:00-0400
# ---------------------------------------
# Haystack 2019 day 1 - grab your popcorn, it's Relevance Avengers time
# 0.07273796
# https://opensourceconnections.com/blog/2019/05/07/haystack-2019-day1/
# charlie-hull
# ['blog', 'Relevance']
# 2019-05-07T00:00:00-0400
# ---------------------------------------
